# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import os
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import random
import cv2
# from vgg16 import VGG16_LSTM
import pickle
import torch.nn as nn
import torch
import datetime
from model import Model
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms, utils, models
from torch.utils.data import Dataset, DataLoader
from facenet_pytorch import MTCNN
import logging
import torch
import torch.nn as nn
import gc
from einops import rearrange
from tqdm import tqdm
# from kw_r2plus1d_video_swin_transformer import SwinTransformer3D
batchsz = 4
frame_nums=15
start_epoch = 0
test_flage=False
model_name ="face_key_point"
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('[%(asctime)s]::%(module)s::%(levelname)s::%(message)s')
streamHandler = logging.StreamHandler()
streamHandler.setFormatter(formatter)
fileHandler = logging.FileHandler('./LOG/personalityLog.log')
fileHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.addHandler(fileHandler)
USE_CUDA = torch.cuda.is_available()
# device = torch.device('cuda:1' if USE_CUDA else 'cpu')

# %%
logger.debug('============={}+2D Video Vision Transformer Strat!============='.format(model_name))
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:0' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:', device)
# Out:
# [2024-10-15 10:58:25,766]::2730006395::DEBUG::=============face_key_point+2D Video Vision Transformer Strat!=============
# True
# 학습을 진행하는 기기: cuda:0

# %%
import numpy as np
import mediapipe as mp

mp_face_mesh = mp.solutions.face_mesh
mp_pose = mp.solutions.pose

num_face_keypoints = 478
num_pose_keypoints = 23
total_keypoints = num_face_keypoints + num_pose_keypoints

A = np.zeros((total_keypoints, total_keypoints))

face_connections = []
face_connections.extend(mp_face_mesh.FACEMESH_TESSELATION)  
face_connections.extend(mp_face_mesh.FACEMESH_CONTOURS)   
face_connections.extend(mp_face_mesh.FACEMESH_IRISES)      

pose_connections = [
    (11, 12),  
    (11, 13),  
    (13, 15),  
    (12, 14),  
    (14, 16),  
    (23, 24),  
    (23, 25),  
    (25, 27), 
    (24, 26),  
    (26, 28), 
    (11, 23),  
    (12, 24)   
]

for i, j in face_connections:
    A[i, j] = 1
    A[j, i] = 1  

for i, j in pose_connections:
    A[i-10 + 478, j-10 + 478] = 1
    A[j-10 + 478, i-10 + 478] = 1
A = torch.from_numpy(np.asarray(A)).to(device)

# %%
def getdata(pathname,datatype):
    if datatype=="train":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            # train_data_set.extend(pickle.load(output_file))
            final_data_set.extend(pickle.load(output_file))
            # print(i)
        return final_data_set
    elif datatype=="valid":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            valid_data_set=[]
            final_data_set.extend(pickle.load(output_file))
            del valid_data_set
        return final_data_set
print(1)
# Out:
# 1

# %%
save_model_file_path = './save_swintransformer_folder/{}_{}.{}'
mtcnn= MTCNN(image_size=224, margin=0, min_face_size= 20, thresholds=[0.6, 0.7, 0.7], post_process=True)
# test_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/test_set.dat","test")
# test_set_data=test_set_data[:datasize("test",batchsz)]
print(1)
# Out:
# 1

# %%
validation_set_data=getdata("/home/ssrlab/qx/video-swin-transformer-pytorch/data/15Frames/15Frames_bodykeys_correct/valid_set.dat","valid")
# validation_set_data=reshape_to_expected_validinput(validation_set_data)
print(1)
# Out:
# 1

# %%
train_set_data=getdata("/home/ssrlab/qx/video-swin-transformer-pytorch/data/15Frames/15Frames_bodykeys_correct/train_set.dat","train")
# train_set_data=reshape_to_expected_traininput(train_set_data)
print(1)
# Out:
# 1

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
])
print(1)
# Out:
# 1

# %%
class ChalearnDataset(Dataset):
    def __init__(self,fullshot,keypoint,tagdata,transform=None):
        self.fullshot=fullshot
        self.tagdata=tagdata
        self.keypoint=keypoint
        self.transform = transform  # 표준화 여부
    def __len__(self):
        return len(self.fullshot)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()#텐서의 경우 목록으로 돌아가기
        # audiodata = self.audiodata[idx]
        # audiodata = torch.FloatTensor(audiodata)
        fullshot=self.fullshot[idx]
        fullshot=torch.FloatTensor(fullshot)
        keypoint = self.keypoint[idx]
        # image_data=image_data.reshape(15,3,224,224)
        big_five_sorces=self.tagdata[idx]
        big_five_sorces = torch.FloatTensor(big_five_sorces)
        return fullshot,keypoint,big_five_sorces
print(1)
# Out:
# 1

# %%
num_workerssz = 20
lr = 3e-05
epochs = 120
print(1)
# Out:
# 1

# %%
train_set_data = ChalearnDataset(fullshot=train_set_data[1],keypoint = train_set_data[3],tagdata=train_set_data[5],transform=transform)
val_set_data = ChalearnDataset(fullshot=validation_set_data[1],keypoint = validation_set_data[3],tagdata=validation_set_data[5],transform=transform)
train_dataloader = DataLoader(dataset=train_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
val_dataloader = DataLoader(dataset=val_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
max_value=0
print(1)
# Out:
# 1

# %%
model=Model(A, 3, 256, 256, [3, 3*3], [3*3, 16, 32, 64], 3)#adj, num_v, num_classes, gc_dims, sc_dims, feat_dims
model.to(device)
criterion = torch.nn.L1Loss().to(device)  # 손실함수
optimizer = torch.optim.AdamW(model.parameters(), lr=lr) # 옵티마이저

if test_flage==True:
    checkpoint=torch.load(save_model_file_path.format('model',start_epoch,'pth'), map_location=device)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    # criterion.load_state_dict(checkpoint["loss"])
train_avg_loss0=[]
val_avg_loss0=[]
print(1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model=Model(A, 3, 256, 256, [3, 3*3], [3*3, 16, 32, 64], 3)#adj, num_v, num_classes, gc_dims, sc_dims, feat_dims
#       2 model.to(device)
#       3 criterion = torch.nn.L1Loss().to(device)  # 손실함수
#
# File ~/qx/facekeypointmodel/model.py:67, in Model.__init__(self, adj, num_v, num_classes_g, num_classes_x, gc_dims, sc_dims, feat_dims, dropout)
#      65 def __init__(self, adj, num_v, num_classes_g, num_classes_x, gc_dims, sc_dims, feat_dims, dropout=0.5):
#      66 	super(Model, self).__init__()
# ---> 67 	self.gcn = ggcn(True,adj, num_v, num_classes_g, gc_dims, sc_dims, feat_dims)
#      68 	self.xception = xception(pretrained=True)
#      69 	self.early_fusion = early_fusion()
#
# File ~/qx/facekeypointmodel/GCN.py:60, in ggcn(pretrained, adj, num_v, num_classes_g, gc_dims, sc_dims, feat_dims)
#      52     pretrained_dict = torch.load("./checkpoint/st_gcn.kinetics-6fa43f73.pth")
#      54     # model_dict = model.state_dict()
#      55     # #사전 훈련 모델에서 로드된 매개변수를 필터링하고 현재 모델에서 매개변수의 모양과 일치하는 부분만 유지하여 크기 불일치로 인한 오류를 방지하는 역할을 합니다.
#      56     # pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in model_dict and v.size() == model_dict[k].size()}
#      57
#      58     # model_dict.update(pretrained_dict)
# ---> 60     model.load_state_dict(pretrained_dict)
#      62     # model.fc = nn.Linear(2048, 256)
#      63 return model
#
# File ~/ENTER/envs/qx/lib/python3.10/site-packages/torch/nn/modules/module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for GGCN:
# 	Missing key(s) in state_dict: "terminal", "conv.conv.0.weight", "conv.conv.0.bias", "conv.conv.3.weight", "conv.conv.3.bias", "conv.conv.6.weight", "conv.conv.6.bias", "conv.self_attention.con2D.weight", "conv.self_attention.con2D.bias", "conv.self_attention.linearlayer.weight", "conv.self_attention.linearlayer.bias", "conv.fc.weight", "conv.fc.bias".
# 	Unexpected key(s) in state_dict: "A", "data_bn.weight", "data_bn.bias", "data_bn.running_mean", "data_bn.running_var", "data_bn.num_batches_tracked", "st_gcn_networks.0.gcn.conv.weight", "st_gcn_networks.0.gcn.conv.bias", "st_gcn_networks.0.tcn.0.weight", "st_gcn_networks.0.tcn.0.bias", "st_gcn_networks.0.tcn.0.running_mean", "st_gcn_networks.0.tcn.0.running_var", "st_gcn_networks.0.tcn.0.num_batches_tracked", "st_gcn_networks.0.tcn.2.weight", "st_gcn_networks.0.tcn.2.bias", "st_gcn_networks.0.tcn.3.weight", "st_gcn_networks.0.tcn.3.bias", "st_gcn_networks.0.tcn.3.running_mean", "st_gcn_networks.0.tcn.3.running_var", "st_gcn_networks.0.tcn.3.num_batches_tracked", "st_gcn_networks.1.gcn.conv.weight", "st_gcn_networks.1.gcn.conv.bias", "st_gcn_networks.1.tcn.0.weight", "st_gcn_networks.1.tcn.0.bias", "st_gcn_networks.1.tcn.0.running_mean", "st_gcn_networks.1.tcn.0.running_var", "st_gcn_networks.1.tcn.0.num_batches_tracked", "st_gcn_networks.1.tcn.2.weight", "st_gcn_networks.1.tcn.2.bias", "st_gcn_networks.1.tcn.3.weight", "st_gcn_networks.1.tcn.3.bias", "st_gcn_networks.1.tcn.3.running_mean", "st_gcn_networks.1.tcn.3.running_var", "st_gcn_networks.1.tcn.3.num_batches_tracked", "st_gcn_networks.2.gcn.conv.weight", "st_gcn_networks.2.gcn.conv.bias", "st_gcn_networks.2.tcn.0.weight", "st_gcn_networks.2.tcn.0.bias", "st_gcn_networks.2.tcn.0.running_mean", "st_gcn_networks.2.tcn.0.running_var", "st_gcn_networks.2.tcn.0.num_batches_tracked", "st_gcn_networks.2.tcn.2.weight", "st_gcn_networks.2.tcn.2.bias", "st_gcn_networks.2.tcn.3.weight", "st_gcn_networks.2.tcn.3.bias", "st_gcn_networks.2.tcn.3.running_mean", "st_gcn_networks.2.tcn.3.running_var", "st_gcn_networks.2.tcn.3.num_batches_tracked", "st_gcn_networks.3.gcn.conv.weight", "st_gcn_networks.3.gcn.conv.bias", "st_gcn_networks.3.tcn.0.weight", "st_gcn_networks.3.tcn.0.bias", "st_gcn_networks.3.tcn.0.running_mean", "st_gcn_networks.3.tcn.0.running_var", "st_gcn_networks.3.tcn.0.num_batches_tracked", "st_gcn_networks.3.tcn.2.weight", "st_gcn_networks.3.tcn.2.bias", "st_gcn_networks.3.tcn.3.weight", "st_gcn_networks.3.tcn.3.bias", "st_gcn_networks.3.tcn.3.running_mean", "st_gcn_networks.3.tcn.3.running_var", "st_gcn_networks.3.tcn.3.num_batches_tracked", "st_gcn_networks.4.gcn.conv.weight", "st_gcn_networks.4.gcn.conv.bias", "st_gcn_networks.4.tcn.0.weight", "st_gcn_networks.4.tcn.0.bias", "st_gcn_networks.4.tcn.0.running_mean", "st_gcn_networks.4.tcn.0.running_var", "st_gcn_networks.4.tcn.0.num_batches_tracked", "st_gcn_networks.4.tcn.2.weight", "st_gcn_networks.4.tcn.2.bias", "st_gcn_networks.4.tcn.3.weight", "st_gcn_networks.4.tcn.3.bias", "st_gcn_networks.4.tcn.3.running_mean", "st_gcn_networks.4.tcn.3.running_var", "st_gcn_networks.4.tcn.3.num_batches_tracked", "st_gcn_networks.4.residual.0.weight", "st_gcn_networks.4.residual.0.bias", "st_gcn_networks.4.residual.1.weight", "st_gcn_networks.4.residual.1.bias", "st_gcn_networks.4.residual.1.running_mean", "st_gcn_networks.4.residual.1.running_var", "st_gcn_networks.4.residual.1.num_batches_tracked", "st_gcn_networks.5.gcn.conv.weight", "st_gcn_networks.5.gcn.conv.bias", "st_gcn_networks.5.tcn.0.weight", "st_gcn_networks.5.tcn.0.bias", "st_gcn_networks.5.tcn.0.running_mean", "st_gcn_networks.5.tcn.0.running_var", "st_gcn_networks.5.tcn.0.num_batches_tracked", "st_gcn_networks.5.tcn.2.weight", "st_gcn_networks.5.tcn.2.bias", "st_gcn_networks.5.tcn.3.weight", "st_gcn_networks.5.tcn.3.bias", "st_gcn_networks.5.tcn.3.running_mean", "st_gcn_networks.5.tcn.3.running_var", "st_gcn_networks.5.tcn.3.num_batches_tracked", "st_gcn_networks.6.gcn.conv.weight", "st_gcn_networks.6.gcn.conv.bias", "st_gcn_networks.6.tcn.0.weight", "st_gcn_networks.6.tcn.0.bias", "st_gcn_networks.6.tcn.0.running_mean", "st_gcn_networks.6.tcn.0.running_var", "st_gcn_networks.6.tcn.0.num_batches_tracked", "st_gcn_networks.6.tcn.2.weight", "st_gcn_networks.6.tcn.2.bias", "st_gcn_networks.6.tcn.3.weight", "st_gcn_networks.6.tcn.3.bias", "st_gcn_networks.6.tcn.3.run ...

# %%
from torchinfo import summary

summary(model, input_size = ((4, 3, 224, 224),(4,15,501,3)), col_names = ['input_size','output_size','num_params'])
# Out:
# /home/ssrlab/qx/facekeypointmodel/model.py:57: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1702400366987/work/torch/csrc/utils/tensor_new.cpp:261.)
#   mask_code = torch.Tensor(mask_code)
# ========================================================================================================================
# Layer (type:depth-idx)                        Input Shape               Output Shape              Param #
# ========================================================================================================================
# Model                                         [4, 3, 224, 224]          [4, 5]                    --
# ├─GGCN: 1-1                                   [4, 15, 501, 3]           [4, 256]                  15
# │    └─GraphConvolution: 2-1                  [1503, 1503]              [4, 13, 1503, 9]          --
# │    │    └─Dropout: 3-1                      [4, 13, 1503, 6]          [4, 13, 1503, 6]          --
# │    └─StandConvolution: 2-2                  [4, 13, 1503, 9]          [4, 256]                  --
# │    │    └─Dropout: 3-2                      [4, 9, 13, 1503]          [4, 9, 13, 1503]          --
# │    │    └─Sequential: 3-3                   [4, 9, 13, 1503]          [4, 64, 2, 185]           13,632
# │    │    └─self_attention: 3-4               [4, 64, 2, 185]           --                        20,800
# │    │    └─Linear: 3-5                       [4, 23680]                [4, 256]                  6,062,336
# ├─Xception: 1-2                               [4, 3, 224, 224]          [4, 256]                  --
# │    └─Conv2d: 2-3                            [4, 3, 224, 224]          [4, 32, 111, 111]         864
# │    └─BatchNorm2d: 2-4                       [4, 32, 111, 111]         [4, 32, 111, 111]         64
# │    └─ReLU: 2-5                              [4, 32, 111, 111]         [4, 32, 111, 111]         --
# │    └─Conv2d: 2-6                            [4, 32, 111, 111]         [4, 64, 109, 109]         18,432
# │    └─BatchNorm2d: 2-7                       [4, 64, 109, 109]         [4, 64, 109, 109]         128
# │    └─ReLU: 2-8                              [4, 64, 109, 109]         [4, 64, 109, 109]         --
# │    └─Block: 2-9                             [4, 64, 109, 109]         [4, 128, 55, 55]          --
# │    │    └─Sequential: 3-6                   [4, 64, 109, 109]         [4, 128, 55, 55]          26,816
# │    │    └─Conv2d: 3-7                       [4, 64, 109, 109]         [4, 128, 55, 55]          8,192
# │    │    └─BatchNorm2d: 3-8                  [4, 128, 55, 55]          [4, 128, 55, 55]          256
# │    └─Block: 2-10                            [4, 128, 55, 55]          [4, 256, 28, 28]          --
# │    │    └─Sequential: 3-9                   [4, 128, 55, 55]          [4, 256, 28, 28]          102,784
# │    │    └─Conv2d: 3-10                      [4, 128, 55, 55]          [4, 256, 28, 28]          32,768
# │    │    └─BatchNorm2d: 3-11                 [4, 256, 28, 28]          [4, 256, 28, 28]          512
# │    └─Block: 2-11                            [4, 256, 28, 28]          [4, 728, 14, 14]          --
# │    │    └─Sequential: 3-12                  [4, 256, 28, 28]          [4, 728, 14, 14]          728,120
# │    │    └─Conv2d: 3-13                      [4, 256, 28, 28]          [4, 728, 14, 14]          186,368
# │    │    └─BatchNorm2d: 3-14                 [4, 728, 14, 14]          [4, 728, 14, 14]          1,456
# │    └─Block: 2-12                            [4, 728, 14, 14]          [4, 728, 14, 14]          --
# │    │    └─Sequential: 3-15                  [4, 728, 14, 14]          [4, 728, 14, 14]          1,613,976
# │    └─Block: 2-13                            [4, 728, 14, 14]          [4, 728, 14, 14]          --
# │    │    └─Sequential: 3-16                  [4, 728, 14, 14]          [4, 728, 14, 14]          1,613,976
# │    └─Block: 2-14                            [4, 728, 14, 14]          [4, 728, 14, 14]          --
# │    │    └─Sequential: 3-17                  [4, 728, 14, 14]          [4, 728, 14, 14]          1,613,976
# │    └─Block: 2-15                            [4, 728, 14, 14]          [4, 728, 14, 14]          --
# │    │    └─Sequential: 3-18                  [4, 728, 14, 14]          [4, 728, 14, 14]          1,613,976
# │    └─Block: 2-16                            [4, 728, 14, 14]          [4, 728, 14, 14]          --
# │    │    └─Sequential: 3-19                  [4, 728, 14, 14]          [4, 728, 14, 14]          1,613,976
# │    └─Block: 2-17                            [4, 728, 14, 14]          [4, 728, 14, 14]          --
# │    │    └─Sequential: 3-20                  [4, 728, 14, 14]          [4, 728, 14, 14]          1,613,976
# │    └─Block: 2-18                            [4, 728, 14, 14]          [4, 728, 14, 14]          --
# │    │    └─Sequential: 3-21                  [4, 728, 14, 14]          [4, 728, 14, 14]          1,613,976
# │    └─Block: 2-19                            [4, 728, 14, 14]          [4, 728, 14, 14]          --
# │    │    └─Sequential: 3-22                  [4, 728, 14, 14]          [4, 728, 14, 14]          1,613,976
# │    └─Block: 2-20                            [4, 728, 14, 14]          [4, 1024, 7, 7]           --
# │    │    └─Sequential: 3-23                  [4, 728, 14, 14]          [4, 1024, 7, 7]           1,292,064
# │    │    └─Conv2d: 3-24                      [4, 728, 14, 14]          [4, 1024, 7, 7]           745,472
# │    │    └─BatchNorm2d: 3-25                 [4, 1024, 7, 7]           [4, 1024, 7, 7]           2,048
# │    └─SeparableConv2d: 2-21                  [4, 1024, 7, 7]           [4, 1536, 7, 7]           --
# │    │    └─Conv2d: 3-26                      [4, 1024, 7, 7]           [4, 1024, 7, 7]           9,216
# │    │    └─Conv2d: 3-27                      [4, 1024, 7, 7]           [4, 1536, 7, 7]           1,572,864
# │    └─BatchNorm2d: 2-22                      [4, 1536, 7, 7]           [4, 1536, 7, 7]           3,072
# │    └─ReLU: 2-23                             [4, 1536, 7, 7]           [4, 1536, 7, 7]           --
# │    └─SeparableConv2d: 2-24                  [4, 1536, 7, 7]           [4, 2048, 7, 7]           --
# │    │    └─Conv2d: 3-28                      [4, 1536, 7, 7]           [4, 1536, 7, 7]           13,824
# │    │    └─Conv2d: 3-29                      [4, 1536, 7, 7]           [4, 2048, 7, 7]           3,145,728
# │    └─BatchNorm2d: 2-25                      [4, 2048, 7, 7]           [4, 2048, 7, 7]           4,096
# │    └─ReLU: 2-26                             [4, 2048, 7, 7]           [4, 2048, 7, 7]           --
# │    └─Linear: 2-27                           [4, 2048]                 [4, 256]                  524,544
# ├─early_fusion: 1-3                           [4, 256]                  [4, 256]                  --
# │    └─Linear: 2-28                           [50176]                   [256]                     12,845,312
# │    └─Linear: 2-29                           [50176]                   [256]                     (recursive)
# │    └─Linear: 2-30                           [50176]                   [256]                     (recursive)
# │    └─Linear: 2-31                           [50176]                   [256]                     (recursive)
# ├─Linear: 1-4                                 [4, 512]                  [4, 256]                  131,328
# ├─Linear: 1-5                                 [4, 512]                  [4, 5]                    2,565
# ========================================================================================================================
# Total params: 40,407,484
# Trainable params: 40,407,484
# Non-trainable params: 0
# Total mult-adds (G): 31.44
# ========================================================================================================================
# Input size (MB): 2.77
# Forward/backward pass size (MB): 1006.45
# Params size (MB): 161.63
# Estimated Total Size (MB): 1170.85
# ========================================================================================================================

# %%
def extract_ocean(data,batch_size):
    o=[]
    c=[]
    e=[]
    a=[]
    n=[]
    if batch_size >1:
        for i in range(batch_size):
            o.append(data[i][0].item())
            c.append(data[i][1].item())
            e.append(data[i][2].item())
            a.append(data[i][3].item())
            n.append(data[i][4].item())
        o = torch.tensor(o) 
        c = torch.tensor(c) 
        e = torch.tensor(e) 
        a = torch.tensor(a) 
        n = torch.tensor(n) 
    elif batch_size == 1:
        data=data.squeeze()
        for i in range(batch_size):
            o.append(data[0].item())
            c.append(data[1].item())
            e.append(data[2].item())
            a.append(data[3].item())
            n.append(data[4].item())
            
        o = torch.tensor(o) 
        c = torch.tensor(c) 
        e = torch.tensor(e) 
        a = torch.tensor(a) 
        n = torch.tensor(n)
    return o,c,e,a,n

# %%
def imagecrop(imagedata,batchsz):
    # convert_tensor= transforms.ToTensor()
    output=[]
    imagedata=imagedata.permute(0,2,1,3,4)
    for j in range(batchsz):#비디오 데이터 batchsz(9) 개 있다
        firstoutput=[]
        for i in range(len(imagedata[j])):#imagedata에 15개의 프레임이 있다
            # temp = convert_tensor(imagedata[i])
            #이미지를 나누
            temp = imagedata[j][i].unfold(1,2,2).unfold(2,2,2)
            temp = rearrange(temp, 'c h1 w1 h w -> (h1 w1) c h w')
            firstoutput.append(temp)
        firstoutput = torch.stack(firstoutput,0)
        output.append(firstoutput)
    output = torch.stack(output,0)
    return output

# %%
torch.autograd.set_detect_anomaly(True)
with torch.cuda.device(0):
    max_value = float('inf')
    for i in range(start_epoch, epochs):
        train_avg_loss = 0
        val_avg_loss = 0
        train_avg_o_loss = 0
        train_avg_c_loss = 0
        train_avg_e_loss = 0
        train_avg_a_loss = 0
        train_avg_n_loss = 0
        val_avg_o_loss = 0
        val_avg_c_loss = 0
        val_avg_e_loss = 0
        val_avg_a_loss = 0
        val_avg_n_loss = 0
        for fullshot,keypoint,big_five_data in tqdm(train_dataloader):
            middle_frame = fullshot[:, 7, :, :, :]
            middle_frame = middle_frame.permute(0,3,1,2)#batch,chan,h,w
            big_five_data=big_five_data.permute(0,2,1)
            big_five_data=big_five_data.squeeze()
            # fullshot=imagecrop(fullshot,batchsz)
            middle_frame = middle_frame.to(device)
            big_five_data = big_five_data.to(device)
            
            optimizer.zero_grad()  # 기울기가 0이 됩니다.
            hypothesis = model(middle_frame,keypoint) # 모델의 예측 결과를 저장합니다.
            
            loss = criterion(hypothesis, big_five_data)  # 예측된 결과와 실제 태그 사이의 손실 값을 저장합니다.
            loss.backward()  # 역방향 전파입니다. 
            optimizer.step()  
            train_avg_loss += loss  
        train_avg_loss=train_avg_loss/len(train_dataloader)
        with torch.no_grad():#validate
            for fullshot,keypoint,big_five_data in tqdm(val_dataloader):
                middle_frame = fullshot[:, 7, :, :, :]
                #4,15,501,3   ------     batch,frame,key,ch
                # fullshot=imagecrop(fullshot,batchsz)
                middle_frame = middle_frame.permute(0,3,1,2)
                big_five_data=big_five_data.permute(0,2,1)
                big_five_data=big_five_data.squeeze()
                middle_frame = middle_frame.to(device)
                big_five_data = big_five_data.to(device)
                hypothesis = model(middle_frame,keypoint)
                val_loss = criterion(hypothesis, big_five_data)
                
                hypothesiso,hypothesisc,hypothesise,hypothesisa,hypothesisn=extract_ocean(hypothesis,len(keypoint))
                big_five_datao,big_five_datac,big_five_datae,big_five_dataa,big_five_datan=extract_ocean(big_five_data,len(keypoint))
                val_o_loss = criterion(hypothesiso, big_five_datao) 
                val_c_loss = criterion(hypothesisc, big_five_datac) 
                val_e_loss = criterion(hypothesise, big_five_datae) 
                val_a_loss = criterion(hypothesisa, big_five_dataa) 
                val_n_loss = criterion(hypothesisn, big_five_datan)  
                val_avg_loss += val_loss
                val_avg_o_loss += val_o_loss
                val_avg_c_loss += val_c_loss
                val_avg_e_loss += val_e_loss
                val_avg_a_loss += val_a_loss
                val_avg_n_loss += val_n_loss
            val_avg_loss=val_avg_loss/len(val_dataloader)
            val_avg_o_loss=val_avg_o_loss/len(val_dataloader)
            val_avg_c_loss=val_avg_c_loss/len(val_dataloader)
            val_avg_e_loss=val_avg_e_loss/len(val_dataloader)
            val_avg_a_loss=val_avg_a_loss/len(val_dataloader)
            val_avg_n_loss=val_avg_n_loss/len(val_dataloader)
        torch.cuda.empty_cache()
        # if (1-val_avg_loss)>=(1-max_value):
        start_epoch+=1
        if val_avg_loss < max_value:
            max_value=val_avg_loss
            torch.save({
                'epoch': i+1,
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'loss': val_avg_loss,
            }, save_model_file_path.format('model',start_epoch,'pth'))
        logger.debug('Epoch: {} , 1-MAE: {:.4f} , 1-Training Loss: {:.4f} , 1-val_avg_o_loss:{:.4f} , 1-val_avg_c_loss:{:.4f} , 1-val_avg_e_loss:{:.4f} , 1-val_avg_a_loss:{:.4f} , 1-val_avg_n_loss:{:.4f}'.format(i+1, 1-val_avg_loss, 1-train_avg_loss,1-val_avg_o_loss, 1-val_avg_c_loss, 1-val_avg_e_loss, 1-val_avg_a_loss,1-val_avg_n_loss))
# Out:
# 100%|██████████| 830/830 [04:14<00:00,  3.26it/s]
# 100%|█████████▉| 279/280 [00:52<00:00,  5.78it/s]/home/ssrlab/ENTER/envs/qx/lib/python3.10/site-packages/torch/nn/modules/loss.py:101: UserWarning: Using a target size (torch.Size([5])) that is different to the input size (torch.Size([1, 5])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# 100%|██████████| 280/280 [00:53<00:00,  5.22it/s]
# [2024-10-14 15:38:51,538]::3947538980::DEBUG::Epoch: 1 , 1-MAE: 0.7705 , 1-Training Loss: 0.7793 , 1-val_avg_o_loss:0.8198 , 1-val_avg_c_loss:0.7439 , 1-val_avg_e_loss:0.7594 , 1-val_avg_a_loss:0.7221 , 1-val_avg_n_loss:0.8072
# 100%|██████████| 830/830 [04:17<00:00,  3.22it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.36it/s]
# [2024-10-14 15:44:02,224]::3947538980::DEBUG::Epoch: 2 , 1-MAE: 0.7851 , 1-Training Loss: 0.7877 , 1-val_avg_o_loss:0.7878 , 1-val_avg_c_loss:0.7980 , 1-val_avg_e_loss:0.7644 , 1-val_avg_a_loss:0.7669 , 1-val_avg_n_loss:0.8083
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 15:49:16,754]::3947538980::DEBUG::Epoch: 3 , 1-MAE: 0.8056 , 1-Training Loss: 0.8081 , 1-val_avg_o_loss:0.8218 , 1-val_avg_c_loss:0.8392 , 1-val_avg_e_loss:0.8366 , 1-val_avg_a_loss:0.7296 , 1-val_avg_n_loss:0.8011
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.33it/s]
# [2024-10-14 15:54:32,073]::3947538980::DEBUG::Epoch: 4 , 1-MAE: 0.8198 , 1-Training Loss: 0.8320 , 1-val_avg_o_loss:0.8392 , 1-val_avg_c_loss:0.8533 , 1-val_avg_e_loss:0.7274 , 1-val_avg_a_loss:0.8591 , 1-val_avg_n_loss:0.8201
# 100%|██████████| 830/830 [04:17<00:00,  3.22it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 15:59:44,206]::3947538980::DEBUG::Epoch: 5 , 1-MAE: 0.8625 , 1-Training Loss: 0.8520 , 1-val_avg_o_loss:0.8570 , 1-val_avg_c_loss:0.8667 , 1-val_avg_e_loss:0.8643 , 1-val_avg_a_loss:0.8471 , 1-val_avg_n_loss:0.8776
# 100%|██████████| 830/830 [04:20<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 16:04:59,189]::3947538980::DEBUG::Epoch: 6 , 1-MAE: 0.8697 , 1-Training Loss: 0.8740 , 1-val_avg_o_loss:0.8532 , 1-val_avg_c_loss:0.8547 , 1-val_avg_e_loss:0.8764 , 1-val_avg_a_loss:0.8836 , 1-val_avg_n_loss:0.8804
# 100%|██████████| 830/830 [04:17<00:00,  3.22it/s]
# 100%|██████████| 280/280 [00:51<00:00,  5.39it/s]
# [2024-10-14 16:10:09,808]::3947538980::DEBUG::Epoch: 7 , 1-MAE: 0.8826 , 1-Training Loss: 0.8912 , 1-val_avg_o_loss:0.8740 , 1-val_avg_c_loss:0.8741 , 1-val_avg_e_loss:0.8910 , 1-val_avg_a_loss:0.8813 , 1-val_avg_n_loss:0.8925
# 100%|██████████| 830/830 [04:22<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.32it/s]
# [2024-10-14 16:15:25,509]::3947538980::DEBUG::Epoch: 8 , 1-MAE: 0.8946 , 1-Training Loss: 0.9021 , 1-val_avg_o_loss:0.9000 , 1-val_avg_c_loss:0.8912 , 1-val_avg_e_loss:0.8996 , 1-val_avg_a_loss:0.8910 , 1-val_avg_n_loss:0.8914
# 100%|██████████| 830/830 [04:19<00:00,  3.20it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 16:20:38,738]::3947538980::DEBUG::Epoch: 9 , 1-MAE: 0.8905 , 1-Training Loss: 0.9131 , 1-val_avg_o_loss:0.8977 , 1-val_avg_c_loss:0.8931 , 1-val_avg_e_loss:0.8666 , 1-val_avg_a_loss:0.8964 , 1-val_avg_n_loss:0.8987
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.28it/s]
# [2024-10-14 16:25:54,116]::3947538980::DEBUG::Epoch: 10 , 1-MAE: 0.8909 , 1-Training Loss: 0.9189 , 1-val_avg_o_loss:0.8834 , 1-val_avg_c_loss:0.8925 , 1-val_avg_e_loss:0.9048 , 1-val_avg_a_loss:0.9022 , 1-val_avg_n_loss:0.8713
# 100%|██████████| 830/830 [04:20<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.23it/s]
# [2024-10-14 16:31:09,614]::3947538980::DEBUG::Epoch: 11 , 1-MAE: 0.8999 , 1-Training Loss: 0.9239 , 1-val_avg_o_loss:0.8891 , 1-val_avg_c_loss:0.8975 , 1-val_avg_e_loss:0.9052 , 1-val_avg_a_loss:0.9057 , 1-val_avg_n_loss:0.9020
# 100%|██████████| 830/830 [04:16<00:00,  3.23it/s]
# 100%|██████████| 280/280 [00:54<00:00,  5.16it/s]
# [2024-10-14 16:36:21,482]::3947538980::DEBUG::Epoch: 12 , 1-MAE: 0.9036 , 1-Training Loss: 0.9291 , 1-val_avg_o_loss:0.9020 , 1-val_avg_c_loss:0.8998 , 1-val_avg_e_loss:0.9080 , 1-val_avg_a_loss:0.9055 , 1-val_avg_n_loss:0.9025
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.37it/s]
# [2024-10-14 16:41:34,823]::3947538980::DEBUG::Epoch: 13 , 1-MAE: 0.9029 , 1-Training Loss: 0.9342 , 1-val_avg_o_loss:0.9042 , 1-val_avg_c_loss:0.8952 , 1-val_avg_e_loss:0.9066 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.8999
# 100%|██████████| 830/830 [04:20<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.31it/s]
# [2024-10-14 16:46:49,196]::3947538980::DEBUG::Epoch: 14 , 1-MAE: 0.9045 , 1-Training Loss: 0.9371 , 1-val_avg_o_loss:0.9035 , 1-val_avg_c_loss:0.8973 , 1-val_avg_e_loss:0.9071 , 1-val_avg_a_loss:0.9082 , 1-val_avg_n_loss:0.9065
# 100%|██████████| 830/830 [04:25<00:00,  3.12it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 16:52:08,877]::3947538980::DEBUG::Epoch: 15 , 1-MAE: 0.9054 , 1-Training Loss: 0.9400 , 1-val_avg_o_loss:0.9019 , 1-val_avg_c_loss:0.9038 , 1-val_avg_e_loss:0.9096 , 1-val_avg_a_loss:0.9071 , 1-val_avg_n_loss:0.9045
# 100%|██████████| 830/830 [04:19<00:00,  3.20it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.28it/s]
# [2024-10-14 16:57:22,188]::3947538980::DEBUG::Epoch: 16 , 1-MAE: 0.9077 , 1-Training Loss: 0.9436 , 1-val_avg_o_loss:0.9060 , 1-val_avg_c_loss:0.9045 , 1-val_avg_e_loss:0.9099 , 1-val_avg_a_loss:0.9114 , 1-val_avg_n_loss:0.9067
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.28it/s]
# [2024-10-14 17:02:38,597]::3947538980::DEBUG::Epoch: 17 , 1-MAE: 0.9055 , 1-Training Loss: 0.9447 , 1-val_avg_o_loss:0.9063 , 1-val_avg_c_loss:0.9058 , 1-val_avg_e_loss:0.9020 , 1-val_avg_a_loss:0.9075 , 1-val_avg_n_loss:0.9057
# 100%|██████████| 830/830 [04:15<00:00,  3.25it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 17:07:47,841]::3947538980::DEBUG::Epoch: 18 , 1-MAE: 0.9053 , 1-Training Loss: 0.9485 , 1-val_avg_o_loss:0.9038 , 1-val_avg_c_loss:0.9031 , 1-val_avg_e_loss:0.9065 , 1-val_avg_a_loss:0.9061 , 1-val_avg_n_loss:0.9070
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 17:13:02,208]::3947538980::DEBUG::Epoch: 19 , 1-MAE: 0.9049 , 1-Training Loss: 0.9498 , 1-val_avg_o_loss:0.9026 , 1-val_avg_c_loss:0.9031 , 1-val_avg_e_loss:0.9076 , 1-val_avg_a_loss:0.9098 , 1-val_avg_n_loss:0.9013
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.37it/s]
# [2024-10-14 17:18:15,428]::3947538980::DEBUG::Epoch: 20 , 1-MAE: 0.9022 , 1-Training Loss: 0.9517 , 1-val_avg_o_loss:0.9011 , 1-val_avg_c_loss:0.9036 , 1-val_avg_e_loss:0.8931 , 1-val_avg_a_loss:0.9096 , 1-val_avg_n_loss:0.9033
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 17:23:32,576]::3947538980::DEBUG::Epoch: 21 , 1-MAE: 0.9065 , 1-Training Loss: 0.9540 , 1-val_avg_o_loss:0.9059 , 1-val_avg_c_loss:0.9010 , 1-val_avg_e_loss:0.9092 , 1-val_avg_a_loss:0.9114 , 1-val_avg_n_loss:0.9051
# 100%|██████████| 830/830 [04:21<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.28it/s]
# [2024-10-14 17:28:47,210]::3947538980::DEBUG::Epoch: 22 , 1-MAE: 0.9058 , 1-Training Loss: 0.9553 , 1-val_avg_o_loss:0.9044 , 1-val_avg_c_loss:0.9012 , 1-val_avg_e_loss:0.9053 , 1-val_avg_a_loss:0.9103 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 17:34:04,105]::3947538980::DEBUG::Epoch: 23 , 1-MAE: 0.9067 , 1-Training Loss: 0.9573 , 1-val_avg_o_loss:0.9027 , 1-val_avg_c_loss:0.9038 , 1-val_avg_e_loss:0.9118 , 1-val_avg_a_loss:0.9121 , 1-val_avg_n_loss:0.9033
# 100%|██████████| 830/830 [04:19<00:00,  3.20it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.34it/s]
# [2024-10-14 17:39:16,278]::3947538980::DEBUG::Epoch: 24 , 1-MAE: 0.9074 , 1-Training Loss: 0.9581 , 1-val_avg_o_loss:0.9063 , 1-val_avg_c_loss:0.9049 , 1-val_avg_e_loss:0.9108 , 1-val_avg_a_loss:0.9098 , 1-val_avg_n_loss:0.9052
# 100%|██████████| 830/830 [04:22<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:51<00:00,  5.39it/s]
# [2024-10-14 17:44:30,980]::3947538980::DEBUG::Epoch: 25 , 1-MAE: 0.9068 , 1-Training Loss: 0.9605 , 1-val_avg_o_loss:0.8996 , 1-val_avg_c_loss:0.9056 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9122 , 1-val_avg_n_loss:0.9057
# 100%|██████████| 830/830 [04:24<00:00,  3.13it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.28it/s]
# [2024-10-14 17:49:49,571]::3947538980::DEBUG::Epoch: 26 , 1-MAE: 0.9064 , 1-Training Loss: 0.9613 , 1-val_avg_o_loss:0.9055 , 1-val_avg_c_loss:0.9032 , 1-val_avg_e_loss:0.9073 , 1-val_avg_a_loss:0.9100 , 1-val_avg_n_loss:0.9060
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.30it/s]
# [2024-10-14 17:55:05,362]::3947538980::DEBUG::Epoch: 27 , 1-MAE: 0.9090 , 1-Training Loss: 0.9628 , 1-val_avg_o_loss:0.9066 , 1-val_avg_c_loss:0.9056 , 1-val_avg_e_loss:0.9120 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.20it/s]
# [2024-10-14 18:00:22,188]::3947538980::DEBUG::Epoch: 28 , 1-MAE: 0.9083 , 1-Training Loss: 0.9637 , 1-val_avg_o_loss:0.9061 , 1-val_avg_c_loss:0.9049 , 1-val_avg_e_loss:0.9098 , 1-val_avg_a_loss:0.9135 , 1-val_avg_n_loss:0.9072
# 100%|██████████| 830/830 [04:21<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.33it/s]
# [2024-10-14 18:05:36,381]::3947538980::DEBUG::Epoch: 29 , 1-MAE: 0.9077 , 1-Training Loss: 0.9646 , 1-val_avg_o_loss:0.9033 , 1-val_avg_c_loss:0.9051 , 1-val_avg_e_loss:0.9093 , 1-val_avg_a_loss:0.9129 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 18:10:52,847]::3947538980::DEBUG::Epoch: 30 , 1-MAE: 0.9064 , 1-Training Loss: 0.9653 , 1-val_avg_o_loss:0.9072 , 1-val_avg_c_loss:0.8954 , 1-val_avg_e_loss:0.9118 , 1-val_avg_a_loss:0.9137 , 1-val_avg_n_loss:0.9039
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.32it/s]
# [2024-10-14 18:16:07,810]::3947538980::DEBUG::Epoch: 31 , 1-MAE: 0.9081 , 1-Training Loss: 0.9660 , 1-val_avg_o_loss:0.9082 , 1-val_avg_c_loss:0.9056 , 1-val_avg_e_loss:0.9094 , 1-val_avg_a_loss:0.9111 , 1-val_avg_n_loss:0.9063
# 100%|██████████| 830/830 [04:21<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 18:21:22,971]::3947538980::DEBUG::Epoch: 32 , 1-MAE: 0.9089 , 1-Training Loss: 0.9668 , 1-val_avg_o_loss:0.9076 , 1-val_avg_c_loss:0.9045 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.9134 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.36it/s]
# [2024-10-14 18:26:36,329]::3947538980::DEBUG::Epoch: 33 , 1-MAE: 0.9077 , 1-Training Loss: 0.9680 , 1-val_avg_o_loss:0.9055 , 1-val_avg_c_loss:0.9036 , 1-val_avg_e_loss:0.9101 , 1-val_avg_a_loss:0.9129 , 1-val_avg_n_loss:0.9061
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.33it/s]
# [2024-10-14 18:31:49,808]::3947538980::DEBUG::Epoch: 34 , 1-MAE: 0.9087 , 1-Training Loss: 0.9687 , 1-val_avg_o_loss:0.9068 , 1-val_avg_c_loss:0.9070 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9123 , 1-val_avg_n_loss:0.9066
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.28it/s]
# [2024-10-14 18:37:06,181]::3947538980::DEBUG::Epoch: 35 , 1-MAE: 0.9089 , 1-Training Loss: 0.9688 , 1-val_avg_o_loss:0.9053 , 1-val_avg_c_loss:0.9048 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9145 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 830/830 [04:22<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.27it/s]
# [2024-10-14 18:42:22,032]::3947538980::DEBUG::Epoch: 36 , 1-MAE: 0.9078 , 1-Training Loss: 0.9698 , 1-val_avg_o_loss:0.9053 , 1-val_avg_c_loss:0.9050 , 1-val_avg_e_loss:0.9100 , 1-val_avg_a_loss:0.9120 , 1-val_avg_n_loss:0.9069
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.28it/s]
# [2024-10-14 18:47:35,798]::3947538980::DEBUG::Epoch: 37 , 1-MAE: 0.9081 , 1-Training Loss: 0.9702 , 1-val_avg_o_loss:0.9073 , 1-val_avg_c_loss:0.9039 , 1-val_avg_e_loss:0.9105 , 1-val_avg_a_loss:0.9131 , 1-val_avg_n_loss:0.9058
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.21it/s]
# [2024-10-14 18:52:50,469]::3947538980::DEBUG::Epoch: 38 , 1-MAE: 0.9081 , 1-Training Loss: 0.9708 , 1-val_avg_o_loss:0.9037 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9105 , 1-val_avg_a_loss:0.9135 , 1-val_avg_n_loss:0.9074
# 100%|██████████| 830/830 [04:19<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.30it/s]
# [2024-10-14 18:58:03,903]::3947538980::DEBUG::Epoch: 39 , 1-MAE: 0.9086 , 1-Training Loss: 0.9714 , 1-val_avg_o_loss:0.9064 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9103 , 1-val_avg_a_loss:0.9123 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 19:03:18,376]::3947538980::DEBUG::Epoch: 40 , 1-MAE: 0.9096 , 1-Training Loss: 0.9715 , 1-val_avg_o_loss:0.9061 , 1-val_avg_c_loss:0.9067 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9144 , 1-val_avg_n_loss:0.9083
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.23it/s]
# [2024-10-14 19:08:36,405]::3947538980::DEBUG::Epoch: 41 , 1-MAE: 0.9094 , 1-Training Loss: 0.9725 , 1-val_avg_o_loss:0.9080 , 1-val_avg_c_loss:0.9043 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9131 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.25it/s]
# [2024-10-14 19:13:53,794]::3947538980::DEBUG::Epoch: 42 , 1-MAE: 0.9094 , 1-Training Loss: 0.9726 , 1-val_avg_o_loss:0.9070 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9114 , 1-val_avg_a_loss:0.9138 , 1-val_avg_n_loss:0.9083
# 100%|██████████| 830/830 [04:17<00:00,  3.22it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 19:19:05,216]::3947538980::DEBUG::Epoch: 43 , 1-MAE: 0.9089 , 1-Training Loss: 0.9732 , 1-val_avg_o_loss:0.9066 , 1-val_avg_c_loss:0.9071 , 1-val_avg_e_loss:0.9095 , 1-val_avg_a_loss:0.9137 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 830/830 [04:15<00:00,  3.25it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.34it/s]
# [2024-10-14 19:24:13,683]::3947538980::DEBUG::Epoch: 44 , 1-MAE: 0.9088 , 1-Training Loss: 0.9733 , 1-val_avg_o_loss:0.9061 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9116 , 1-val_avg_a_loss:0.9134 , 1-val_avg_n_loss:0.9075
# 100%|██████████| 830/830 [04:19<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.28it/s]
# [2024-10-14 19:29:27,311]::3947538980::DEBUG::Epoch: 45 , 1-MAE: 0.9095 , 1-Training Loss: 0.9740 , 1-val_avg_o_loss:0.9066 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9156 , 1-val_avg_n_loss:0.9073
# 100%|██████████| 830/830 [04:25<00:00,  3.13it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.30it/s]
# [2024-10-14 19:34:45,760]::3947538980::DEBUG::Epoch: 46 , 1-MAE: 0.9092 , 1-Training Loss: 0.9741 , 1-val_avg_o_loss:0.9069 , 1-val_avg_c_loss:0.9047 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9151 , 1-val_avg_n_loss:0.9067
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.31it/s]
# [2024-10-14 19:40:01,910]::3947538980::DEBUG::Epoch: 47 , 1-MAE: 0.9101 , 1-Training Loss: 0.9745 , 1-val_avg_o_loss:0.9082 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9144 , 1-val_avg_n_loss:0.9091
# 100%|██████████| 830/830 [04:19<00:00,  3.20it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.37it/s]
# [2024-10-14 19:45:14,160]::3947538980::DEBUG::Epoch: 48 , 1-MAE: 0.9077 , 1-Training Loss: 0.9748 , 1-val_avg_o_loss:0.9052 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9091 , 1-val_avg_n_loss:0.9042
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 19:50:29,480]::3947538980::DEBUG::Epoch: 49 , 1-MAE: 0.9091 , 1-Training Loss: 0.9750 , 1-val_avg_o_loss:0.9068 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9116 , 1-val_avg_a_loss:0.9133 , 1-val_avg_n_loss:0.9073
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.31it/s]
# [2024-10-14 19:55:45,571]::3947538980::DEBUG::Epoch: 50 , 1-MAE: 0.9096 , 1-Training Loss: 0.9752 , 1-val_avg_o_loss:0.9071 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9067
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.27it/s]
# [2024-10-14 20:01:01,261]::3947538980::DEBUG::Epoch: 51 , 1-MAE: 0.9095 , 1-Training Loss: 0.9754 , 1-val_avg_o_loss:0.9073 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9149 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 830/830 [04:19<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.27it/s]
# [2024-10-14 20:06:14,865]::3947538980::DEBUG::Epoch: 52 , 1-MAE: 0.9096 , 1-Training Loss: 0.9762 , 1-val_avg_o_loss:0.9080 , 1-val_avg_c_loss:0.9055 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9145 , 1-val_avg_n_loss:0.9073
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.31it/s]
# [2024-10-14 20:11:31,494]::3947538980::DEBUG::Epoch: 53 , 1-MAE: 0.9099 , 1-Training Loss: 0.9760 , 1-val_avg_o_loss:0.9077 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9142 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.20it/s]
# [2024-10-14 20:16:47,562]::3947538980::DEBUG::Epoch: 54 , 1-MAE: 0.9097 , 1-Training Loss: 0.9765 , 1-val_avg_o_loss:0.9081 , 1-val_avg_c_loss:0.9069 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9121 , 1-val_avg_n_loss:0.9088
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 20:22:02,648]::3947538980::DEBUG::Epoch: 55 , 1-MAE: 0.9094 , 1-Training Loss: 0.9767 , 1-val_avg_o_loss:0.9076 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9145 , 1-val_avg_n_loss:0.9054
# 100%|██████████| 830/830 [04:22<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.32it/s]
# [2024-10-14 20:27:18,076]::3947538980::DEBUG::Epoch: 56 , 1-MAE: 0.9098 , 1-Training Loss: 0.9770 , 1-val_avg_o_loss:0.9083 , 1-val_avg_c_loss:0.9056 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9150 , 1-val_avg_n_loss:0.9074
# 100%|██████████| 830/830 [04:21<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.27it/s]
# [2024-10-14 20:32:33,634]::3947538980::DEBUG::Epoch: 57 , 1-MAE: 0.9103 , 1-Training Loss: 0.9773 , 1-val_avg_o_loss:0.9082 , 1-val_avg_c_loss:0.9067 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9140 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 830/830 [04:22<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 20:37:49,756]::3947538980::DEBUG::Epoch: 58 , 1-MAE: 0.9088 , 1-Training Loss: 0.9771 , 1-val_avg_o_loss:0.9073 , 1-val_avg_c_loss:0.9067 , 1-val_avg_e_loss:0.9092 , 1-val_avg_a_loss:0.9144 , 1-val_avg_n_loss:0.9063
# 100%|██████████| 830/830 [04:22<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.34it/s]
# [2024-10-14 20:43:05,032]::3947538980::DEBUG::Epoch: 59 , 1-MAE: 0.9097 , 1-Training Loss: 0.9776 , 1-val_avg_o_loss:0.9080 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9142 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 830/830 [04:22<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.35it/s]
# [2024-10-14 20:48:20,190]::3947538980::DEBUG::Epoch: 60 , 1-MAE: 0.9097 , 1-Training Loss: 0.9781 , 1-val_avg_o_loss:0.9067 , 1-val_avg_c_loss:0.9058 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9162 , 1-val_avg_n_loss:0.9067
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.24it/s]
# [2024-10-14 20:53:35,107]::3947538980::DEBUG::Epoch: 61 , 1-MAE: 0.9104 , 1-Training Loss: 0.9781 , 1-val_avg_o_loss:0.9082 , 1-val_avg_c_loss:0.9067 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9153 , 1-val_avg_n_loss:0.9089
# 100%|██████████| 830/830 [04:25<00:00,  3.12it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 20:58:54,946]::3947538980::DEBUG::Epoch: 62 , 1-MAE: 0.9093 , 1-Training Loss: 0.9783 , 1-val_avg_o_loss:0.9068 , 1-val_avg_c_loss:0.9052 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9147 , 1-val_avg_n_loss:0.9071
# 100%|██████████| 830/830 [04:19<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.33it/s]
# [2024-10-14 21:04:08,076]::3947538980::DEBUG::Epoch: 63 , 1-MAE: 0.9099 , 1-Training Loss: 0.9789 , 1-val_avg_o_loss:0.9080 , 1-val_avg_c_loss:0.9075 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9137 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 830/830 [04:18<00:00,  3.21it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 21:09:20,587]::3947538980::DEBUG::Epoch: 64 , 1-MAE: 0.9088 , 1-Training Loss: 0.9791 , 1-val_avg_o_loss:0.9071 , 1-val_avg_c_loss:0.9058 , 1-val_avg_e_loss:0.9099 , 1-val_avg_a_loss:0.9136 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 21:14:37,902]::3947538980::DEBUG::Epoch: 65 , 1-MAE: 0.9097 , 1-Training Loss: 0.9787 , 1-val_avg_o_loss:0.9075 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9139 , 1-val_avg_a_loss:0.9147 , 1-val_avg_n_loss:0.9067
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.34it/s]
# [2024-10-14 21:19:51,528]::3947538980::DEBUG::Epoch: 66 , 1-MAE: 0.9093 , 1-Training Loss: 0.9794 , 1-val_avg_o_loss:0.9053 , 1-val_avg_c_loss:0.9052 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 830/830 [04:22<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.24it/s]
# [2024-10-14 21:25:07,844]::3947538980::DEBUG::Epoch: 67 , 1-MAE: 0.9098 , 1-Training Loss: 0.9793 , 1-val_avg_o_loss:0.9077 , 1-val_avg_c_loss:0.9059 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 830/830 [04:20<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.27it/s]
# [2024-10-14 21:30:22,367]::3947538980::DEBUG::Epoch: 68 , 1-MAE: 0.9099 , 1-Training Loss: 0.9795 , 1-val_avg_o_loss:0.9089 , 1-val_avg_c_loss:0.9068 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9147 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 21:35:36,289]::3947538980::DEBUG::Epoch: 69 , 1-MAE: 0.9103 , 1-Training Loss: 0.9796 , 1-val_avg_o_loss:0.9084 , 1-val_avg_c_loss:0.9070 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9149 , 1-val_avg_n_loss:0.9093
# 100%|██████████| 830/830 [04:25<00:00,  3.12it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.33it/s]
# [2024-10-14 21:40:55,214]::3947538980::DEBUG::Epoch: 70 , 1-MAE: 0.9099 , 1-Training Loss: 0.9798 , 1-val_avg_o_loss:0.9074 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9143 , 1-val_avg_a_loss:0.9147 , 1-val_avg_n_loss:0.9071
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.27it/s]
# [2024-10-14 21:46:10,442]::3947538980::DEBUG::Epoch: 71 , 1-MAE: 0.9090 , 1-Training Loss: 0.9801 , 1-val_avg_o_loss:0.9067 , 1-val_avg_c_loss:0.9044 , 1-val_avg_e_loss:0.9114 , 1-val_avg_a_loss:0.9153 , 1-val_avg_n_loss:0.9073
# 100%|██████████| 830/830 [04:20<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.35it/s]
# [2024-10-14 21:51:24,189]::3947538980::DEBUG::Epoch: 72 , 1-MAE: 0.9103 , 1-Training Loss: 0.9802 , 1-val_avg_o_loss:0.9083 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 830/830 [04:19<00:00,  3.20it/s]
# 100%|██████████| 280/280 [00:51<00:00,  5.39it/s]
# [2024-10-14 21:56:36,219]::3947538980::DEBUG::Epoch: 73 , 1-MAE: 0.9099 , 1-Training Loss: 0.9801 , 1-val_avg_o_loss:0.9076 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9150 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 830/830 [04:23<00:00,  3.14it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.37it/s]
# [2024-10-14 22:01:52,945]::3947538980::DEBUG::Epoch: 74 , 1-MAE: 0.9098 , 1-Training Loss: 0.9806 , 1-val_avg_o_loss:0.9071 , 1-val_avg_c_loss:0.9073 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.9164 , 1-val_avg_n_loss:0.9070
# 100%|██████████| 830/830 [04:21<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.32it/s]
# [2024-10-14 22:07:07,271]::3947538980::DEBUG::Epoch: 75 , 1-MAE: 0.9089 , 1-Training Loss: 0.9804 , 1-val_avg_o_loss:0.9067 , 1-val_avg_c_loss:0.9046 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9136 , 1-val_avg_n_loss:0.9067
# 100%|██████████| 830/830 [04:24<00:00,  3.14it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 22:12:25,377]::3947538980::DEBUG::Epoch: 76 , 1-MAE: 0.9097 , 1-Training Loss: 0.9802 , 1-val_avg_o_loss:0.9066 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9150 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.35it/s]
# [2024-10-14 22:17:38,822]::3947538980::DEBUG::Epoch: 77 , 1-MAE: 0.9095 , 1-Training Loss: 0.9808 , 1-val_avg_o_loss:0.9070 , 1-val_avg_c_loss:0.9068 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9135 , 1-val_avg_n_loss:0.9075
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 22:22:55,796]::3947538980::DEBUG::Epoch: 78 , 1-MAE: 0.9103 , 1-Training Loss: 0.9810 , 1-val_avg_o_loss:0.9078 , 1-val_avg_c_loss:0.9058 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9161 , 1-val_avg_n_loss:0.9094
# 100%|██████████| 830/830 [04:22<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 22:28:11,791]::3947538980::DEBUG::Epoch: 79 , 1-MAE: 0.9100 , 1-Training Loss: 0.9811 , 1-val_avg_o_loss:0.9073 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9072
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.22it/s]
# [2024-10-14 22:33:28,480]::3947538980::DEBUG::Epoch: 80 , 1-MAE: 0.9100 , 1-Training Loss: 0.9809 , 1-val_avg_o_loss:0.9087 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9120 , 1-val_avg_a_loss:0.9150 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.30it/s]
# [2024-10-14 22:38:44,834]::3947538980::DEBUG::Epoch: 81 , 1-MAE: 0.9086 , 1-Training Loss: 0.9812 , 1-val_avg_o_loss:0.9065 , 1-val_avg_c_loss:0.9068 , 1-val_avg_e_loss:0.9122 , 1-val_avg_a_loss:0.9099 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 830/830 [04:27<00:00,  3.11it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.27it/s]
# [2024-10-14 22:44:06,021]::3947538980::DEBUG::Epoch: 82 , 1-MAE: 0.9105 , 1-Training Loss: 0.9812 , 1-val_avg_o_loss:0.9082 , 1-val_avg_c_loss:0.9074 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9156 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 830/830 [04:21<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:54<00:00,  5.17it/s]
# [2024-10-14 22:49:22,037]::3947538980::DEBUG::Epoch: 83 , 1-MAE: 0.9101 , 1-Training Loss: 0.9816 , 1-val_avg_o_loss:0.9070 , 1-val_avg_c_loss:0.9070 , 1-val_avg_e_loss:0.9127 , 1-val_avg_a_loss:0.9148 , 1-val_avg_n_loss:0.9088
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 22:54:39,566]::3947538980::DEBUG::Epoch: 84 , 1-MAE: 0.9102 , 1-Training Loss: 0.9815 , 1-val_avg_o_loss:0.9078 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9164 , 1-val_avg_n_loss:0.9083
# 100%|██████████| 830/830 [04:19<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.31it/s]
# [2024-10-14 22:59:52,942]::3947538980::DEBUG::Epoch: 85 , 1-MAE: 0.9098 , 1-Training Loss: 0.9817 , 1-val_avg_o_loss:0.9074 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 830/830 [04:27<00:00,  3.10it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.34it/s]
# [2024-10-14 23:05:13,732]::3947538980::DEBUG::Epoch: 86 , 1-MAE: 0.9104 , 1-Training Loss: 0.9819 , 1-val_avg_o_loss:0.9085 , 1-val_avg_c_loss:0.9069 , 1-val_avg_e_loss:0.9122 , 1-val_avg_a_loss:0.9151 , 1-val_avg_n_loss:0.9091
# 100%|██████████| 830/830 [04:24<00:00,  3.13it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 23:10:32,509]::3947538980::DEBUG::Epoch: 87 , 1-MAE: 0.9109 , 1-Training Loss: 0.9820 , 1-val_avg_o_loss:0.9085 , 1-val_avg_c_loss:0.9071 , 1-val_avg_e_loss:0.9145 , 1-val_avg_a_loss:0.9166 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 830/830 [04:18<00:00,  3.21it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.34it/s]
# [2024-10-14 23:15:44,163]::3947538980::DEBUG::Epoch: 88 , 1-MAE: 0.9097 , 1-Training Loss: 0.9822 , 1-val_avg_o_loss:0.9077 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9146 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.25it/s]
# [2024-10-14 23:21:00,085]::3947538980::DEBUG::Epoch: 89 , 1-MAE: 0.9103 , 1-Training Loss: 0.9821 , 1-val_avg_o_loss:0.9087 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9156 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.21it/s]
# [2024-10-14 23:26:17,201]::3947538980::DEBUG::Epoch: 90 , 1-MAE: 0.9111 , 1-Training Loss: 0.9823 , 1-val_avg_o_loss:0.9095 , 1-val_avg_c_loss:0.9076 , 1-val_avg_e_loss:0.9145 , 1-val_avg_a_loss:0.9147 , 1-val_avg_n_loss:0.9093
# 100%|██████████| 830/830 [04:19<00:00,  3.20it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 23:31:30,204]::3947538980::DEBUG::Epoch: 91 , 1-MAE: 0.9098 , 1-Training Loss: 0.9819 , 1-val_avg_o_loss:0.9072 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-14 23:36:46,994]::3947538980::DEBUG::Epoch: 92 , 1-MAE: 0.9102 , 1-Training Loss: 0.9824 , 1-val_avg_o_loss:0.9085 , 1-val_avg_c_loss:0.9074 , 1-val_avg_e_loss:0.9121 , 1-val_avg_a_loss:0.9155 , 1-val_avg_n_loss:0.9074
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.25it/s]
# [2024-10-14 23:42:02,979]::3947538980::DEBUG::Epoch: 93 , 1-MAE: 0.9095 , 1-Training Loss: 0.9824 , 1-val_avg_o_loss:0.9080 , 1-val_avg_c_loss:0.9071 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9122 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 830/830 [04:20<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.23it/s]
# [2024-10-14 23:47:18,103]::3947538980::DEBUG::Epoch: 94 , 1-MAE: 0.9102 , 1-Training Loss: 0.9828 , 1-val_avg_o_loss:0.9075 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9158 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 830/830 [04:20<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-14 23:52:32,391]::3947538980::DEBUG::Epoch: 95 , 1-MAE: 0.9108 , 1-Training Loss: 0.9825 , 1-val_avg_o_loss:0.9088 , 1-val_avg_c_loss:0.9079 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.37it/s]
# [2024-10-14 23:57:45,753]::3947538980::DEBUG::Epoch: 96 , 1-MAE: 0.9102 , 1-Training Loss: 0.9829 , 1-val_avg_o_loss:0.9079 , 1-val_avg_c_loss:0.9058 , 1-val_avg_e_loss:0.9143 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-15 00:03:01,583]::3947538980::DEBUG::Epoch: 97 , 1-MAE: 0.9105 , 1-Training Loss: 0.9833 , 1-val_avg_o_loss:0.9093 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.32it/s]
# [2024-10-15 00:08:16,415]::3947538980::DEBUG::Epoch: 98 , 1-MAE: 0.9103 , 1-Training Loss: 0.9831 , 1-val_avg_o_loss:0.9074 , 1-val_avg_c_loss:0.9068 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 830/830 [04:24<00:00,  3.13it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.24it/s]
# [2024-10-15 00:13:35,307]::3947538980::DEBUG::Epoch: 99 , 1-MAE: 0.9100 , 1-Training Loss: 0.9829 , 1-val_avg_o_loss:0.9078 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9149 , 1-val_avg_n_loss:0.9069
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-15 00:18:52,699]::3947538980::DEBUG::Epoch: 100 , 1-MAE: 0.9099 , 1-Training Loss: 0.9832 , 1-val_avg_o_loss:0.9083 , 1-val_avg_c_loss:0.9074 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9072
# 100%|██████████| 830/830 [04:19<00:00,  3.20it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.34it/s]
# [2024-10-15 00:24:04,854]::3947538980::DEBUG::Epoch: 101 , 1-MAE: 0.9103 , 1-Training Loss: 0.9834 , 1-val_avg_o_loss:0.9090 , 1-val_avg_c_loss:0.9058 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9151 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.37it/s]
# [2024-10-15 00:29:20,236]::3947538980::DEBUG::Epoch: 102 , 1-MAE: 0.9095 , 1-Training Loss: 0.9833 , 1-val_avg_o_loss:0.9077 , 1-val_avg_c_loss:0.9037 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9147 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 830/830 [04:20<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.30it/s]
# [2024-10-15 00:34:34,429]::3947538980::DEBUG::Epoch: 103 , 1-MAE: 0.9107 , 1-Training Loss: 0.9836 , 1-val_avg_o_loss:0.9091 , 1-val_avg_c_loss:0.9074 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9089
# 100%|██████████| 830/830 [04:18<00:00,  3.21it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.20it/s]
# [2024-10-15 00:39:47,464]::3947538980::DEBUG::Epoch: 104 , 1-MAE: 0.9105 , 1-Training Loss: 0.9836 , 1-val_avg_o_loss:0.9081 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9135 , 1-val_avg_a_loss:0.9162 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 830/830 [04:20<00:00,  3.19it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.22it/s]
# [2024-10-15 00:45:01,845]::3947538980::DEBUG::Epoch: 105 , 1-MAE: 0.9105 , 1-Training Loss: 0.9836 , 1-val_avg_o_loss:0.9073 , 1-val_avg_c_loss:0.9079 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9161 , 1-val_avg_n_loss:0.9087
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.32it/s]
# [2024-10-15 00:50:18,053]::3947538980::DEBUG::Epoch: 106 , 1-MAE: 0.9111 , 1-Training Loss: 0.9839 , 1-val_avg_o_loss:0.9090 , 1-val_avg_c_loss:0.9073 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9170 , 1-val_avg_n_loss:0.9083
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.31it/s]
# [2024-10-15 00:55:34,622]::3947538980::DEBUG::Epoch: 107 , 1-MAE: 0.9097 , 1-Training Loss: 0.9835 , 1-val_avg_o_loss:0.9079 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9146 , 1-val_avg_n_loss:0.9063
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.28it/s]
# [2024-10-15 01:00:50,760]::3947538980::DEBUG::Epoch: 108 , 1-MAE: 0.9107 , 1-Training Loss: 0.9837 , 1-val_avg_o_loss:0.9089 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9162 , 1-val_avg_n_loss:0.9090
# 100%|██████████| 830/830 [04:21<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.31it/s]
# [2024-10-15 01:06:05,478]::3947538980::DEBUG::Epoch: 109 , 1-MAE: 0.9096 , 1-Training Loss: 0.9839 , 1-val_avg_o_loss:0.9070 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9132 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 830/830 [04:26<00:00,  3.12it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.19it/s]
# [2024-10-15 01:11:26,512]::3947538980::DEBUG::Epoch: 110 , 1-MAE: 0.9106 , 1-Training Loss: 0.9842 , 1-val_avg_o_loss:0.9083 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9168 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 830/830 [04:19<00:00,  3.20it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.30it/s]
# [2024-10-15 01:16:39,142]::3947538980::DEBUG::Epoch: 111 , 1-MAE: 0.9102 , 1-Training Loss: 0.9837 , 1-val_avg_o_loss:0.9077 , 1-val_avg_c_loss:0.9077 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 830/830 [04:24<00:00,  3.14it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.24it/s]
# [2024-10-15 01:21:57,722]::3947538980::DEBUG::Epoch: 112 , 1-MAE: 0.9106 , 1-Training Loss: 0.9843 , 1-val_avg_o_loss:0.9078 , 1-val_avg_c_loss:0.9077 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9158 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 830/830 [04:25<00:00,  3.12it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.29it/s]
# [2024-10-15 01:27:16,986]::3947538980::DEBUG::Epoch: 113 , 1-MAE: 0.9108 , 1-Training Loss: 0.9841 , 1-val_avg_o_loss:0.9090 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9083
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.27it/s]
# [2024-10-15 01:32:32,318]::3947538980::DEBUG::Epoch: 114 , 1-MAE: 0.9109 , 1-Training Loss: 0.9841 , 1-val_avg_o_loss:0.9093 , 1-val_avg_c_loss:0.9069 , 1-val_avg_e_loss:0.9138 , 1-val_avg_a_loss:0.9159 , 1-val_avg_n_loss:0.9083
# 100%|██████████| 830/830 [04:24<00:00,  3.14it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.25it/s]
# [2024-10-15 01:37:50,777]::3947538980::DEBUG::Epoch: 115 , 1-MAE: 0.9102 , 1-Training Loss: 0.9845 , 1-val_avg_o_loss:0.9079 , 1-val_avg_c_loss:0.9069 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 830/830 [04:21<00:00,  3.17it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.19it/s]
# [2024-10-15 01:43:07,397]::3947538980::DEBUG::Epoch: 116 , 1-MAE: 0.9103 , 1-Training Loss: 0.9843 , 1-val_avg_o_loss:0.9085 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9073
# 100%|██████████| 830/830 [04:23<00:00,  3.15it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.34it/s]
# [2024-10-15 01:48:23,825]::3947538980::DEBUG::Epoch: 117 , 1-MAE: 0.9105 , 1-Training Loss: 0.9843 , 1-val_avg_o_loss:0.9075 , 1-val_avg_c_loss:0.9076 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9158 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 830/830 [04:21<00:00,  3.18it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.26it/s]
# [2024-10-15 01:53:39,007]::3947538980::DEBUG::Epoch: 118 , 1-MAE: 0.9103 , 1-Training Loss: 0.9843 , 1-val_avg_o_loss:0.9068 , 1-val_avg_c_loss:0.9069 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9161 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 830/830 [04:24<00:00,  3.13it/s]
# 100%|██████████| 280/280 [00:53<00:00,  5.28it/s]
# [2024-10-15 01:58:57,548]::3947538980::DEBUG::Epoch: 119 , 1-MAE: 0.9108 , 1-Training Loss: 0.9846 , 1-val_avg_o_loss:0.9092 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9087
# 100%|██████████| 830/830 [04:22<00:00,  3.16it/s]
# 100%|██████████| 280/280 [00:52<00:00,  5.35it/s]
# [2024-10-15 02:04:13,117]::3947538980::DEBUG::Epoch: 120 , 1-MAE: 0.9109 , 1-Training Loss: 0.9847 , 1-val_avg_o_loss:0.9090 , 1-val_avg_c_loss:0.9069 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9166 , 1-val_avg_n_loss:0.9081

# %%
#下一个就是使用预训练数据进行实验。
#使用Xception和STGCN各自实验得到结果，进行比较。
#将这个方式用到Video Swin Transformer or Video Vision Transformer

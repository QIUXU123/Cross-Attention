# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import os
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import random
import cv2
# from vgg16 import VGG16_LSTM
import pickle
import torch.nn as nn
import torch
import datetime
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms, utils, models
from torch.utils.data import Dataset, DataLoader
from facenet_pytorch import MTCNN
import logging
import torch
import torch.nn as nn
from qx_noface_no2d_video_swin_transformer01 import SwinTransformer3D
import gc
from einops import rearrange
from tqdm import tqdm
# from kw_r2plus1d_video_swin_transformer import SwinTransformer3D
batchsz = 4
frame_nums=15
start_epoch = 0
test_flage=False
model_name ="fullshot "
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('[%(asctime)s]::%(module)s::%(levelname)s::%(message)s')
streamHandler = logging.StreamHandler()
streamHandler.setFormatter(formatter)
fileHandler = logging.FileHandler('./LOG/personalityLog.log')
fileHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.addHandler(fileHandler)
USE_CUDA = torch.cuda.is_available()
# device = torch.device('cuda:1' if USE_CUDA else 'cpu')
# Out:
# /home/ssrlab/.local/lib/python3.10/site-packages/lazy_loader/__init__.py:202: RuntimeWarning: subpackages can technically be lazily loaded, but it causes the package to be eagerly loaded even if it is already lazily loaded.So, you probably shouldn't use subpackages with this lazy feature.
#   warnings.warn(msg, RuntimeWarning)
# /home/ssrlab/.local/lib/python3.10/site-packages/lazy_loader/__init__.py:202: RuntimeWarning: subpackages can technically be lazily loaded, but it causes the package to be eagerly loaded even if it is already lazily loaded.So, you probably shouldn't use subpackages with this lazy feature.
#   warnings.warn(msg, RuntimeWarning)
# /home/ssrlab/anaconda3/envs/qx/lib/python3.10/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
logger.debug('============={}+Video swin transformerTrain Strat!============='.format(model_name))
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:1' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:', device)
# Out:
# [2024-04-12 01:26:25,129]::387438924::DEBUG::=============fullshot +Video swin transformerTrain Strat!=============
# True
# 학습을 진행하는 기기: cuda:1

# %%
def select_frame_data(datas,frame_num):
    data_set=[]
    begin_num=0
    x=128/frame_num
    indexes=[None] * frame_num
    for i in range(frame_num):
        indexes[i]=int(begin_num)
        begin_num+=x
    for data in datas:
        video_frames = [None] * 2
        video_frames[0]=[]
        video_frames[1]=[]
        for index in indexes:
            video_frames[0].append(data[0][index])
        video_frames[1].append(data[1])
        data_set.append(video_frames)
        del video_frames
        del data 
        gc.collect()
    del datas
    gc.collect()
    return data_set
print(1)
# Out:
# 1

# %%
def getdata(pathname,datatype):
    if datatype=="train":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            # train_data_set.extend(pickle.load(output_file))
            final_data_set.extend(pickle.load(output_file))
            # print(i)
        return final_data_set
    elif datatype=="valid":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            valid_data_set=[]
            final_data_set.extend(pickle.load(output_file))
            del valid_data_set
        return final_data_set
print(1)
# Out:
# 1

# %%
def datasize(type,batchsz):
    if type=='train':
        i=5967#5967
        while True:
            if i%batchsz==0:
                return i
            else:
                i-=1
    else:
        i=1986#1986
        while True:
            if i%batchsz==0:
                return i
            else:
                i-=1
print(1)
# Out:
# 1

# %%
save_model_file_path = './save_swintransformer_folder/{}_{}.{}'
print(1)
# Out:
# 1

# %%
def reshape_to_expected_traininput(dataset: List[Tuple[ np.ndarray, np.ndarray]]) -> Tuple[
     np.ndarray, np.ndarray]:
    result=[]
    for i in range(0, len(dataset[0])):
        result.append((dataset[0][i],dataset[1][i],dataset[2][i],dataset[3][i],dataset[4][i],dataset[5][i]))
    result = result[:datasize("train",batchsz)]
    x0_list = []
    x1_list = []
    x2_list = []
    x3_list = []
    x4_list = []
    x5_list = []
    for i in range(0, len(result)):
        x0_list.append(result[i][0])
        x1_list.append(result[i][1])
        x2_list.append(result[i][2])
        x3_list.append(result[i][3])
        x4_list.append(result[i][4])
        x5_list.append(result[i][5])
    return (np.stack(x0_list), np.stack(x1_list), np.stack(x2_list),np.stack(x3_list), np.stack(x4_list), np.stack(x5_list))
print(1)
# Out:
# 1

# %%
def reshape_to_expected_input(dataset: List[Tuple[ np.ndarray, np.ndarray]]) -> Tuple[
     np.ndarray, np.ndarray]:
    x0_list = []
    x1_list = []
    for i in range(0, len(dataset)):
        x0_list.append(dataset[i][0])
        x1_list.append(dataset[i][1])
    return (np.stack(x0_list), np.stack(x1_list))
print(1)
# Out:
# 1

# %%
validation_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/Full_frames/valid_set.dat","valid")
validation_set_data = validation_set_data[:datasize("valid",batchsz)]
validation_set_data = reshape_to_expected_input(validation_set_data)
print(1)
# Out:
# 1

# %%
train_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/Full_frames/train_set.dat","train")
train_set_data = train_set_data[:datasize("train",batchsz)]
train_set_data = reshape_to_expected_input(train_set_data)
print(1)
# Out:
# 1

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
])
print(1)
# Out:
# 1

# %%
class ChalearnDataset(Dataset):
    def __init__(self,fullshot,tagdata,transform=None):
        self.fullshot=fullshot
        self.tagdata=tagdata
        self.transform = transform  # 표준화 여부
    def __len__(self):
        return len(self.fullshot)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()#텐서의 경우 목록으로 돌아가기
        # textdata = torch.FloatTensor(textdata)
        fullshot=self.fullshot[idx]
        fullshot=torch.FloatTensor(fullshot)
        # image_data=image_data.reshape(15,3,224,224)
        big_five_sorces=self.tagdata[idx]
        big_five_sorces = torch.FloatTensor(big_five_sorces)
        return fullshot,big_five_sorces
print(1)
# Out:
# 1

# %%
num_workerssz = 20
lr = 3e-05
epochs = 120
print(1)
# Out:
# 1

# %%
train_set_data = ChalearnDataset(fullshot = train_set_data[0],tagdata=train_set_data[1],transform=transform)
val_set_data = ChalearnDataset(fullshot = validation_set_data[0], tagdata=validation_set_data[1],transform=transform)
train_dataloader = DataLoader(dataset=train_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
val_dataloader = DataLoader(dataset=val_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
max_value=0
print(1)
# Out:
# 1

# %%
model=SwinTransformer3D()#num_frames=frame_nums,batchsz = batchsz
model.to(device)
criterion = torch.nn.L1Loss().to(device)  # 손실함수
optimizer = torch.optim.AdamW(model.parameters(), lr=lr) # 옵티마이저

if test_flage==True:
    checkpoint=torch.load(save_model_file_path.format('model',start_epoch,'pth'), map_location=device)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    # criterion.load_state_dict(checkpoint["loss"])
train_avg_loss0=[]
val_avg_loss0=[]
print(1)
# Out:
# /home/ssrlab/.local/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 1

# %%
from torchinfo import summary

summary(model, input_size = ((8,15,224,224,3)), col_names = ['input_size','output_size','num_params'])
# Out:
# =============================================================================================================================
# Layer (type:depth-idx)                             Input Shape               Output Shape              Param #
# =============================================================================================================================
# SwinTransformer3D                                  [8, 15, 224, 224, 3]      [8, 5]                    2,236,416
# ├─VideoResNet: 1-1                                 [8, 3, 15, 224, 224]      [8, 512, 2, 14, 14]       205,200
# │    └─R2Plus1dStem: 2-1                           [8, 3, 15, 224, 224]      [8, 64, 15, 112, 112]     --
# │    │    └─Conv3d: 3-1                            [8, 3, 15, 224, 224]      [8, 45, 15, 112, 112]     6,615
# │    │    └─BatchNorm3d: 3-2                       [8, 45, 15, 112, 112]     [8, 45, 15, 112, 112]     90
# │    │    └─ReLU: 3-3                              [8, 45, 15, 112, 112]     [8, 45, 15, 112, 112]     --
# │    │    └─Conv3d: 3-4                            [8, 45, 15, 112, 112]     [8, 64, 15, 112, 112]     8,640
# │    │    └─BatchNorm3d: 3-5                       [8, 64, 15, 112, 112]     [8, 64, 15, 112, 112]     128
# │    │    └─ReLU: 3-6                              [8, 64, 15, 112, 112]     [8, 64, 15, 112, 112]     --
# │    └─Sequential: 2-2                             [8, 64, 15, 112, 112]     [8, 64, 15, 112, 112]     --
# │    │    └─BasicBlock: 3-7                        [8, 64, 15, 112, 112]     [8, 64, 15, 112, 112]     222,016
# │    │    └─BasicBlock: 3-8                        [8, 64, 15, 112, 112]     [8, 64, 15, 112, 112]     222,016
# │    └─Sequential: 2-3                             [8, 64, 15, 112, 112]     [8, 128, 8, 56, 56]       --
# │    │    └─BasicBlock: 3-9                        [8, 64, 15, 112, 112]     [8, 128, 8, 56, 56]       583,960
# │    │    └─BasicBlock: 3-10                       [8, 128, 8, 56, 56]       [8, 128, 8, 56, 56]       886,400
# │    └─Sequential: 2-4                             [8, 128, 8, 56, 56]       [8, 256, 4, 28, 28]       --
# │    │    └─BasicBlock: 3-11                       [8, 128, 8, 56, 56]       [8, 256, 4, 28, 28]       2,332,464
# │    │    └─BasicBlock: 3-12                       [8, 256, 4, 28, 28]       [8, 256, 4, 28, 28]       3,542,272
# │    └─Sequential: 2-5                             [8, 256, 4, 28, 28]       [8, 512, 2, 14, 14]       --
# │    │    └─BasicBlock: 3-13                       [8, 256, 4, 28, 28]       [8, 512, 2, 14, 14]       9,333,092
# │    │    └─BasicBlock: 3-14                       [8, 512, 2, 14, 14]       [8, 512, 2, 14, 14]       14,162,432
# ├─PatchEmbed3D: 1-2                                [8, 512, 2, 14, 14]       [8, 96, 1, 4, 4]          --
# │    └─Conv3d: 2-6                                 [8, 512, 4, 16, 16]       [8, 96, 1, 4, 4]          3,145,824
# ├─Dropout: 1-3                                     [8, 96, 1, 4, 4]          [8, 96, 1, 4, 4]          --
# ├─ModuleList: 1-4                                  --                        --                        --
# │    └─BasicLayer: 2-7                             [8, 96, 1, 4, 4]          [8, 192, 1, 2, 2]         --
# │    │    └─ModuleList: 3-15                       --                        --                        226,722
# │    │    └─PatchMerging: 3-16                     [8, 1, 4, 4, 96]          [8, 1, 2, 2, 192]         74,496
# │    └─BasicLayer: 2-8                             [8, 192, 1, 2, 2]         [8, 384, 1, 1, 1]         --
# │    │    └─ModuleList: 3-17                       --                        --                        895,812
# │    │    └─PatchMerging: 3-18                     [8, 1, 2, 2, 192]         [8, 1, 1, 1, 384]         296,448
# │    └─BasicLayer: 2-9                             [8, 384, 1, 1, 1]         [8, 768, 1, 1, 1]         --
# │    │    └─ModuleList: 3-19                       --                        --                        10,683,288
# │    │    └─PatchMerging: 3-20                     [8, 1, 1, 1, 384]         [8, 1, 1, 1, 768]         1,182,720
# │    └─BasicLayer: 2-10                            [8, 768, 1, 1, 1]         [8, 1536, 1, 1, 1]        --
# │    │    └─ModuleList: 3-21                       --                        --                        14,200,080
# │    │    └─PatchMerging: 3-22                     [8, 1, 1, 1, 768]         [8, 1, 1, 1, 1536]        4,724,736
# ├─Linear: 1-5                                      [8, 1536]                 [8, 512]                  786,944
# ├─Linear: 1-6                                      [8, 512]                  [8, 5]                    2,565
# =============================================================================================================================
# Total params: 69,961,376
# Trainable params: 69,961,376
# Non-trainable params: 0
# Total mult-adds (T): 1.25
# =============================================================================================================================
# Input size (MB): 72.25
# Forward/backward pass size (MB): 30611.44
# Params size (MB): 269.80
# Estimated Total Size (MB): 30953.50
# =============================================================================================================================

# %%
def extract_ocean(data,batch_size):
    o=[]
    c=[]
    e=[]
    a=[]
    n=[]
    for i in range(batch_size):
        o.append(data[i][0].item())
        c.append(data[i][1].item())
        e.append(data[i][2].item())
        a.append(data[i][3].item())
        n.append(data[i][4].item())
    o = torch.tensor(o) 
    c = torch.tensor(c) 
    e = torch.tensor(e) 
    a = torch.tensor(a) 
    n = torch.tensor(n) 
    return o,c,e,a,n

# %%
with torch.cuda.device(1):
    for i in range(start_epoch, epochs):
        train_avg_loss = 0
        val_avg_loss = 0
        train_avg_o_loss = 0
        train_avg_c_loss = 0
        train_avg_e_loss = 0
        train_avg_a_loss = 0
        train_avg_n_loss = 0
        val_avg_o_loss = 0
        val_avg_c_loss = 0
        val_avg_e_loss = 0
        val_avg_a_loss = 0
        val_avg_n_loss = 0
        for fullshot,big_five_data in tqdm(train_dataloader):
            big_five_data=big_five_data.permute(0,2,1)
            big_five_data=big_five_data.squeeze()
            # fullshot = fullshot.permute(0,4,1,2,3)
            fullshot = fullshot.to(device)
            big_five_data = big_five_data.to(device)
            optimizer.zero_grad()  # 기울기가 0이 됩니다.
            hypothesis = model(fullshot)  # 모델의 예측 결과를 저장합니다.
            loss = criterion(hypothesis, big_five_data)  # 예측된 결과와 실제 태그 사이의 손실 값을 저장합니다.
            loss.backward()  # 역방향 전파입니다. 
            optimizer.step()  
            train_avg_loss += loss  
        train_avg_loss=train_avg_loss/len(train_dataloader)
        with torch.no_grad():#validate
            for fullshot,big_five_data in tqdm(val_dataloader):
                big_five_data=big_five_data.permute(0,2,1)
                big_five_data=big_five_data.squeeze()
                fullshot = fullshot.to(device)
                big_five_data = big_five_data.to(device)
                hypothesis = model(fullshot)
                val_loss = criterion(hypothesis, big_five_data)
                hypothesiso,hypothesisc,hypothesise,hypothesisa,hypothesisn=extract_ocean(hypothesis,batchsz)
                big_five_datao,big_five_datac,big_five_datae,big_five_dataa,big_five_datan=extract_ocean(big_five_data,batchsz)
                val_o_loss = criterion(hypothesiso, big_five_datao) 
                val_c_loss = criterion(hypothesisc, big_five_datac) 
                val_e_loss = criterion(hypothesise, big_five_datae) 
                val_a_loss = criterion(hypothesisa, big_five_dataa) 
                val_n_loss = criterion(hypothesisn, big_five_datan)  
                val_avg_loss += val_loss
                val_avg_o_loss += val_o_loss
                val_avg_c_loss += val_c_loss
                val_avg_e_loss += val_e_loss
                val_avg_a_loss += val_a_loss
                val_avg_n_loss += val_n_loss
            val_avg_loss=val_avg_loss/len(val_dataloader)
            val_avg_o_loss=val_avg_o_loss/len(val_dataloader)
            val_avg_c_loss=val_avg_c_loss/len(val_dataloader)
            val_avg_e_loss=val_avg_e_loss/len(val_dataloader)
            val_avg_a_loss=val_avg_a_loss/len(val_dataloader)
            val_avg_n_loss=val_avg_n_loss/len(val_dataloader)
        torch.cuda.empty_cache()
        # if (1-val_avg_loss)>=(1-max_value):
        max_value=val_avg_loss
        start_epoch+=1
        if (i + 1) % 5 == 0:
            torch.save({
                    'epoch': i+1,
                    'model': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'loss': val_avg_loss,
                }, save_model_file_path.format('model',start_epoch,'pth'))
        logger.debug('Epoch: {} , 1-MAE: {:.4f} , 1-val_avg_o_loss:{:.4f} , 1-val_avg_c_loss:{:.4f} , 1-val_avg_e_loss:{:.4f} , 1-val_avg_a_loss:{:.4f} , 1-val_avg_n_loss:{:.4f}'.format(i+1, 1-val_avg_loss, 1-val_avg_o_loss, 1-val_avg_c_loss, 1-val_avg_e_loss, 1-val_avg_a_loss,1-val_avg_n_loss))
# Out:
# 100%|██████████| 1491/1491 [05:30<00:00,  4.51it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.97it/s]
# [2024-04-12 01:32:46,895]::3110976099::DEBUG::Epoch: 1 , 1-MAE: 0.8909 , 1-val_avg_o_loss:0.8937 , 1-val_avg_c_loss:0.8961 , 1-val_avg_e_loss:0.9035 , 1-val_avg_a_loss:0.8598 , 1-val_avg_n_loss:0.9011
# 100%|██████████| 1491/1491 [05:30<00:00,  4.51it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.88it/s]
# [2024-04-12 01:39:00,507]::3110976099::DEBUG::Epoch: 2 , 1-MAE: 0.8934 , 1-val_avg_o_loss:0.9057 , 1-val_avg_c_loss:0.8893 , 1-val_avg_e_loss:0.9070 , 1-val_avg_a_loss:0.8706 , 1-val_avg_n_loss:0.8945
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.89it/s]
# [2024-04-12 01:45:14,270]::3110976099::DEBUG::Epoch: 3 , 1-MAE: 0.9008 , 1-val_avg_o_loss:0.9029 , 1-val_avg_c_loss:0.8955 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.8921 , 1-val_avg_n_loss:0.9024
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.87it/s]
# [2024-04-12 01:51:28,092]::3110976099::DEBUG::Epoch: 4 , 1-MAE: 0.9035 , 1-val_avg_o_loss:0.9083 , 1-val_avg_c_loss:0.9048 , 1-val_avg_e_loss:0.9055 , 1-val_avg_a_loss:0.8969 , 1-val_avg_n_loss:0.9021
# 100%|██████████| 1491/1491 [05:30<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.87it/s]
# [2024-04-12 01:57:42,965]::3110976099::DEBUG::Epoch: 5 , 1-MAE: 0.9089 , 1-val_avg_o_loss:0.9089 , 1-val_avg_c_loss:0.9084 , 1-val_avg_e_loss:0.9084 , 1-val_avg_a_loss:0.9088 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 02:03:56,647]::3110976099::DEBUG::Epoch: 6 , 1-MAE: 0.9103 , 1-val_avg_o_loss:0.9111 , 1-val_avg_c_loss:0.9086 , 1-val_avg_e_loss:0.9127 , 1-val_avg_a_loss:0.9094 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 02:10:10,522]::3110976099::DEBUG::Epoch: 7 , 1-MAE: 0.9118 , 1-val_avg_o_loss:0.9116 , 1-val_avg_c_loss:0.9086 , 1-val_avg_e_loss:0.9146 , 1-val_avg_a_loss:0.9130 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 02:16:24,386]::3110976099::DEBUG::Epoch: 8 , 1-MAE: 0.9053 , 1-val_avg_o_loss:0.9070 , 1-val_avg_c_loss:0.8974 , 1-val_avg_e_loss:0.9103 , 1-val_avg_a_loss:0.9096 , 1-val_avg_n_loss:0.9025
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 02:22:37,912]::3110976099::DEBUG::Epoch: 9 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9147 , 1-val_avg_c_loss:0.9023 , 1-val_avg_e_loss:0.9032 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9104
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.99it/s]
# [2024-04-12 02:28:52,617]::3110976099::DEBUG::Epoch: 10 , 1-MAE: 0.9107 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9030 , 1-val_avg_e_loss:0.9146 , 1-val_avg_a_loss:0.9133 , 1-val_avg_n_loss:0.9098
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 02:35:06,144]::3110976099::DEBUG::Epoch: 11 , 1-MAE: 0.9105 , 1-val_avg_o_loss:0.9143 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9033 , 1-val_avg_a_loss:0.9139 , 1-val_avg_n_loss:0.9114
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 02:41:20,044]::3110976099::DEBUG::Epoch: 12 , 1-MAE: 0.9075 , 1-val_avg_o_loss:0.9069 , 1-val_avg_c_loss:0.8951 , 1-val_avg_e_loss:0.9120 , 1-val_avg_a_loss:0.9145 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 02:47:33,760]::3110976099::DEBUG::Epoch: 13 , 1-MAE: 0.9121 , 1-val_avg_o_loss:0.9135 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9116 , 1-val_avg_a_loss:0.9157 , 1-val_avg_n_loss:0.9104
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 02:53:47,790]::3110976099::DEBUG::Epoch: 14 , 1-MAE: 0.9113 , 1-val_avg_o_loss:0.9117 , 1-val_avg_c_loss:0.9075 , 1-val_avg_e_loss:0.9161 , 1-val_avg_a_loss:0.9121 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 03:00:03,005]::3110976099::DEBUG::Epoch: 15 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9137 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9150 , 1-val_avg_a_loss:0.9148 , 1-val_avg_n_loss:0.9124
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 03:06:16,781]::3110976099::DEBUG::Epoch: 16 , 1-MAE: 0.9122 , 1-val_avg_o_loss:0.9138 , 1-val_avg_c_loss:0.9100 , 1-val_avg_e_loss:0.9145 , 1-val_avg_a_loss:0.9144 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 03:12:30,641]::3110976099::DEBUG::Epoch: 17 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9134 , 1-val_avg_c_loss:0.9067 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9121 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 12.00it/s]
# [2024-04-12 03:18:44,277]::3110976099::DEBUG::Epoch: 18 , 1-MAE: 0.9122 , 1-val_avg_o_loss:0.9108 , 1-val_avg_c_loss:0.9108 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9146 , 1-val_avg_n_loss:0.9124
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.99it/s]
# [2024-04-12 03:24:57,750]::3110976099::DEBUG::Epoch: 19 , 1-MAE: 0.9124 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9105 , 1-val_avg_e_loss:0.9104 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9132
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.98it/s]
# [2024-04-12 03:31:12,614]::3110976099::DEBUG::Epoch: 20 , 1-MAE: 0.9110 , 1-val_avg_o_loss:0.9146 , 1-val_avg_c_loss:0.9078 , 1-val_avg_e_loss:0.9086 , 1-val_avg_a_loss:0.9119 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.97it/s]
# [2024-04-12 03:37:26,078]::3110976099::DEBUG::Epoch: 21 , 1-MAE: 0.9121 , 1-val_avg_o_loss:0.9146 , 1-val_avg_c_loss:0.9100 , 1-val_avg_e_loss:0.9106 , 1-val_avg_a_loss:0.9124 , 1-val_avg_n_loss:0.9132
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.98it/s]
# [2024-04-12 03:43:39,727]::3110976099::DEBUG::Epoch: 22 , 1-MAE: 0.9120 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9087 , 1-val_avg_e_loss:0.9069 , 1-val_avg_a_loss:0.9143 , 1-val_avg_n_loss:0.9136
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 03:49:53,373]::3110976099::DEBUG::Epoch: 23 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9136 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9101 , 1-val_avg_n_loss:0.9126
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.98it/s]
# [2024-04-12 03:56:07,170]::3110976099::DEBUG::Epoch: 24 , 1-MAE: 0.9131 , 1-val_avg_o_loss:0.9150 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9157 , 1-val_avg_n_loss:0.9133
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 04:02:22,142]::3110976099::DEBUG::Epoch: 25 , 1-MAE: 0.9126 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9104 , 1-val_avg_e_loss:0.9115 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9132
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 04:08:35,575]::3110976099::DEBUG::Epoch: 26 , 1-MAE: 0.9131 , 1-val_avg_o_loss:0.9137 , 1-val_avg_c_loss:0.9109 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9142 , 1-val_avg_n_loss:0.9139
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.98it/s]
# [2024-04-12 04:14:49,232]::3110976099::DEBUG::Epoch: 27 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9113 , 1-val_avg_e_loss:0.9104 , 1-val_avg_a_loss:0.9149 , 1-val_avg_n_loss:0.9120
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.97it/s]
# [2024-04-12 04:21:02,924]::3110976099::DEBUG::Epoch: 28 , 1-MAE: 0.9135 , 1-val_avg_o_loss:0.9162 , 1-val_avg_c_loss:0.9107 , 1-val_avg_e_loss:0.9122 , 1-val_avg_a_loss:0.9155 , 1-val_avg_n_loss:0.9127
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 04:27:16,567]::3110976099::DEBUG::Epoch: 29 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9142 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9108 , 1-val_avg_a_loss:0.9135 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 04:33:31,593]::3110976099::DEBUG::Epoch: 30 , 1-MAE: 0.9129 , 1-val_avg_o_loss:0.9147 , 1-val_avg_c_loss:0.9101 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9150 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.97it/s]
# [2024-04-12 04:39:45,375]::3110976099::DEBUG::Epoch: 31 , 1-MAE: 0.9119 , 1-val_avg_o_loss:0.9127 , 1-val_avg_c_loss:0.9097 , 1-val_avg_e_loss:0.9108 , 1-val_avg_a_loss:0.9158 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 04:45:59,170]::3110976099::DEBUG::Epoch: 32 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9104 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9168 , 1-val_avg_n_loss:0.9110
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 04:52:12,941]::3110976099::DEBUG::Epoch: 33 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9154 , 1-val_avg_c_loss:0.9101 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9156 , 1-val_avg_n_loss:0.9114
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 04:58:26,715]::3110976099::DEBUG::Epoch: 34 , 1-MAE: 0.9121 , 1-val_avg_o_loss:0.9144 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9115 , 1-val_avg_a_loss:0.9162 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 05:04:41,620]::3110976099::DEBUG::Epoch: 35 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9152 , 1-val_avg_c_loss:0.9104 , 1-val_avg_e_loss:0.9120 , 1-val_avg_a_loss:0.9164 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 05:10:55,345]::3110976099::DEBUG::Epoch: 36 , 1-MAE: 0.9145 , 1-val_avg_o_loss:0.9170 , 1-val_avg_c_loss:0.9118 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.91it/s]
# [2024-04-12 05:17:09,326]::3110976099::DEBUG::Epoch: 37 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9142 , 1-val_avg_c_loss:0.9112 , 1-val_avg_e_loss:0.9120 , 1-val_avg_a_loss:0.9158 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 12.00it/s]
# [2024-04-12 05:23:23,222]::3110976099::DEBUG::Epoch: 38 , 1-MAE: 0.9123 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9097 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9156 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 05:29:37,100]::3110976099::DEBUG::Epoch: 39 , 1-MAE: 0.9125 , 1-val_avg_o_loss:0.9144 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9163 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.88it/s]
# [2024-04-12 05:35:52,441]::3110976099::DEBUG::Epoch: 40 , 1-MAE: 0.9125 , 1-val_avg_o_loss:0.9144 , 1-val_avg_c_loss:0.9107 , 1-val_avg_e_loss:0.9120 , 1-val_avg_a_loss:0.9155 , 1-val_avg_n_loss:0.9098
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 05:42:06,366]::3110976099::DEBUG::Epoch: 41 , 1-MAE: 0.9126 , 1-val_avg_o_loss:0.9134 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9161 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 05:48:20,315]::3110976099::DEBUG::Epoch: 42 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9150 , 1-val_avg_c_loss:0.9109 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 05:54:34,330]::3110976099::DEBUG::Epoch: 43 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9145 , 1-val_avg_c_loss:0.9099 , 1-val_avg_e_loss:0.9145 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 06:00:48,245]::3110976099::DEBUG::Epoch: 44 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9111 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9157 , 1-val_avg_n_loss:0.9122
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.89it/s]
# [2024-04-12 06:07:03,509]::3110976099::DEBUG::Epoch: 45 , 1-MAE: 0.9143 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9115 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9130
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 06:13:17,422]::3110976099::DEBUG::Epoch: 46 , 1-MAE: 0.9128 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9097 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9111
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.91it/s]
# [2024-04-12 06:19:31,606]::3110976099::DEBUG::Epoch: 47 , 1-MAE: 0.9135 , 1-val_avg_o_loss:0.9161 , 1-val_avg_c_loss:0.9110 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9168 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 06:25:45,534]::3110976099::DEBUG::Epoch: 48 , 1-MAE: 0.9119 , 1-val_avg_o_loss:0.9152 , 1-val_avg_c_loss:0.9104 , 1-val_avg_e_loss:0.9107 , 1-val_avg_a_loss:0.9116 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.90it/s]
# [2024-04-12 06:31:59,571]::3110976099::DEBUG::Epoch: 49 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9104 , 1-val_avg_e_loss:0.9148 , 1-val_avg_a_loss:0.9163 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 06:38:14,671]::3110976099::DEBUG::Epoch: 50 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9159 , 1-val_avg_c_loss:0.9104 , 1-val_avg_e_loss:0.9138 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9094
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 06:44:28,686]::3110976099::DEBUG::Epoch: 51 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9150 , 1-val_avg_c_loss:0.9110 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9160 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.89it/s]
# [2024-04-12 06:50:42,943]::3110976099::DEBUG::Epoch: 52 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9109 , 1-val_avg_e_loss:0.9145 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9116
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.97it/s]
# [2024-04-12 06:56:57,164]::3110976099::DEBUG::Epoch: 53 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9162 , 1-val_avg_c_loss:0.9102 , 1-val_avg_e_loss:0.9142 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 07:03:11,190]::3110976099::DEBUG::Epoch: 54 , 1-MAE: 0.9125 , 1-val_avg_o_loss:0.9141 , 1-val_avg_c_loss:0.9106 , 1-val_avg_e_loss:0.9148 , 1-val_avg_a_loss:0.9161 , 1-val_avg_n_loss:0.9069
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 07:09:26,403]::3110976099::DEBUG::Epoch: 55 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9076 , 1-val_avg_e_loss:0.9138 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.91it/s]
# [2024-04-12 07:15:40,668]::3110976099::DEBUG::Epoch: 56 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9104 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9090
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 07:21:54,460]::3110976099::DEBUG::Epoch: 57 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9145 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9166 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 07:28:08,672]::3110976099::DEBUG::Epoch: 58 , 1-MAE: 0.9135 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 07:34:22,589]::3110976099::DEBUG::Epoch: 59 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9150 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9179 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 07:40:37,617]::3110976099::DEBUG::Epoch: 60 , 1-MAE: 0.9128 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9073 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9114
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 07:46:51,575]::3110976099::DEBUG::Epoch: 61 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9168 , 1-val_avg_c_loss:0.9075 , 1-val_avg_e_loss:0.9146 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9123
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.98it/s]
# [2024-04-12 07:53:05,485]::3110976099::DEBUG::Epoch: 62 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9079 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 07:59:19,371]::3110976099::DEBUG::Epoch: 63 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9167 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 08:05:33,298]::3110976099::DEBUG::Epoch: 64 , 1-MAE: 0.9131 , 1-val_avg_o_loss:0.9152 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9170 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 08:11:48,542]::3110976099::DEBUG::Epoch: 65 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9086 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9166 , 1-val_avg_n_loss:0.9110
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 08:18:02,515]::3110976099::DEBUG::Epoch: 66 , 1-MAE: 0.9129 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9072 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9177 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.88it/s]
# [2024-04-12 08:24:16,635]::3110976099::DEBUG::Epoch: 67 , 1-MAE: 0.9125 , 1-val_avg_o_loss:0.9146 , 1-val_avg_c_loss:0.9072 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9170 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.89it/s]
# [2024-04-12 08:30:30,651]::3110976099::DEBUG::Epoch: 68 , 1-MAE: 0.9124 , 1-val_avg_o_loss:0.9145 , 1-val_avg_c_loss:0.9076 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.88it/s]
# [2024-04-12 08:36:45,033]::3110976099::DEBUG::Epoch: 69 , 1-MAE: 0.9127 , 1-val_avg_o_loss:0.9152 , 1-val_avg_c_loss:0.9099 , 1-val_avg_e_loss:0.9120 , 1-val_avg_a_loss:0.9150 , 1-val_avg_n_loss:0.9116
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 08:43:00,449]::3110976099::DEBUG::Epoch: 70 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9177 , 1-val_avg_n_loss:0.9127
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 08:49:14,592]::3110976099::DEBUG::Epoch: 71 , 1-MAE: 0.9131 , 1-val_avg_o_loss:0.9154 , 1-val_avg_c_loss:0.9085 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.91it/s]
# [2024-04-12 08:55:28,899]::3110976099::DEBUG::Epoch: 72 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9160 , 1-val_avg_c_loss:0.9075 , 1-val_avg_e_loss:0.9143 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 09:01:43,016]::3110976099::DEBUG::Epoch: 73 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9150 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9135 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 09:07:57,381]::3110976099::DEBUG::Epoch: 74 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9080 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9123
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 09:14:12,449]::3110976099::DEBUG::Epoch: 75 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9169 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9142 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9114
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 09:20:26,319]::3110976099::DEBUG::Epoch: 76 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9135 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 09:26:40,204]::3110976099::DEBUG::Epoch: 77 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9125
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.98it/s]
# [2024-04-12 09:32:54,186]::3110976099::DEBUG::Epoch: 78 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9162 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9145 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 09:39:08,251]::3110976099::DEBUG::Epoch: 79 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9177 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 09:45:23,291]::3110976099::DEBUG::Epoch: 80 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9167 , 1-val_avg_c_loss:0.9102 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 09:51:37,392]::3110976099::DEBUG::Epoch: 81 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9105 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9126
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.99it/s]
# [2024-04-12 09:57:51,331]::3110976099::DEBUG::Epoch: 82 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9122
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 10:04:05,382]::3110976099::DEBUG::Epoch: 83 , 1-MAE: 0.9131 , 1-val_avg_o_loss:0.9154 , 1-val_avg_c_loss:0.9073 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9159 , 1-val_avg_n_loss:0.9128
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 10:10:19,556]::3110976099::DEBUG::Epoch: 84 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9098 , 1-val_avg_e_loss:0.9138 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9123
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 10:16:34,893]::3110976099::DEBUG::Epoch: 85 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9143 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 10:22:48,889]::3110976099::DEBUG::Epoch: 86 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9151 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9138 , 1-val_avg_a_loss:0.9161 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 10:29:02,846]::3110976099::DEBUG::Epoch: 87 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9153 , 1-val_avg_c_loss:0.9092 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9125
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.89it/s]
# [2024-04-12 10:35:17,137]::3110976099::DEBUG::Epoch: 88 , 1-MAE: 0.9131 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9081 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 10:41:31,164]::3110976099::DEBUG::Epoch: 89 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9088 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 10:47:46,370]::3110976099::DEBUG::Epoch: 90 , 1-MAE: 0.9135 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9120
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 10:54:00,517]::3110976099::DEBUG::Epoch: 91 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9151 , 1-val_avg_c_loss:0.9102 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.92it/s]
# [2024-04-12 11:00:14,396]::3110976099::DEBUG::Epoch: 92 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9099 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9184 , 1-val_avg_n_loss:0.9116
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 11:06:28,466]::3110976099::DEBUG::Epoch: 93 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9170 , 1-val_avg_c_loss:0.9100 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9126
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.97it/s]
# [2024-04-12 11:12:42,639]::3110976099::DEBUG::Epoch: 94 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9171 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 11:18:57,916]::3110976099::DEBUG::Epoch: 95 , 1-MAE: 0.9144 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9099 , 1-val_avg_e_loss:0.9154 , 1-val_avg_a_loss:0.9171 , 1-val_avg_n_loss:0.9128
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.97it/s]
# [2024-04-12 11:25:12,079]::3110976099::DEBUG::Epoch: 96 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9167 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9178 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 11:31:26,007]::3110976099::DEBUG::Epoch: 97 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9098 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9178 , 1-val_avg_n_loss:0.9126
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 11:37:40,051]::3110976099::DEBUG::Epoch: 98 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9110 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 11:43:54,259]::3110976099::DEBUG::Epoch: 99 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9154 , 1-val_avg_c_loss:0.9105 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 11:50:09,782]::3110976099::DEBUG::Epoch: 100 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9098 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9114
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.96it/s]
# [2024-04-12 11:56:23,963]::3110976099::DEBUG::Epoch: 101 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9162 , 1-val_avg_c_loss:0.9092 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9168 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.99it/s]
# [2024-04-12 12:02:37,620]::3110976099::DEBUG::Epoch: 102 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9102 , 1-val_avg_e_loss:0.9135 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.88it/s]
# [2024-04-12 12:08:51,777]::3110976099::DEBUG::Epoch: 103 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9152 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9146 , 1-val_avg_a_loss:0.9182 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.97it/s]
# [2024-04-12 12:15:05,614]::3110976099::DEBUG::Epoch: 104 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9169 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.94it/s]
# [2024-04-12 12:21:21,098]::3110976099::DEBUG::Epoch: 105 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9160 , 1-val_avg_c_loss:0.9083 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9188 , 1-val_avg_n_loss:0.9122
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 12:27:35,296]::3110976099::DEBUG::Epoch: 106 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9162 , 1-val_avg_c_loss:0.9079 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9171 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 12:33:49,736]::3110976099::DEBUG::Epoch: 107 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9161 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 12:40:04,181]::3110976099::DEBUG::Epoch: 108 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9161 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9145 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9120
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.90it/s]
# [2024-04-12 12:46:18,603]::3110976099::DEBUG::Epoch: 109 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9169 , 1-val_avg_c_loss:0.9108 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9171 , 1-val_avg_n_loss:0.9124
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.99it/s]
# [2024-04-12 12:52:34,065]::3110976099::DEBUG::Epoch: 110 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9159 , 1-val_avg_c_loss:0.9103 , 1-val_avg_e_loss:0.9146 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9120
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.91it/s]
# [2024-04-12 12:58:48,567]::3110976099::DEBUG::Epoch: 111 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9102 , 1-val_avg_e_loss:0.9138 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9131
# 100%|██████████| 1491/1491 [05:32<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.90it/s]
# [2024-04-12 13:05:03,202]::3110976099::DEBUG::Epoch: 112 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9106 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9123
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.88it/s]
# [2024-04-12 13:11:17,750]::3110976099::DEBUG::Epoch: 113 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9127
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.90it/s]
# [2024-04-12 13:17:32,262]::3110976099::DEBUG::Epoch: 114 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 13:23:47,780]::3110976099::DEBUG::Epoch: 115 , 1-MAE: 0.9145 , 1-val_avg_o_loss:0.9168 , 1-val_avg_c_loss:0.9102 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9133
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.97it/s]
# [2024-04-12 13:30:02,246]::3110976099::DEBUG::Epoch: 116 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9101 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9181 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 13:36:16,707]::3110976099::DEBUG::Epoch: 117 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9165 , 1-val_avg_c_loss:0.9101 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9168 , 1-val_avg_n_loss:0.9123
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.91it/s]
# [2024-04-12 13:42:31,147]::3110976099::DEBUG::Epoch: 118 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9099 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9180 , 1-val_avg_n_loss:0.9122
# 100%|██████████| 1491/1491 [05:31<00:00,  4.49it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.93it/s]
# [2024-04-12 13:48:45,481]::3110976099::DEBUG::Epoch: 119 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9074 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1491/1491 [05:31<00:00,  4.50it/s]
# 100%|██████████| 496/496 [00:41<00:00, 11.95it/s]
# [2024-04-12 13:55:00,801]::3110976099::DEBUG::Epoch: 120 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9100 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9180 , 1-val_avg_n_loss:0.9120

# %%
# from torchinfo import summary

# summary(model, input_size = (4,15,4,3,224,224))

# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import os
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import random
import cv2
# from vgg16 import VGG16_LSTM
import pickle
import torch.nn as nn
import torch
import datetime
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms, utils, models
from torch.utils.data import Dataset, DataLoader
from facenet_pytorch import MTCNN
import logging
import torch
import torch.nn as nn
from qx_noface_no2d_video_swin_transformer01 import SwinTransformer3D
import gc
from einops import rearrange
from tqdm import tqdm
# from kw_r2plus1d_video_swin_transformer import SwinTransformer3D
batchsz = 4
frame_nums=15
start_epoch = 0
test_flage=False
model_name ="14 "
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('[%(asctime)s]::%(module)s::%(levelname)s::%(message)s')
streamHandler = logging.StreamHandler()
streamHandler.setFormatter(formatter)
fileHandler = logging.FileHandler('./LOG/personalityLog.log')
fileHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.addHandler(fileHandler)
USE_CUDA = torch.cuda.is_available()
# device = torch.device('cuda:1' if USE_CUDA else 'cpu')

# %%
logger.debug('============={}+Video swin transformerTrain Strat!============='.format(model_name))
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:1' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:', device)
# Out:
# [2024-04-05 22:13:11,633]::387438924::DEBUG::=============14 +Video swin transformerTrain Strat!=============
# True
# 학습을 진행하는 기기: cuda:1

# %%
def select_frame_data(datas,frame_num):
    data_set=[]
    begin_num=0
    x=128/frame_num
    indexes=[None] * frame_num
    for i in range(frame_num):
        indexes[i]=int(begin_num)
        begin_num+=x
    for data in datas:
        video_frames = [None] * 2
        video_frames[0]=[]
        video_frames[1]=[]
        for index in indexes:
            video_frames[0].append(data[0][index])
        video_frames[1].append(data[1])
        data_set.append(video_frames)
        del video_frames
        del data 
        gc.collect()
    del datas
    gc.collect()
    return data_set
print(1)
# Out:
# 1

# %%
def getdata(pathname,datatype):
    if datatype=="train":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            # train_data_set.extend(pickle.load(output_file))
            final_data_set.extend(pickle.load(output_file))
            # print(i)
        return final_data_set
    elif datatype=="valid":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            valid_data_set=[]
            final_data_set.extend(pickle.load(output_file))
            del valid_data_set
        return final_data_set
print(1)
# Out:
# 1

# %%
def datasize(type,batchsz):
    if type=='train':
        i=5076#5967
        while True:
            if i%batchsz==0:
                return i
            else:
                i-=1
    else:
        i=1682#1986
        while True:
            if i%batchsz==0:
                return i
            else:
                i-=1
print(1)
# Out:
# 1

# %%
save_model_file_path = './save_swintransformer_folder/{}_{}.{}'
print(1)
# Out:
# 1

# %%
def reshape_to_expected_traininput(dataset: List[Tuple[ np.ndarray, np.ndarray]]) -> Tuple[
     np.ndarray, np.ndarray]:
    result=[]
    for i in range(0, len(dataset[0])):
        result.append((dataset[0][i],dataset[1][i],dataset[2][i],dataset[3][i]))
    result = result[:datasize("train",batchsz)]
    x0_list = []
    x1_list = []
    x2_list = []
    x3_list = []
    for i in range(0, len(result)):
        x0_list.append(result[i][0])
        x1_list.append(result[i][1])
        x2_list.append(result[i][2])
        x3_list.append(result[i][3])
    return (np.stack(x0_list), np.stack(x1_list), np.stack(x2_list),np.stack(x3_list))
print(1)
# Out:
# 1

# %%
def reshape_to_expected_validinput(dataset: List[Tuple[ np.ndarray, np.ndarray]]) -> Tuple[
     np.ndarray, np.ndarray]:
    result=[]
    for i in range(0, len(dataset[0])):
        result.append((dataset[0][i],dataset[1][i],dataset[2][i],dataset[3][i]))
    result = result[:datasize("valid",batchsz)]
    x0_list = []
    x1_list = []
    x2_list = []
    x3_list = []
    for i in range(0, len(result)):
        x0_list.append(result[i][0])
        x1_list.append(result[i][1])
        x2_list.append(result[i][2])
        x3_list.append(result[i][3])
    return (np.stack(x0_list), np.stack(x1_list), np.stack(x2_list),np.stack(x3_list))
print(1)
# Out:
# 1

# %%
validation_set_data=getdata("/mnt/2ndSSD/qx/data/15Frames/margin/121314valid_set.dat","valid")
validation_set_data=reshape_to_expected_validinput(validation_set_data)
print(1)
# Out:
# 1

# %%
train_set_data=getdata("/mnt/2ndSSD/qx/data/15Frames/margin/121314train_set.dat","train")
train_set_data=reshape_to_expected_traininput(train_set_data)
print(1)
# Out:
# 1

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
])
print(1)
# Out:
# 1

# %%
class ChalearnDataset(Dataset):
    def __init__(self,fullshot,tagdata,transform=None):
        self.fullshot=fullshot
        self.tagdata=tagdata
        self.transform = transform  # 표준화 여부
    def __len__(self):
        return len(self.fullshot)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()#텐서의 경우 목록으로 돌아가기
        fullshot=self.fullshot[idx]
        fullshot=torch.FloatTensor(fullshot)
        big_five_sorces=self.tagdata[idx]
        big_five_sorces = torch.FloatTensor(big_five_sorces)
        return fullshot,big_five_sorces
print(1)
# Out:
# 1

# %%
num_workerssz = 20
lr = 3e-05
epochs = 120
print(1)
# Out:
# 1

# %%
train_set_data = ChalearnDataset(fullshot = train_set_data[2],tagdata=train_set_data[3],transform=transform)
val_set_data = ChalearnDataset(fullshot = validation_set_data[2], tagdata=validation_set_data[3],transform=transform)
train_dataloader = DataLoader(dataset=train_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
val_dataloader = DataLoader(dataset=val_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
max_value=0
print(1)
# Out:
# 1

# %%
model=SwinTransformer3D()#num_frames=frame_nums,batchsz = batchsz
model.to(device)
criterion = torch.nn.L1Loss().to(device)  # 손실함수
optimizer = torch.optim.AdamW(model.parameters(), lr=lr) # 옵티마이저

if test_flage==True:
    checkpoint=torch.load(save_model_file_path.format('model',start_epoch,'pth'), map_location=device)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    # criterion.load_state_dict(checkpoint["loss"])
train_avg_loss0=[]
val_avg_loss0=[]
print(1)
# Out:
# /home/ssrlab/anaconda3/envs/qx/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 1

# %%
# from torchinfo import summary

# summary(model, input_size = ((8,15,224,224,3),(8,24,1319,1)), col_names = ['input_size','output_size','num_params'])

# %%
def extract_ocean(data,batch_size):
    o=[]
    c=[]
    e=[]
    a=[]
    n=[]
    for i in range(batch_size):
        o.append(data[i][0].item())
        c.append(data[i][1].item())
        e.append(data[i][2].item())
        a.append(data[i][3].item())
        n.append(data[i][4].item())
    o = torch.tensor(o) 
    c = torch.tensor(c) 
    e = torch.tensor(e) 
    a = torch.tensor(a) 
    n = torch.tensor(n) 
    return o,c,e,a,n

# %%
with torch.cuda.device(1):
    for i in range(start_epoch, epochs):
        train_avg_loss = 0
        val_avg_loss = 0
        train_avg_o_loss = 0
        train_avg_c_loss = 0
        train_avg_e_loss = 0
        train_avg_a_loss = 0
        train_avg_n_loss = 0
        val_avg_o_loss = 0
        val_avg_c_loss = 0
        val_avg_e_loss = 0
        val_avg_a_loss = 0
        val_avg_n_loss = 0
        for fullshot,big_five_data in tqdm(train_dataloader):
            big_five_data=big_five_data.permute(0,2,1)
            big_five_data=big_five_data.squeeze()
            fullshot = fullshot.to(device)
            big_five_data = big_five_data.to(device)
            optimizer.zero_grad()  # 기울기가 0이 됩니다.
            hypothesis = model(fullshot)  # 모델의 예측 결과를 저장합니다.
            loss = criterion(hypothesis, big_five_data)  # 예측된 결과와 실제 태그 사이의 손실 값을 저장합니다.
            loss.backward()  # 역방향 전파입니다. 
            optimizer.step()  
            train_avg_loss += loss  
        train_avg_loss=train_avg_loss/len(train_dataloader)
        with torch.no_grad():#validate
            for fullshot,big_five_data in tqdm(val_dataloader):
                big_five_data=big_five_data.permute(0,2,1)
                big_five_data=big_five_data.squeeze()
                fullshot = fullshot.to(device)
                big_five_data = big_five_data.to(device)
                hypothesis = model(fullshot)
                val_loss = criterion(hypothesis, big_five_data)
                hypothesiso,hypothesisc,hypothesise,hypothesisa,hypothesisn=extract_ocean(hypothesis,batchsz)
                big_five_datao,big_five_datac,big_five_datae,big_five_dataa,big_five_datan=extract_ocean(big_five_data,batchsz)
                val_o_loss = criterion(hypothesiso, big_five_datao) 
                val_c_loss = criterion(hypothesisc, big_five_datac) 
                val_e_loss = criterion(hypothesise, big_five_datae) 
                val_a_loss = criterion(hypothesisa, big_five_dataa) 
                val_n_loss = criterion(hypothesisn, big_five_datan)  
                val_avg_loss += val_loss
                val_avg_o_loss += val_o_loss
                val_avg_c_loss += val_c_loss
                val_avg_e_loss += val_e_loss
                val_avg_a_loss += val_a_loss
                val_avg_n_loss += val_n_loss
            val_avg_loss=val_avg_loss/len(val_dataloader)
            val_avg_o_loss=val_avg_o_loss/len(val_dataloader)
            val_avg_c_loss=val_avg_c_loss/len(val_dataloader)
            val_avg_e_loss=val_avg_e_loss/len(val_dataloader)
            val_avg_a_loss=val_avg_a_loss/len(val_dataloader)
            val_avg_n_loss=val_avg_n_loss/len(val_dataloader)
        torch.cuda.empty_cache()
        # if (1-val_avg_loss)>=(1-max_value):
        max_value=val_avg_loss
        start_epoch+=1
        if (i + 1) % 5 == 0:
            torch.save({
                    'epoch': i+1,
                    'model': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'loss': val_avg_loss,
                }, save_model_file_path.format('model',start_epoch,'pth'))
        logger.debug('Epoch: {} , 1-MAE: {:.4f} , 1-val_avg_o_loss:{:.4f} , 1-val_avg_c_loss:{:.4f} , 1-val_avg_e_loss:{:.4f} , 1-val_avg_a_loss:{:.4f} , 1-val_avg_n_loss:{:.4f}'.format(i+1, 1-val_avg_loss, 1-val_avg_o_loss, 1-val_avg_c_loss, 1-val_avg_e_loss, 1-val_avg_a_loss,1-val_avg_n_loss))
# Out:
# 100%|██████████| 1269/1269 [04:26<00:00,  4.77it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.65it/s]
# [2024-04-05 22:19:33,632]::3605594554::DEBUG::Epoch: 1 , 1-MAE: 0.8562 , 1-val_avg_o_loss:0.7667 , 1-val_avg_c_loss:0.8791 , 1-val_avg_e_loss:0.8788 , 1-val_avg_a_loss:0.8758 , 1-val_avg_n_loss:0.8805
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.66it/s]
# [2024-04-05 22:24:32,727]::3605594554::DEBUG::Epoch: 2 , 1-MAE: 0.8812 , 1-val_avg_o_loss:0.8489 , 1-val_avg_c_loss:0.8836 , 1-val_avg_e_loss:0.9013 , 1-val_avg_a_loss:0.8794 , 1-val_avg_n_loss:0.8928
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.67it/s]
# [2024-04-05 22:29:32,076]::3605594554::DEBUG::Epoch: 3 , 1-MAE: 0.8955 , 1-val_avg_o_loss:0.8971 , 1-val_avg_c_loss:0.8940 , 1-val_avg_e_loss:0.9032 , 1-val_avg_a_loss:0.8887 , 1-val_avg_n_loss:0.8945
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.62it/s]
# [2024-04-05 22:34:31,608]::3605594554::DEBUG::Epoch: 4 , 1-MAE: 0.8955 , 1-val_avg_o_loss:0.8827 , 1-val_avg_c_loss:0.8988 , 1-val_avg_e_loss:0.9058 , 1-val_avg_a_loss:0.8906 , 1-val_avg_n_loss:0.8994
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.64it/s]
# [2024-04-05 22:39:32,023]::3605594554::DEBUG::Epoch: 5 , 1-MAE: 0.8973 , 1-val_avg_o_loss:0.8965 , 1-val_avg_c_loss:0.8950 , 1-val_avg_e_loss:0.9018 , 1-val_avg_a_loss:0.8930 , 1-val_avg_n_loss:0.9000
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.59it/s]
# [2024-04-05 22:44:31,378]::3605594554::DEBUG::Epoch: 6 , 1-MAE: 0.9015 , 1-val_avg_o_loss:0.9079 , 1-val_avg_c_loss:0.8980 , 1-val_avg_e_loss:0.9103 , 1-val_avg_a_loss:0.8930 , 1-val_avg_n_loss:0.8982
# 100%|██████████| 1269/1269 [04:25<00:00,  4.79it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.56it/s]
# [2024-04-05 22:49:30,762]::3605594554::DEBUG::Epoch: 7 , 1-MAE: 0.9044 , 1-val_avg_o_loss:0.9076 , 1-val_avg_c_loss:0.9022 , 1-val_avg_e_loss:0.9051 , 1-val_avg_a_loss:0.8991 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.74it/s]
# [2024-04-05 22:54:29,771]::3605594554::DEBUG::Epoch: 8 , 1-MAE: 0.9052 , 1-val_avg_o_loss:0.9104 , 1-val_avg_c_loss:0.9012 , 1-val_avg_e_loss:0.9066 , 1-val_avg_a_loss:0.9004 , 1-val_avg_n_loss:0.9072
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.67it/s]
# [2024-04-05 22:59:29,012]::3605594554::DEBUG::Epoch: 9 , 1-MAE: 0.9069 , 1-val_avg_o_loss:0.9087 , 1-val_avg_c_loss:0.9035 , 1-val_avg_e_loss:0.9101 , 1-val_avg_a_loss:0.9040 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.65it/s]
# [2024-04-05 23:04:29,113]::3605594554::DEBUG::Epoch: 10 , 1-MAE: 0.9078 , 1-val_avg_o_loss:0.9081 , 1-val_avg_c_loss:0.9049 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9051 , 1-val_avg_n_loss:0.9091
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.60it/s]
# [2024-04-05 23:09:28,554]::3605594554::DEBUG::Epoch: 11 , 1-MAE: 0.9072 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9047 , 1-val_avg_e_loss:0.9075 , 1-val_avg_a_loss:0.9019 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.59it/s]
# [2024-04-05 23:14:28,258]::3605594554::DEBUG::Epoch: 12 , 1-MAE: 0.9057 , 1-val_avg_o_loss:0.9117 , 1-val_avg_c_loss:0.9039 , 1-val_avg_e_loss:0.9058 , 1-val_avg_a_loss:0.8984 , 1-val_avg_n_loss:0.9089
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.55it/s]
# [2024-04-05 23:19:27,952]::3605594554::DEBUG::Epoch: 13 , 1-MAE: 0.9082 , 1-val_avg_o_loss:0.9099 , 1-val_avg_c_loss:0.9049 , 1-val_avg_e_loss:0.9098 , 1-val_avg_a_loss:0.9073 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.66it/s]
# [2024-04-05 23:24:27,458]::3605594554::DEBUG::Epoch: 14 , 1-MAE: 0.9052 , 1-val_avg_o_loss:0.9086 , 1-val_avg_c_loss:0.9034 , 1-val_avg_e_loss:0.9072 , 1-val_avg_a_loss:0.8989 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.68it/s]
# [2024-04-05 23:29:27,607]::3605594554::DEBUG::Epoch: 15 , 1-MAE: 0.9076 , 1-val_avg_o_loss:0.9115 , 1-val_avg_c_loss:0.9045 , 1-val_avg_e_loss:0.9088 , 1-val_avg_a_loss:0.9073 , 1-val_avg_n_loss:0.9059
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.75it/s]
# [2024-04-05 23:34:26,819]::3605594554::DEBUG::Epoch: 16 , 1-MAE: 0.9066 , 1-val_avg_o_loss:0.9112 , 1-val_avg_c_loss:0.9042 , 1-val_avg_e_loss:0.9101 , 1-val_avg_a_loss:0.8999 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.58it/s]
# [2024-04-05 23:39:26,384]::3605594554::DEBUG::Epoch: 17 , 1-MAE: 0.9075 , 1-val_avg_o_loss:0.9110 , 1-val_avg_c_loss:0.9033 , 1-val_avg_e_loss:0.9107 , 1-val_avg_a_loss:0.9059 , 1-val_avg_n_loss:0.9067
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.55it/s]
# [2024-04-05 23:44:26,193]::3605594554::DEBUG::Epoch: 18 , 1-MAE: 0.9075 , 1-val_avg_o_loss:0.9088 , 1-val_avg_c_loss:0.9034 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.9068 , 1-val_avg_n_loss:0.9074
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.69it/s]
# [2024-04-05 23:49:25,669]::3605594554::DEBUG::Epoch: 19 , 1-MAE: 0.9064 , 1-val_avg_o_loss:0.9097 , 1-val_avg_c_loss:0.9037 , 1-val_avg_e_loss:0.9095 , 1-val_avg_a_loss:0.9059 , 1-val_avg_n_loss:0.9030
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.64it/s]
# [2024-04-05 23:54:25,988]::3605594554::DEBUG::Epoch: 20 , 1-MAE: 0.9073 , 1-val_avg_o_loss:0.9107 , 1-val_avg_c_loss:0.9026 , 1-val_avg_e_loss:0.9101 , 1-val_avg_a_loss:0.9081 , 1-val_avg_n_loss:0.9050
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.63it/s]
# [2024-04-05 23:59:25,432]::3605594554::DEBUG::Epoch: 21 , 1-MAE: 0.9074 , 1-val_avg_o_loss:0.9120 , 1-val_avg_c_loss:0.9005 , 1-val_avg_e_loss:0.9102 , 1-val_avg_a_loss:0.9076 , 1-val_avg_n_loss:0.9067
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.72it/s]
# [2024-04-06 00:04:24,437]::3605594554::DEBUG::Epoch: 22 , 1-MAE: 0.9069 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9023 , 1-val_avg_e_loss:0.9072 , 1-val_avg_a_loss:0.9075 , 1-val_avg_n_loss:0.9057
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.58it/s]
# [2024-04-06 00:09:24,175]::3605594554::DEBUG::Epoch: 23 , 1-MAE: 0.9060 , 1-val_avg_o_loss:0.9094 , 1-val_avg_c_loss:0.9008 , 1-val_avg_e_loss:0.9078 , 1-val_avg_a_loss:0.9065 , 1-val_avg_n_loss:0.9057
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.67it/s]
# [2024-04-06 00:14:23,335]::3605594554::DEBUG::Epoch: 24 , 1-MAE: 0.9076 , 1-val_avg_o_loss:0.9115 , 1-val_avg_c_loss:0.9027 , 1-val_avg_e_loss:0.9089 , 1-val_avg_a_loss:0.9072 , 1-val_avg_n_loss:0.9075
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.69it/s]
# [2024-04-06 00:19:23,442]::3605594554::DEBUG::Epoch: 25 , 1-MAE: 0.9074 , 1-val_avg_o_loss:0.9112 , 1-val_avg_c_loss:0.9022 , 1-val_avg_e_loss:0.9101 , 1-val_avg_a_loss:0.9067 , 1-val_avg_n_loss:0.9069
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.62it/s]
# [2024-04-06 00:24:22,982]::3605594554::DEBUG::Epoch: 26 , 1-MAE: 0.9076 , 1-val_avg_o_loss:0.9116 , 1-val_avg_c_loss:0.9022 , 1-val_avg_e_loss:0.9097 , 1-val_avg_a_loss:0.9076 , 1-val_avg_n_loss:0.9068
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.69it/s]
# [2024-04-06 00:29:22,122]::3605594554::DEBUG::Epoch: 27 , 1-MAE: 0.9080 , 1-val_avg_o_loss:0.9115 , 1-val_avg_c_loss:0.9030 , 1-val_avg_e_loss:0.9106 , 1-val_avg_a_loss:0.9068 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 00:34:21,299]::3605594554::DEBUG::Epoch: 28 , 1-MAE: 0.9076 , 1-val_avg_o_loss:0.9114 , 1-val_avg_c_loss:0.9019 , 1-val_avg_e_loss:0.9096 , 1-val_avg_a_loss:0.9084 , 1-val_avg_n_loss:0.9067
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.67it/s]
# [2024-04-06 00:39:20,666]::3605594554::DEBUG::Epoch: 29 , 1-MAE: 0.9077 , 1-val_avg_o_loss:0.9120 , 1-val_avg_c_loss:0.9031 , 1-val_avg_e_loss:0.9090 , 1-val_avg_a_loss:0.9082 , 1-val_avg_n_loss:0.9062
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 00:44:20,919]::3605594554::DEBUG::Epoch: 30 , 1-MAE: 0.9073 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.8996 , 1-val_avg_e_loss:0.9103 , 1-val_avg_a_loss:0.9075 , 1-val_avg_n_loss:0.9061
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.68it/s]
# [2024-04-06 00:49:20,404]::3605594554::DEBUG::Epoch: 31 , 1-MAE: 0.9074 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9021 , 1-val_avg_e_loss:0.9087 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.9053
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.62it/s]
# [2024-04-06 00:54:19,820]::3605594554::DEBUG::Epoch: 32 , 1-MAE: 0.9073 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9034 , 1-val_avg_e_loss:0.9055 , 1-val_avg_a_loss:0.9081 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.61it/s]
# [2024-04-06 00:59:19,546]::3605594554::DEBUG::Epoch: 33 , 1-MAE: 0.9080 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9020 , 1-val_avg_e_loss:0.9087 , 1-val_avg_a_loss:0.9090 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.73it/s]
# [2024-04-06 01:04:18,805]::3605594554::DEBUG::Epoch: 34 , 1-MAE: 0.9092 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9043 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9089 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.73it/s]
# [2024-04-06 01:09:18,998]::3605594554::DEBUG::Epoch: 35 , 1-MAE: 0.9077 , 1-val_avg_o_loss:0.9112 , 1-val_avg_c_loss:0.9032 , 1-val_avg_e_loss:0.9097 , 1-val_avg_a_loss:0.9080 , 1-val_avg_n_loss:0.9064
# 100%|██████████| 1269/1269 [04:25<00:00,  4.79it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 01:14:17,901]::3605594554::DEBUG::Epoch: 36 , 1-MAE: 0.9082 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9025 , 1-val_avg_e_loss:0.9100 , 1-val_avg_a_loss:0.9084 , 1-val_avg_n_loss:0.9071
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.77it/s]
# [2024-04-06 01:19:17,109]::3605594554::DEBUG::Epoch: 37 , 1-MAE: 0.9082 , 1-val_avg_o_loss:0.9118 , 1-val_avg_c_loss:0.9029 , 1-val_avg_e_loss:0.9101 , 1-val_avg_a_loss:0.9097 , 1-val_avg_n_loss:0.9065
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.66it/s]
# [2024-04-06 01:24:16,445]::3605594554::DEBUG::Epoch: 38 , 1-MAE: 0.9084 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9028 , 1-val_avg_e_loss:0.9108 , 1-val_avg_a_loss:0.9080 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.63it/s]
# [2024-04-06 01:29:15,943]::3605594554::DEBUG::Epoch: 39 , 1-MAE: 0.9084 , 1-val_avg_o_loss:0.9119 , 1-val_avg_c_loss:0.9034 , 1-val_avg_e_loss:0.9098 , 1-val_avg_a_loss:0.9082 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.66it/s]
# [2024-04-06 01:34:16,404]::3605594554::DEBUG::Epoch: 40 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9037 , 1-val_avg_e_loss:0.9102 , 1-val_avg_a_loss:0.9088 , 1-val_avg_n_loss:0.9070
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.74it/s]
# [2024-04-06 01:39:15,575]::3605594554::DEBUG::Epoch: 41 , 1-MAE: 0.9088 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9045 , 1-val_avg_e_loss:0.9098 , 1-val_avg_a_loss:0.9089 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.62it/s]
# [2024-04-06 01:44:14,899]::3605594554::DEBUG::Epoch: 42 , 1-MAE: 0.9082 , 1-val_avg_o_loss:0.9111 , 1-val_avg_c_loss:0.9039 , 1-val_avg_e_loss:0.9101 , 1-val_avg_a_loss:0.9076 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.78it/s]
# [2024-04-06 01:49:13,932]::3605594554::DEBUG::Epoch: 43 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9139 , 1-val_avg_c_loss:0.9035 , 1-val_avg_e_loss:0.9121 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.76it/s]
# [2024-04-06 01:54:13,008]::3605594554::DEBUG::Epoch: 44 , 1-MAE: 0.9089 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9051 , 1-val_avg_e_loss:0.9104 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.66it/s]
# [2024-04-06 01:59:13,070]::3605594554::DEBUG::Epoch: 45 , 1-MAE: 0.9084 , 1-val_avg_o_loss:0.9119 , 1-val_avg_c_loss:0.9036 , 1-val_avg_e_loss:0.9083 , 1-val_avg_a_loss:0.9097 , 1-val_avg_n_loss:0.9087
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.75it/s]
# [2024-04-06 02:04:12,351]::3605594554::DEBUG::Epoch: 46 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9031 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9093 , 1-val_avg_n_loss:0.9091
# 100%|██████████| 1269/1269 [04:25<00:00,  4.79it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.75it/s]
# [2024-04-06 02:09:11,193]::3605594554::DEBUG::Epoch: 47 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9132 , 1-val_avg_c_loss:0.9040 , 1-val_avg_e_loss:0.9115 , 1-val_avg_a_loss:0.9106 , 1-val_avg_n_loss:0.9074
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.65it/s]
# [2024-04-06 02:14:10,660]::3605594554::DEBUG::Epoch: 48 , 1-MAE: 0.9080 , 1-val_avg_o_loss:0.9122 , 1-val_avg_c_loss:0.9031 , 1-val_avg_e_loss:0.9082 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.75it/s]
# [2024-04-06 02:19:09,949]::3605594554::DEBUG::Epoch: 49 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9029 , 1-val_avg_e_loss:0.9103 , 1-val_avg_a_loss:0.9092 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.68it/s]
# [2024-04-06 02:24:10,242]::3605594554::DEBUG::Epoch: 50 , 1-MAE: 0.9088 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9040 , 1-val_avg_e_loss:0.9104 , 1-val_avg_a_loss:0.9086 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.70it/s]
# [2024-04-06 02:29:09,462]::3605594554::DEBUG::Epoch: 51 , 1-MAE: 0.9082 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9036 , 1-val_avg_e_loss:0.9096 , 1-val_avg_a_loss:0.9079 , 1-val_avg_n_loss:0.9074
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.69it/s]
# [2024-04-06 02:34:08,840]::3605594554::DEBUG::Epoch: 52 , 1-MAE: 0.9084 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9036 , 1-val_avg_e_loss:0.9111 , 1-val_avg_a_loss:0.9074 , 1-val_avg_n_loss:0.9071
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.63it/s]
# [2024-04-06 02:39:08,426]::3605594554::DEBUG::Epoch: 53 , 1-MAE: 0.9090 , 1-val_avg_o_loss:0.9136 , 1-val_avg_c_loss:0.9047 , 1-val_avg_e_loss:0.9103 , 1-val_avg_a_loss:0.9088 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.59it/s]
# [2024-04-06 02:44:08,109]::3605594554::DEBUG::Epoch: 54 , 1-MAE: 0.9087 , 1-val_avg_o_loss:0.9112 , 1-val_avg_c_loss:0.9041 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9088 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.75it/s]
# [2024-04-06 02:49:08,351]::3605594554::DEBUG::Epoch: 55 , 1-MAE: 0.9090 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9042 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.9085 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.73it/s]
# [2024-04-06 02:54:07,370]::3605594554::DEBUG::Epoch: 56 , 1-MAE: 0.9092 , 1-val_avg_o_loss:0.9134 , 1-val_avg_c_loss:0.9049 , 1-val_avg_e_loss:0.9112 , 1-val_avg_a_loss:0.9085 , 1-val_avg_n_loss:0.9083
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.70it/s]
# [2024-04-06 02:59:06,693]::3605594554::DEBUG::Epoch: 57 , 1-MAE: 0.9084 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9020 , 1-val_avg_e_loss:0.9111 , 1-val_avg_a_loss:0.9084 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.72it/s]
# [2024-04-06 03:04:06,055]::3605594554::DEBUG::Epoch: 58 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9045 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.9093 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.73it/s]
# [2024-04-06 03:09:05,389]::3605594554::DEBUG::Epoch: 59 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9053 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.69it/s]
# [2024-04-06 03:14:05,312]::3605594554::DEBUG::Epoch: 60 , 1-MAE: 0.9089 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9044 , 1-val_avg_e_loss:0.9096 , 1-val_avg_a_loss:0.9095 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 03:19:04,459]::3605594554::DEBUG::Epoch: 61 , 1-MAE: 0.9094 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9046 , 1-val_avg_e_loss:0.9116 , 1-val_avg_a_loss:0.9095 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 03:24:03,772]::3605594554::DEBUG::Epoch: 62 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9045 , 1-val_avg_e_loss:0.9111 , 1-val_avg_a_loss:0.9091 , 1-val_avg_n_loss:0.9087
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.70it/s]
# [2024-04-06 03:29:02,986]::3605594554::DEBUG::Epoch: 63 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9044 , 1-val_avg_e_loss:0.9114 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 03:34:02,158]::3605594554::DEBUG::Epoch: 64 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9035 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9075 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.79it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 03:39:02,041]::3605594554::DEBUG::Epoch: 65 , 1-MAE: 0.9087 , 1-val_avg_o_loss:0.9122 , 1-val_avg_c_loss:0.9042 , 1-val_avg_e_loss:0.9100 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1269/1269 [04:25<00:00,  4.79it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.73it/s]
# [2024-04-06 03:44:01,014]::3605594554::DEBUG::Epoch: 66 , 1-MAE: 0.9095 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9037 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.9099 , 1-val_avg_n_loss:0.9091
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.62it/s]
# [2024-04-06 03:49:00,553]::3605594554::DEBUG::Epoch: 67 , 1-MAE: 0.9089 , 1-val_avg_o_loss:0.9122 , 1-val_avg_c_loss:0.9043 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9083 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 1269/1269 [04:25<00:00,  4.79it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.76it/s]
# [2024-04-06 03:53:59,292]::3605594554::DEBUG::Epoch: 68 , 1-MAE: 0.9088 , 1-val_avg_o_loss:0.9132 , 1-val_avg_c_loss:0.9040 , 1-val_avg_e_loss:0.9112 , 1-val_avg_a_loss:0.9077 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.78it/s]
# [2024-04-06 03:58:58,365]::3605594554::DEBUG::Epoch: 69 , 1-MAE: 0.9092 , 1-val_avg_o_loss:0.9127 , 1-val_avg_c_loss:0.9040 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.9097 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.79it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.73it/s]
# [2024-04-06 04:03:58,173]::3605594554::DEBUG::Epoch: 70 , 1-MAE: 0.9090 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9043 , 1-val_avg_e_loss:0.9114 , 1-val_avg_a_loss:0.9092 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.72it/s]
# [2024-04-06 04:08:57,404]::3605594554::DEBUG::Epoch: 71 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9038 , 1-val_avg_e_loss:0.9111 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.67it/s]
# [2024-04-06 04:13:56,862]::3605594554::DEBUG::Epoch: 72 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9037 , 1-val_avg_e_loss:0.9097 , 1-val_avg_a_loss:0.9082 , 1-val_avg_n_loss:0.9088
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 04:18:56,204]::3605594554::DEBUG::Epoch: 73 , 1-MAE: 0.9096 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9051 , 1-val_avg_e_loss:0.9114 , 1-val_avg_a_loss:0.9094 , 1-val_avg_n_loss:0.9091
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.73it/s]
# [2024-04-06 04:23:55,317]::3605594554::DEBUG::Epoch: 74 , 1-MAE: 0.9094 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9050 , 1-val_avg_e_loss:0.9104 , 1-val_avg_a_loss:0.9096 , 1-val_avg_n_loss:0.9089
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 04:28:55,266]::3605594554::DEBUG::Epoch: 75 , 1-MAE: 0.9088 , 1-val_avg_o_loss:0.9136 , 1-val_avg_c_loss:0.9027 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9088 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.67it/s]
# [2024-04-06 04:33:54,536]::3605594554::DEBUG::Epoch: 76 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9042 , 1-val_avg_e_loss:0.9115 , 1-val_avg_a_loss:0.9089 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 04:38:53,637]::3605594554::DEBUG::Epoch: 77 , 1-MAE: 0.9092 , 1-val_avg_o_loss:0.9134 , 1-val_avg_c_loss:0.9045 , 1-val_avg_e_loss:0.9112 , 1-val_avg_a_loss:0.9086 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.72it/s]
# [2024-04-06 04:43:52,686]::3605594554::DEBUG::Epoch: 78 , 1-MAE: 0.9088 , 1-val_avg_o_loss:0.9135 , 1-val_avg_c_loss:0.9033 , 1-val_avg_e_loss:0.9105 , 1-val_avg_a_loss:0.9084 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.75it/s]
# [2024-04-06 04:48:51,639]::3605594554::DEBUG::Epoch: 79 , 1-MAE: 0.9087 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9036 , 1-val_avg_e_loss:0.9101 , 1-val_avg_a_loss:0.9086 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.74it/s]
# [2024-04-06 04:53:51,744]::3605594554::DEBUG::Epoch: 80 , 1-MAE: 0.9092 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9039 , 1-val_avg_e_loss:0.9111 , 1-val_avg_a_loss:0.9097 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.74it/s]
# [2024-04-06 04:58:50,814]::3605594554::DEBUG::Epoch: 81 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9040 , 1-val_avg_e_loss:0.9100 , 1-val_avg_a_loss:0.9093 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.69it/s]
# [2024-04-06 05:03:50,110]::3605594554::DEBUG::Epoch: 82 , 1-MAE: 0.9089 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9042 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9089 , 1-val_avg_n_loss:0.9073
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.73it/s]
# [2024-04-06 05:08:49,325]::3605594554::DEBUG::Epoch: 83 , 1-MAE: 0.9094 , 1-val_avg_o_loss:0.9132 , 1-val_avg_c_loss:0.9042 , 1-val_avg_e_loss:0.9115 , 1-val_avg_a_loss:0.9094 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.75it/s]
# [2024-04-06 05:13:48,678]::3605594554::DEBUG::Epoch: 84 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9048 , 1-val_avg_e_loss:0.9102 , 1-val_avg_a_loss:0.9079 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.72it/s]
# [2024-04-06 05:18:48,632]::3605594554::DEBUG::Epoch: 85 , 1-MAE: 0.9090 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9044 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9092 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.65it/s]
# [2024-04-06 05:23:47,936]::3605594554::DEBUG::Epoch: 86 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9037 , 1-val_avg_e_loss:0.9111 , 1-val_avg_a_loss:0.9092 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.64it/s]
# [2024-04-06 05:28:47,375]::3605594554::DEBUG::Epoch: 87 , 1-MAE: 0.9084 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9039 , 1-val_avg_e_loss:0.9107 , 1-val_avg_a_loss:0.9096 , 1-val_avg_n_loss:0.9058
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.73it/s]
# [2024-04-06 05:33:46,663]::3605594554::DEBUG::Epoch: 88 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9039 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9090 , 1-val_avg_n_loss:0.9060
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.73it/s]
# [2024-04-06 05:38:46,024]::3605594554::DEBUG::Epoch: 89 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9045 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.9091 , 1-val_avg_n_loss:0.9088
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.77it/s]
# [2024-04-06 05:43:45,988]::3605594554::DEBUG::Epoch: 90 , 1-MAE: 0.9089 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9038 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9092 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.78it/s]
# [2024-04-06 05:48:44,865]::3605594554::DEBUG::Epoch: 91 , 1-MAE: 0.9094 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9048 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9090 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.73it/s]
# [2024-04-06 05:53:43,903]::3605594554::DEBUG::Epoch: 92 , 1-MAE: 0.9095 , 1-val_avg_o_loss:0.9134 , 1-val_avg_c_loss:0.9048 , 1-val_avg_e_loss:0.9114 , 1-val_avg_a_loss:0.9095 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.72it/s]
# [2024-04-06 05:58:43,041]::3605594554::DEBUG::Epoch: 93 , 1-MAE: 0.9090 , 1-val_avg_o_loss:0.9120 , 1-val_avg_c_loss:0.9050 , 1-val_avg_e_loss:0.9108 , 1-val_avg_a_loss:0.9094 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.75it/s]
# [2024-04-06 06:03:42,190]::3605594554::DEBUG::Epoch: 94 , 1-MAE: 0.9090 , 1-val_avg_o_loss:0.9136 , 1-val_avg_c_loss:0.9040 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9088 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 1269/1269 [04:25<00:00,  4.79it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.65it/s]
# [2024-04-06 06:08:42,204]::3605594554::DEBUG::Epoch: 95 , 1-MAE: 0.9088 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9041 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9093 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.62it/s]
# [2024-04-06 06:13:41,671]::3605594554::DEBUG::Epoch: 96 , 1-MAE: 0.9090 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9049 , 1-val_avg_e_loss:0.9114 , 1-val_avg_a_loss:0.9090 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.59it/s]
# [2024-04-06 06:18:41,289]::3605594554::DEBUG::Epoch: 97 , 1-MAE: 0.9084 , 1-val_avg_o_loss:0.9120 , 1-val_avg_c_loss:0.9044 , 1-val_avg_e_loss:0.9101 , 1-val_avg_a_loss:0.9083 , 1-val_avg_n_loss:0.9071
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.62it/s]
# [2024-04-06 06:23:40,584]::3605594554::DEBUG::Epoch: 98 , 1-MAE: 0.9082 , 1-val_avg_o_loss:0.9116 , 1-val_avg_c_loss:0.9031 , 1-val_avg_e_loss:0.9108 , 1-val_avg_a_loss:0.9083 , 1-val_avg_n_loss:0.9075
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.62it/s]
# [2024-04-06 06:28:39,882]::3605594554::DEBUG::Epoch: 99 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9132 , 1-val_avg_c_loss:0.9042 , 1-val_avg_e_loss:0.9107 , 1-val_avg_a_loss:0.9089 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.72it/s]
# [2024-04-06 06:33:40,115]::3605594554::DEBUG::Epoch: 100 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9047 , 1-val_avg_e_loss:0.9116 , 1-val_avg_a_loss:0.9089 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.70it/s]
# [2024-04-06 06:38:39,393]::3605594554::DEBUG::Epoch: 101 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9046 , 1-val_avg_e_loss:0.9107 , 1-val_avg_a_loss:0.9097 , 1-val_avg_n_loss:0.9088
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.64it/s]
# [2024-04-06 06:43:38,935]::3605594554::DEBUG::Epoch: 102 , 1-MAE: 0.9089 , 1-val_avg_o_loss:0.9127 , 1-val_avg_c_loss:0.9039 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9091 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.79it/s]
# [2024-04-06 06:48:37,934]::3605594554::DEBUG::Epoch: 103 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9044 , 1-val_avg_e_loss:0.9112 , 1-val_avg_a_loss:0.9093 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.64it/s]
# [2024-04-06 06:53:37,455]::3605594554::DEBUG::Epoch: 104 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9039 , 1-val_avg_e_loss:0.9095 , 1-val_avg_a_loss:0.9096 , 1-val_avg_n_loss:0.9075
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.65it/s]
# [2024-04-06 06:58:37,958]::3605594554::DEBUG::Epoch: 105 , 1-MAE: 0.9084 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9041 , 1-val_avg_e_loss:0.9107 , 1-val_avg_a_loss:0.9077 , 1-val_avg_n_loss:0.9068
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.72it/s]
# [2024-04-06 07:03:36,985]::3605594554::DEBUG::Epoch: 106 , 1-MAE: 0.9094 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9052 , 1-val_avg_e_loss:0.9112 , 1-val_avg_a_loss:0.9091 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.73it/s]
# [2024-04-06 07:08:36,285]::3605594554::DEBUG::Epoch: 107 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9044 , 1-val_avg_e_loss:0.9099 , 1-val_avg_a_loss:0.9086 , 1-val_avg_n_loss:0.9077
# 100%|██████████| 1269/1269 [04:25<00:00,  4.79it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.66it/s]
# [2024-04-06 07:13:35,413]::3605594554::DEBUG::Epoch: 108 , 1-MAE: 0.9088 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9041 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9082 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 07:18:34,770]::3605594554::DEBUG::Epoch: 109 , 1-MAE: 0.9095 , 1-val_avg_o_loss:0.9134 , 1-val_avg_c_loss:0.9047 , 1-val_avg_e_loss:0.9116 , 1-val_avg_a_loss:0.9098 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.74it/s]
# [2024-04-06 07:23:34,865]::3605594554::DEBUG::Epoch: 110 , 1-MAE: 0.9094 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9041 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9095 , 1-val_avg_n_loss:0.9085
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.63it/s]
# [2024-04-06 07:28:34,248]::3605594554::DEBUG::Epoch: 111 , 1-MAE: 0.9092 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9046 , 1-val_avg_e_loss:0.9112 , 1-val_avg_a_loss:0.9092 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.70it/s]
# [2024-04-06 07:33:33,593]::3605594554::DEBUG::Epoch: 112 , 1-MAE: 0.9092 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9043 , 1-val_avg_e_loss:0.9115 , 1-val_avg_a_loss:0.9096 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.75it/s]
# [2024-04-06 07:38:32,813]::3605594554::DEBUG::Epoch: 113 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9048 , 1-val_avg_e_loss:0.9111 , 1-val_avg_a_loss:0.9091 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.78it/s]
# [2024-04-06 07:43:31,997]::3605594554::DEBUG::Epoch: 114 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9043 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9090 , 1-val_avg_n_loss:0.9084
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.61it/s]
# [2024-04-06 07:48:32,343]::3605594554::DEBUG::Epoch: 115 , 1-MAE: 0.9085 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9036 , 1-val_avg_e_loss:0.9106 , 1-val_avg_a_loss:0.9079 , 1-val_avg_n_loss:0.9081
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:32<00:00, 12.74it/s]
# [2024-04-06 07:53:31,497]::3605594554::DEBUG::Epoch: 116 , 1-MAE: 0.9087 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9038 , 1-val_avg_e_loss:0.9100 , 1-val_avg_a_loss:0.9090 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.69it/s]
# [2024-04-06 07:58:30,812]::3605594554::DEBUG::Epoch: 117 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9044 , 1-val_avg_e_loss:0.9107 , 1-val_avg_a_loss:0.9093 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.66it/s]
# [2024-04-06 08:03:30,277]::3605594554::DEBUG::Epoch: 118 , 1-MAE: 0.9088 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9037 , 1-val_avg_e_loss:0.9115 , 1-val_avg_a_loss:0.9087 , 1-val_avg_n_loss:0.9074
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.71it/s]
# [2024-04-06 08:08:29,682]::3605594554::DEBUG::Epoch: 119 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9042 , 1-val_avg_e_loss:0.9112 , 1-val_avg_a_loss:0.9090 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 1269/1269 [04:25<00:00,  4.78it/s]
# 100%|██████████| 420/420 [00:33<00:00, 12.70it/s]
# [2024-04-06 08:13:29,973]::3605594554::DEBUG::Epoch: 120 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9136 , 1-val_avg_c_loss:0.9043 , 1-val_avg_e_loss:0.9112 , 1-val_avg_a_loss:0.9094 , 1-val_avg_n_loss:0.9083

# %%
# from torchinfo import summary

# summary(model, input_size = (4,15,4,3,224,224))

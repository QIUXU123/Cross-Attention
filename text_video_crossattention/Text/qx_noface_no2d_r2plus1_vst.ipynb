# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import os
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import random
import cv2
# from vgg16 import VGG16_LSTM
import pickle
import torch.nn as nn
import torch
import datetime
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms, utils, models
from torch.utils.data import Dataset, DataLoader
from facenet_pytorch import MTCNN
import logging
import torch
import torch.nn as nn
from qx_noface_no2d_video_swin_transformer01 import SwinTransformer3D
import gc
from einops import rearrange
from tqdm import tqdm
# from kw_r2plus1d_video_swin_transformer import SwinTransformer3D
batchsz = 4
frame_nums=15
start_epoch = 0
test_flage=False
model_name ="fullshot and xlm-roberta"
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('[%(asctime)s]::%(module)s::%(levelname)s::%(message)s')
streamHandler = logging.StreamHandler()
streamHandler.setFormatter(formatter)
fileHandler = logging.FileHandler('./LOG/personalityLog.log')
fileHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.addHandler(fileHandler)
USE_CUDA = torch.cuda.is_available()
# device = torch.device('cuda:1' if USE_CUDA else 'cpu')

# %%
logger.debug('============={}+Video swin transformerTrain Strat!============='.format(model_name))
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:1' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:', device)
# Out:
# [2024-03-21 16:53:10,066]::387438924::DEBUG::=============fullshot and xlm-roberta+Video swin transformerTrain Strat!=============
# True
# 학습을 진행하는 기기: cuda:1

# %%
def select_frame_data(datas,frame_num):
    data_set=[]
    begin_num=0
    x=128/frame_num
    indexes=[None] * frame_num
    for i in range(frame_num):
        indexes[i]=int(begin_num)
        begin_num+=x
    for data in datas:
        video_frames = [None] * 2
        video_frames[0]=[]
        video_frames[1]=[]
        for index in indexes:
            video_frames[0].append(data[0][index])
        video_frames[1].append(data[1])
        data_set.append(video_frames)
        del video_frames
        del data 
        gc.collect()
    del datas
    gc.collect()
    return data_set
print(1)
# Out:
# 1

# %%
def getdata(pathname,datatype):
    if datatype=="train":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            # train_data_set.extend(pickle.load(output_file))
            final_data_set.extend(pickle.load(output_file))
            # print(i)
        return final_data_set
    elif datatype=="valid":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            valid_data_set=[]
            final_data_set.extend(pickle.load(output_file))
            del valid_data_set
        return final_data_set
print(1)
# Out:
# 1

# %%
def datasize(type,batchsz):
    if type=='train':
        i=5076#5967
        while True:
            if i%batchsz==0:
                return i
            else:
                i-=1
    else:
        i=1700#1986
        while True:
            if i%batchsz==0:
                return i
            else:
                i-=1
print(1)
# Out:
# 1

# %%
save_model_file_path = './save_swintransformer_folder/{}_{}.{}'
mtcnn= MTCNN(image_size=224, margin=0, min_face_size= 20, thresholds=[0.6, 0.7, 0.7], post_process=True)
# test_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/test_set.dat","test")
# test_set_data=test_set_data[:datasize("test",batchsz)]
print(1)
# Out:
# 1

# %%
def reshape_to_expected_traininput(dataset: List[Tuple[ np.ndarray, np.ndarray]]) -> Tuple[
     np.ndarray, np.ndarray]:
    result=[]
    for i in range(0, len(dataset[0])):
        result.append((dataset[0][i],dataset[1][i],dataset[2][i],dataset[3][i],dataset[4][i],dataset[5][i]))
    result = result[:datasize("train",batchsz)]
    x0_list = []
    x1_list = []
    x2_list = []
    x3_list = []
    x4_list = []
    x5_list = []
    for i in range(0, len(result)):
        x0_list.append(result[i][0])
        x1_list.append(result[i][1])
        x2_list.append(result[i][2])
        x3_list.append(result[i][3])
        x4_list.append(result[i][4])
        x5_list.append(result[i][5])
    return (np.stack(x0_list), np.stack(x1_list), np.stack(x2_list),np.stack(x3_list), np.stack(x4_list), np.stack(x5_list))
print(1)
# Out:
# 1

# %%
def reshape_to_expected_validinput(dataset: List[Tuple[ np.ndarray, np.ndarray]]) -> Tuple[
     np.ndarray, np.ndarray]:
    result=[]
    for i in range(0, len(dataset[0])):
        result.append((dataset[0][i],dataset[1][i],dataset[2][i],dataset[3][i],dataset[4][i],dataset[5][i]))
    result = result[:datasize("valid",batchsz)]
    x0_list = []
    x1_list = []
    x2_list = []
    x3_list = []
    x4_list = []
    x5_list = []
    for i in range(0, len(result)):
        x0_list.append(result[i][0])
        x1_list.append(result[i][1])
        x2_list.append(result[i][2])
        x3_list.append(result[i][3])
        x4_list.append(result[i][4])
        x5_list.append(result[i][5])
    return (np.stack(x0_list), np.stack(x1_list), np.stack(x2_list),np.stack(x3_list), np.stack(x4_list), np.stack(x5_list))
print(1)
# Out:
# 1

# %%
validation_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/multidata/1700valid_set.dat","valid")
validation_set_data=reshape_to_expected_validinput(validation_set_data)
print(1)
# Out:
# 1

# %%
train_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/multidata/5076train_set.dat","train")
train_set_data=reshape_to_expected_traininput(train_set_data)
print(1)
# Out:
# 1

# %%
def imagecrop(imagedata,batchsz):
    # convert_tensor= transforms.ToTensor()
    output=[]
    for j in range(batchsz):#비디오 데이터 batchsz(9) 개 있다
        firstoutput=[]
        for i in range(len(imagedata[j])):#imagedata에 15개의 프레임이 있다
            # temp = convert_tensor(imagedata[i])
            #이미지를 나누
            temp = imagedata[j][i].unfold(1,112,112).unfold(2,112,112)
            temp = rearrange(temp, 'c h1 w1 h w -> (h1 w1) c h w')
            firstoutput.append(temp)
        firstoutput = torch.stack(firstoutput,0)
        output.append(firstoutput)
    output = torch.stack(output,0)
    return output
print(1)
# Out:
# 1

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
])
print(1)
# Out:
# 1

# %%
class ChalearnDataset(Dataset):
    def __init__(self,textdata,tagdata,transform=None):
        self.textdata=textdata
        self.tagdata=tagdata
        self.transform = transform  # 표준화 여부
    def __len__(self):
        return len(self.textdata)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()#텐서의 경우 목록으로 돌아가기
        textdata = self.textdata[idx]
        big_five_sorces=self.tagdata[idx]
        big_five_sorces = torch.FloatTensor(big_five_sorces)
        return textdata,big_five_sorces
print(1)
# Out:
# 1

# %%
num_workerssz = 20
lr = 3e-05
epochs = 120
#device = torch.device('cuda')
# train_set_data = reshape_to_expected_input(train_set_data)
# val_set_data = reshape_to_expected_input(validation_set_data)
print(1)
# Out:
# 1

# %%
train_set_data = ChalearnDataset(textdata=train_set_data[4],tagdata=train_set_data[5],transform=transform)
val_set_data = ChalearnDataset(textdata=validation_set_data[4], tagdata=validation_set_data[5],transform=transform)
train_dataloader = DataLoader(dataset=train_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
val_dataloader = DataLoader(dataset=val_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
max_value=0
print(1)
# Out:
# 1

# %%
model=SwinTransformer3D()#num_frames=frame_nums,batchsz = batchsz
model.to(device)
criterion = torch.nn.L1Loss().to(device)  # 손실함수
optimizer = torch.optim.AdamW(model.parameters(), lr=lr) # 옵티마이저

if test_flage==True:
    checkpoint=torch.load(save_model_file_path.format('model',start_epoch,'pth'), map_location=device)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    # criterion.load_state_dict(checkpoint["loss"])
train_avg_loss0=[]
val_avg_loss0=[]
print(1)
# Out:
# Some weights of AlbertModel were not initialized from the model checkpoint at text_model/ and are newly initialized: ['albert.pooler.weight', 'albert.pooler.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/ssrlab/anaconda3/envs/qx/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 1

# %%
# from torchinfo import summary

# summary(model, input_size = ((8,15,224,224,3),(8,24,1319,1)), col_names = ['input_size','output_size','num_params'])

# %%
def extract_ocean(data,batch_size):
    o=[]
    c=[]
    e=[]
    a=[]
    n=[]
    for i in range(batch_size):
        o.append(data[i][0].item())
        c.append(data[i][1].item())
        e.append(data[i][2].item())
        a.append(data[i][3].item())
        n.append(data[i][4].item())
    o = torch.tensor(o) 
    c = torch.tensor(c) 
    e = torch.tensor(e) 
    a = torch.tensor(a) 
    n = torch.tensor(n) 
    return o,c,e,a,n

# %%
with torch.cuda.device(1):
    for i in range(start_epoch, epochs):
        train_avg_loss = 0
        val_avg_loss = 0
        train_avg_o_loss = 0
        train_avg_c_loss = 0
        train_avg_e_loss = 0
        train_avg_a_loss = 0
        train_avg_n_loss = 0
        val_avg_o_loss = 0
        val_avg_c_loss = 0
        val_avg_e_loss = 0
        val_avg_a_loss = 0
        val_avg_n_loss = 0
        for textdata,big_five_data in tqdm(train_dataloader):
            big_five_data=big_five_data.permute(0,2,1)
            big_five_data=big_five_data.squeeze()
            big_five_data = big_five_data.to(device)
            optimizer.zero_grad()  # 기울기가 0이 됩니다.
            hypothesis = model(textdata)  # 모델의 예측 결과를 저장합니다.
            loss = criterion(hypothesis, big_five_data)  # 예측된 결과와 실제 태그 사이의 손실 값을 저장합니다.
            loss.backward()  # 역방향 전파입니다. 
            optimizer.step()  
            train_avg_loss += loss  
        train_avg_loss=train_avg_loss/len(train_dataloader)
        with torch.no_grad():#validate
            for textdata,big_five_data in tqdm(val_dataloader):
                big_five_data=big_five_data.permute(0,2,1)
                big_five_data=big_five_data.squeeze()
                big_five_data = big_five_data.to(device)
                hypothesis = model(textdata)
                val_loss = criterion(hypothesis, big_five_data)
                hypothesiso,hypothesisc,hypothesise,hypothesisa,hypothesisn=extract_ocean(hypothesis,batchsz)
                big_five_datao,big_five_datac,big_five_datae,big_five_dataa,big_five_datan=extract_ocean(big_five_data,batchsz)
                val_o_loss = criterion(hypothesiso, big_five_datao) 
                val_c_loss = criterion(hypothesisc, big_five_datac) 
                val_e_loss = criterion(hypothesise, big_five_datae) 
                val_a_loss = criterion(hypothesisa, big_five_dataa) 
                val_n_loss = criterion(hypothesisn, big_five_datan)  
                val_avg_loss += val_loss
                val_avg_o_loss += val_o_loss
                val_avg_c_loss += val_c_loss
                val_avg_e_loss += val_e_loss
                val_avg_a_loss += val_a_loss
                val_avg_n_loss += val_n_loss
            val_avg_loss=val_avg_loss/len(val_dataloader)
            val_avg_o_loss=val_avg_o_loss/len(val_dataloader)
            val_avg_c_loss=val_avg_c_loss/len(val_dataloader)
            val_avg_e_loss=val_avg_e_loss/len(val_dataloader)
            val_avg_a_loss=val_avg_a_loss/len(val_dataloader)
            val_avg_n_loss=val_avg_n_loss/len(val_dataloader)
        torch.cuda.empty_cache()
        # if (1-val_avg_loss)>=(1-max_value):
        max_value=val_avg_loss
        start_epoch+=1
        if (i + 1) % 5 == 0:
            torch.save({
                    'epoch': i+1,
                    'model': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'loss': val_avg_loss,
                }, save_model_file_path.format('model',start_epoch,'pth'))
        logger.debug('Epoch: {} , 1-MAE: {:.4f} , 1-val_avg_o_loss:{:.4f} , 1-val_avg_c_loss:{:.4f} , 1-val_avg_e_loss:{:.4f} , 1-val_avg_a_loss:{:.4f} , 1-val_avg_n_loss:{:.4f}'.format(i+1, 1-val_avg_loss, 1-val_avg_o_loss, 1-val_avg_c_loss, 1-val_avg_e_loss, 1-val_avg_a_loss,1-val_avg_n_loss))
# Out:
#   0%|          | 0/1269 [00:00<?, ?it/s]We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# 100%|██████████| 1269/1269 [01:13<00:00, 17.19it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.13it/s]
# [2024-03-21 16:55:52,201]::4171747451::DEBUG::Epoch: 1 , 1-MAE: 0.8750 , 1-val_avg_o_loss:0.8725 , 1-val_avg_c_loss:0.8501 , 1-val_avg_e_loss:0.8969 , 1-val_avg_a_loss:0.8743 , 1-val_avg_n_loss:0.8813
# 100%|██████████| 1269/1269 [01:13<00:00, 17.26it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.37it/s]
# [2024-03-21 16:57:15,949]::4171747451::DEBUG::Epoch: 2 , 1-MAE: 0.8654 , 1-val_avg_o_loss:0.8679 , 1-val_avg_c_loss:0.8709 , 1-val_avg_e_loss:0.8786 , 1-val_avg_a_loss:0.8256 , 1-val_avg_n_loss:0.8841
# 100%|██████████| 1269/1269 [01:13<00:00, 17.33it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.27it/s]
# [2024-03-21 16:58:39,604]::4171747451::DEBUG::Epoch: 3 , 1-MAE: 0.8830 , 1-val_avg_o_loss:0.8735 , 1-val_avg_c_loss:0.8816 , 1-val_avg_e_loss:0.9006 , 1-val_avg_a_loss:0.8722 , 1-val_avg_n_loss:0.8869
# 100%|██████████| 1269/1269 [01:13<00:00, 17.26it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.27it/s]
# [2024-03-21 17:00:03,754]::4171747451::DEBUG::Epoch: 4 , 1-MAE: 0.8820 , 1-val_avg_o_loss:0.8811 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.8995 , 1-val_avg_a_loss:0.8744 , 1-val_avg_n_loss:0.8769
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.27it/s]
# [2024-03-21 17:01:29,099]::4171747451::DEBUG::Epoch: 5 , 1-MAE: 0.8807 , 1-val_avg_o_loss:0.8811 , 1-val_avg_c_loss:0.8728 , 1-val_avg_e_loss:0.8974 , 1-val_avg_a_loss:0.8682 , 1-val_avg_n_loss:0.8842
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.46it/s]
# [2024-03-21 17:02:53,578]::4171747451::DEBUG::Epoch: 6 , 1-MAE: 0.8780 , 1-val_avg_o_loss:0.8761 , 1-val_avg_c_loss:0.8704 , 1-val_avg_e_loss:0.8968 , 1-val_avg_a_loss:0.8635 , 1-val_avg_n_loss:0.8830
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.67it/s]
# [2024-03-21 17:04:18,038]::4171747451::DEBUG::Epoch: 7 , 1-MAE: 0.8819 , 1-val_avg_o_loss:0.8814 , 1-val_avg_c_loss:0.8782 , 1-val_avg_e_loss:0.8936 , 1-val_avg_a_loss:0.8726 , 1-val_avg_n_loss:0.8838
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.85it/s]
# [2024-03-21 17:05:42,572]::4171747451::DEBUG::Epoch: 8 , 1-MAE: 0.8811 , 1-val_avg_o_loss:0.8811 , 1-val_avg_c_loss:0.8709 , 1-val_avg_e_loss:0.8945 , 1-val_avg_a_loss:0.8752 , 1-val_avg_n_loss:0.8838
# 100%|██████████| 1269/1269 [01:14<00:00, 17.15it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.26it/s]
# [2024-03-21 17:07:07,266]::4171747451::DEBUG::Epoch: 9 , 1-MAE: 0.8822 , 1-val_avg_o_loss:0.8797 , 1-val_avg_c_loss:0.8763 , 1-val_avg_e_loss:0.8987 , 1-val_avg_a_loss:0.8726 , 1-val_avg_n_loss:0.8837
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.63it/s]
# [2024-03-21 17:08:32,505]::4171747451::DEBUG::Epoch: 10 , 1-MAE: 0.8817 , 1-val_avg_o_loss:0.8807 , 1-val_avg_c_loss:0.8753 , 1-val_avg_e_loss:0.8981 , 1-val_avg_a_loss:0.8744 , 1-val_avg_n_loss:0.8802
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.29it/s]
# [2024-03-21 17:09:56,686]::4171747451::DEBUG::Epoch: 11 , 1-MAE: 0.8802 , 1-val_avg_o_loss:0.8780 , 1-val_avg_c_loss:0.8778 , 1-val_avg_e_loss:0.8931 , 1-val_avg_a_loss:0.8748 , 1-val_avg_n_loss:0.8771
# 100%|██████████| 1269/1269 [01:13<00:00, 17.25it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.96it/s]
# [2024-03-21 17:11:20,504]::4171747451::DEBUG::Epoch: 12 , 1-MAE: 0.8795 , 1-val_avg_o_loss:0.8786 , 1-val_avg_c_loss:0.8727 , 1-val_avg_e_loss:0.8871 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8839
# 100%|██████████| 1269/1269 [01:13<00:00, 17.21it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.07it/s]
# [2024-03-21 17:12:44,949]::4171747451::DEBUG::Epoch: 13 , 1-MAE: 0.8805 , 1-val_avg_o_loss:0.8767 , 1-val_avg_c_loss:0.8783 , 1-val_avg_e_loss:0.8986 , 1-val_avg_a_loss:0.8711 , 1-val_avg_n_loss:0.8780
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.75it/s]
# [2024-03-21 17:14:09,394]::4171747451::DEBUG::Epoch: 14 , 1-MAE: 0.8817 , 1-val_avg_o_loss:0.8816 , 1-val_avg_c_loss:0.8740 , 1-val_avg_e_loss:0.8964 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8810
# 100%|██████████| 1269/1269 [01:13<00:00, 17.23it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.20it/s]
# [2024-03-21 17:15:34,291]::4171747451::DEBUG::Epoch: 15 , 1-MAE: 0.8800 , 1-val_avg_o_loss:0.8817 , 1-val_avg_c_loss:0.8757 , 1-val_avg_e_loss:0.8982 , 1-val_avg_a_loss:0.8606 , 1-val_avg_n_loss:0.8838
# 100%|██████████| 1269/1269 [01:13<00:00, 17.24it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.07it/s]
# [2024-03-21 17:16:58,591]::4171747451::DEBUG::Epoch: 16 , 1-MAE: 0.8828 , 1-val_avg_o_loss:0.8784 , 1-val_avg_c_loss:0.8784 , 1-val_avg_e_loss:0.8996 , 1-val_avg_a_loss:0.8736 , 1-val_avg_n_loss:0.8842
# 100%|██████████| 1269/1269 [01:13<00:00, 17.15it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.05it/s]
# [2024-03-21 17:18:23,273]::4171747451::DEBUG::Epoch: 17 , 1-MAE: 0.8813 , 1-val_avg_o_loss:0.8805 , 1-val_avg_c_loss:0.8784 , 1-val_avg_e_loss:0.8881 , 1-val_avg_a_loss:0.8752 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:14<00:00, 17.14it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.00it/s]
# [2024-03-21 17:19:48,032]::4171747451::DEBUG::Epoch: 18 , 1-MAE: 0.8799 , 1-val_avg_o_loss:0.8793 , 1-val_avg_c_loss:0.8691 , 1-val_avg_e_loss:0.8990 , 1-val_avg_a_loss:0.8695 , 1-val_avg_n_loss:0.8827
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.13it/s]
# [2024-03-21 17:21:12,664]::4171747451::DEBUG::Epoch: 19 , 1-MAE: 0.8831 , 1-val_avg_o_loss:0.8794 , 1-val_avg_c_loss:0.8776 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8747 , 1-val_avg_n_loss:0.8841
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.44it/s]
# [2024-03-21 17:22:37,930]::4171747451::DEBUG::Epoch: 20 , 1-MAE: 0.8770 , 1-val_avg_o_loss:0.8773 , 1-val_avg_c_loss:0.8728 , 1-val_avg_e_loss:0.8896 , 1-val_avg_a_loss:0.8633 , 1-val_avg_n_loss:0.8821
# 100%|██████████| 1269/1269 [01:14<00:00, 17.14it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.85it/s]
# [2024-03-21 17:24:02,492]::4171747451::DEBUG::Epoch: 21 , 1-MAE: 0.8807 , 1-val_avg_o_loss:0.8675 , 1-val_avg_c_loss:0.8782 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8748 , 1-val_avg_n_loss:0.8829
# 100%|██████████| 1269/1269 [01:13<00:00, 17.22it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.02it/s]
# [2024-03-21 17:25:26,634]::4171747451::DEBUG::Epoch: 22 , 1-MAE: 0.8817 , 1-val_avg_o_loss:0.8799 , 1-val_avg_c_loss:0.8742 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8737 , 1-val_avg_n_loss:0.8805
# 100%|██████████| 1269/1269 [01:13<00:00, 17.23it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.96it/s]
# [2024-03-21 17:26:50,755]::4171747451::DEBUG::Epoch: 23 , 1-MAE: 0.8823 , 1-val_avg_o_loss:0.8786 , 1-val_avg_c_loss:0.8775 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8751 , 1-val_avg_n_loss:0.8805
# 100%|██████████| 1269/1269 [01:13<00:00, 17.22it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.88it/s]
# [2024-03-21 17:28:14,934]::4171747451::DEBUG::Epoch: 24 , 1-MAE: 0.8828 , 1-val_avg_o_loss:0.8813 , 1-val_avg_c_loss:0.8776 , 1-val_avg_e_loss:0.8997 , 1-val_avg_a_loss:0.8745 , 1-val_avg_n_loss:0.8811
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.18it/s]
# [2024-03-21 17:29:40,283]::4171747451::DEBUG::Epoch: 25 , 1-MAE: 0.8798 , 1-val_avg_o_loss:0.8759 , 1-val_avg_c_loss:0.8777 , 1-val_avg_e_loss:0.8869 , 1-val_avg_a_loss:0.8750 , 1-val_avg_n_loss:0.8833
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.54it/s]
# [2024-03-21 17:31:04,813]::4171747451::DEBUG::Epoch: 26 , 1-MAE: 0.8813 , 1-val_avg_o_loss:0.8810 , 1-val_avg_c_loss:0.8756 , 1-val_avg_e_loss:0.8956 , 1-val_avg_a_loss:0.8706 , 1-val_avg_n_loss:0.8839
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.05it/s]
# [2024-03-21 17:32:29,410]::4171747451::DEBUG::Epoch: 27 , 1-MAE: 0.8796 , 1-val_avg_o_loss:0.8804 , 1-val_avg_c_loss:0.8785 , 1-val_avg_e_loss:0.8795 , 1-val_avg_a_loss:0.8751 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.95it/s]
# [2024-03-21 17:33:53,877]::4171747451::DEBUG::Epoch: 28 , 1-MAE: 0.8789 , 1-val_avg_o_loss:0.8818 , 1-val_avg_c_loss:0.8645 , 1-val_avg_e_loss:0.8982 , 1-val_avg_a_loss:0.8703 , 1-val_avg_n_loss:0.8795
# 100%|██████████| 1269/1269 [01:13<00:00, 17.24it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.46it/s]
# [2024-03-21 17:35:17,814]::4171747451::DEBUG::Epoch: 29 , 1-MAE: 0.8814 , 1-val_avg_o_loss:0.8814 , 1-val_avg_c_loss:0.8690 , 1-val_avg_e_loss:0.8984 , 1-val_avg_a_loss:0.8748 , 1-val_avg_n_loss:0.8836
# 100%|██████████| 1269/1269 [01:13<00:00, 17.25it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.01it/s]
# [2024-03-21 17:36:42,873]::4171747451::DEBUG::Epoch: 30 , 1-MAE: 0.8818 , 1-val_avg_o_loss:0.8730 , 1-val_avg_c_loss:0.8784 , 1-val_avg_e_loss:0.8990 , 1-val_avg_a_loss:0.8744 , 1-val_avg_n_loss:0.8840
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.98it/s]
# [2024-03-21 17:38:07,421]::4171747451::DEBUG::Epoch: 31 , 1-MAE: 0.8816 , 1-val_avg_o_loss:0.8737 , 1-val_avg_c_loss:0.8770 , 1-val_avg_e_loss:0.8979 , 1-val_avg_a_loss:0.8750 , 1-val_avg_n_loss:0.8842
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.37it/s]
# [2024-03-21 17:39:32,034]::4171747451::DEBUG::Epoch: 32 , 1-MAE: 0.8817 , 1-val_avg_o_loss:0.8790 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.8942 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8817
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.99it/s]
# [2024-03-21 17:40:56,286]::4171747451::DEBUG::Epoch: 33 , 1-MAE: 0.8833 , 1-val_avg_o_loss:0.8819 , 1-val_avg_c_loss:0.8748 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.24it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.18it/s]
# [2024-03-21 17:42:20,320]::4171747451::DEBUG::Epoch: 34 , 1-MAE: 0.8809 , 1-val_avg_o_loss:0.8798 , 1-val_avg_c_loss:0.8756 , 1-val_avg_e_loss:0.8916 , 1-val_avg_a_loss:0.8736 , 1-val_avg_n_loss:0.8840
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.21it/s]
# [2024-03-21 17:43:45,417]::4171747451::DEBUG::Epoch: 35 , 1-MAE: 0.8830 , 1-val_avg_o_loss:0.8811 , 1-val_avg_c_loss:0.8765 , 1-val_avg_e_loss:0.8979 , 1-val_avg_a_loss:0.8748 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.25it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.36it/s]
# [2024-03-21 17:45:09,383]::4171747451::DEBUG::Epoch: 36 , 1-MAE: 0.8819 , 1-val_avg_o_loss:0.8787 , 1-val_avg_c_loss:0.8744 , 1-val_avg_e_loss:0.8998 , 1-val_avg_a_loss:0.8730 , 1-val_avg_n_loss:0.8837
# 100%|██████████| 1269/1269 [01:13<00:00, 17.23it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.37it/s]
# [2024-03-21 17:46:33,660]::4171747451::DEBUG::Epoch: 37 , 1-MAE: 0.8821 , 1-val_avg_o_loss:0.8769 , 1-val_avg_c_loss:0.8753 , 1-val_avg_e_loss:0.8995 , 1-val_avg_a_loss:0.8751 , 1-val_avg_n_loss:0.8834
# 100%|██████████| 1269/1269 [01:13<00:00, 17.25it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.39it/s]
# [2024-03-21 17:47:57,845]::4171747451::DEBUG::Epoch: 38 , 1-MAE: 0.8835 , 1-val_avg_o_loss:0.8805 , 1-val_avg_c_loss:0.8782 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8751 , 1-val_avg_n_loss:0.8837
# 100%|██████████| 1269/1269 [01:13<00:00, 17.21it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.11it/s]
# [2024-03-21 17:49:22,305]::4171747451::DEBUG::Epoch: 39 , 1-MAE: 0.8818 , 1-val_avg_o_loss:0.8766 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.8997 , 1-val_avg_a_loss:0.8710 , 1-val_avg_n_loss:0.8836
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.95it/s]
# [2024-03-21 17:50:47,359]::4171747451::DEBUG::Epoch: 40 , 1-MAE: 0.8837 , 1-val_avg_o_loss:0.8818 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.8994 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8836
# 100%|██████████| 1269/1269 [01:13<00:00, 17.21it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.54it/s]
# [2024-03-21 17:52:11,666]::4171747451::DEBUG::Epoch: 41 , 1-MAE: 0.8821 , 1-val_avg_o_loss:0.8767 , 1-val_avg_c_loss:0.8785 , 1-val_avg_e_loss:0.8996 , 1-val_avg_a_loss:0.8741 , 1-val_avg_n_loss:0.8814
# 100%|██████████| 1269/1269 [01:14<00:00, 17.10it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.38it/s]
# [2024-03-21 17:53:36,494]::4171747451::DEBUG::Epoch: 42 , 1-MAE: 0.8825 , 1-val_avg_o_loss:0.8809 , 1-val_avg_c_loss:0.8764 , 1-val_avg_e_loss:0.8958 , 1-val_avg_a_loss:0.8747 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.10it/s]
# [2024-03-21 17:55:00,980]::4171747451::DEBUG::Epoch: 43 , 1-MAE: 0.8833 , 1-val_avg_o_loss:0.8792 , 1-val_avg_c_loss:0.8779 , 1-val_avg_e_loss:0.8996 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.21it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.18it/s]
# [2024-03-21 17:56:25,437]::4171747451::DEBUG::Epoch: 44 , 1-MAE: 0.8825 , 1-val_avg_o_loss:0.8798 , 1-val_avg_c_loss:0.8750 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8751 , 1-val_avg_n_loss:0.8829
# 100%|██████████| 1269/1269 [01:13<00:00, 17.19it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.72it/s]
# [2024-03-21 17:57:50,584]::4171747451::DEBUG::Epoch: 45 , 1-MAE: 0.8818 , 1-val_avg_o_loss:0.8772 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.8975 , 1-val_avg_a_loss:0.8713 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.27it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.41it/s]
# [2024-03-21 17:59:14,428]::4171747451::DEBUG::Epoch: 46 , 1-MAE: 0.8834 , 1-val_avg_o_loss:0.8818 , 1-val_avg_c_loss:0.8787 , 1-val_avg_e_loss:0.8972 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8838
# 100%|██████████| 1269/1269 [01:13<00:00, 17.25it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.07it/s]
# [2024-03-21 18:00:38,466]::4171747451::DEBUG::Epoch: 47 , 1-MAE: 0.8830 , 1-val_avg_o_loss:0.8811 , 1-val_avg_c_loss:0.8771 , 1-val_avg_e_loss:0.8975 , 1-val_avg_a_loss:0.8749 , 1-val_avg_n_loss:0.8846
# 100%|██████████| 1269/1269 [01:13<00:00, 17.26it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.47it/s]
# [2024-03-21 18:02:02,822]::4171747451::DEBUG::Epoch: 48 , 1-MAE: 0.8833 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8779 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8752 , 1-val_avg_n_loss:0.8814
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.15it/s]
# [2024-03-21 18:03:27,460]::4171747451::DEBUG::Epoch: 49 , 1-MAE: 0.8785 , 1-val_avg_o_loss:0.8813 , 1-val_avg_c_loss:0.8739 , 1-val_avg_e_loss:0.8955 , 1-val_avg_a_loss:0.8737 , 1-val_avg_n_loss:0.8679
# 100%|██████████| 1269/1269 [01:13<00:00, 17.21it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.35it/s]
# [2024-03-21 18:04:52,606]::4171747451::DEBUG::Epoch: 50 , 1-MAE: 0.8808 , 1-val_avg_o_loss:0.8798 , 1-val_avg_c_loss:0.8719 , 1-val_avg_e_loss:0.8983 , 1-val_avg_a_loss:0.8741 , 1-val_avg_n_loss:0.8800
# 100%|██████████| 1269/1269 [01:13<00:00, 17.23it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.48it/s]
# [2024-03-21 18:06:16,890]::4171747451::DEBUG::Epoch: 51 , 1-MAE: 0.8834 , 1-val_avg_o_loss:0.8821 , 1-val_avg_c_loss:0.8777 , 1-val_avg_e_loss:0.8980 , 1-val_avg_a_loss:0.8750 , 1-val_avg_n_loss:0.8841
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.39it/s]
# [2024-03-21 18:07:41,459]::4171747451::DEBUG::Epoch: 52 , 1-MAE: 0.8835 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8785 , 1-val_avg_e_loss:0.8997 , 1-val_avg_a_loss:0.8732 , 1-val_avg_n_loss:0.8842
# 100%|██████████| 1269/1269 [01:13<00:00, 17.22it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.55it/s]
# [2024-03-21 18:09:05,748]::4171747451::DEBUG::Epoch: 53 , 1-MAE: 0.8818 , 1-val_avg_o_loss:0.8730 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8735 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.99it/s]
# [2024-03-21 18:10:30,036]::4171747451::DEBUG::Epoch: 54 , 1-MAE: 0.8797 , 1-val_avg_o_loss:0.8740 , 1-val_avg_c_loss:0.8754 , 1-val_avg_e_loss:0.8951 , 1-val_avg_a_loss:0.8732 , 1-val_avg_n_loss:0.8811
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.94it/s]
# [2024-03-21 18:11:55,410]::4171747451::DEBUG::Epoch: 55 , 1-MAE: 0.8836 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8760 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.39it/s]
# [2024-03-21 18:13:19,941]::4171747451::DEBUG::Epoch: 56 , 1-MAE: 0.8838 , 1-val_avg_o_loss:0.8818 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.8998 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8835
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.81it/s]
# [2024-03-21 18:14:44,495]::4171747451::DEBUG::Epoch: 57 , 1-MAE: 0.8823 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8782 , 1-val_avg_e_loss:0.8991 , 1-val_avg_a_loss:0.8688 , 1-val_avg_n_loss:0.8835
# 100%|██████████| 1269/1269 [01:13<00:00, 17.22it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.44it/s]
# [2024-03-21 18:16:08,817]::4171747451::DEBUG::Epoch: 58 , 1-MAE: 0.8818 , 1-val_avg_o_loss:0.8782 , 1-val_avg_c_loss:0.8762 , 1-val_avg_e_loss:0.8987 , 1-val_avg_a_loss:0.8721 , 1-val_avg_n_loss:0.8836
# 100%|██████████| 1269/1269 [01:14<00:00, 17.11it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.04it/s]
# [2024-03-21 18:17:33,709]::4171747451::DEBUG::Epoch: 59 , 1-MAE: 0.8840 , 1-val_avg_o_loss:0.8817 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.19it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.33it/s]
# [2024-03-21 18:18:58,981]::4171747451::DEBUG::Epoch: 60 , 1-MAE: 0.8835 , 1-val_avg_o_loss:0.8819 , 1-val_avg_c_loss:0.8785 , 1-val_avg_e_loss:0.8992 , 1-val_avg_a_loss:0.8732 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.25it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.80it/s]
# [2024-03-21 18:20:23,057]::4171747451::DEBUG::Epoch: 61 , 1-MAE: 0.8838 , 1-val_avg_o_loss:0.8815 , 1-val_avg_c_loss:0.8783 , 1-val_avg_e_loss:0.8996 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8840
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.99it/s]
# [2024-03-21 18:21:47,443]::4171747451::DEBUG::Epoch: 62 , 1-MAE: 0.8839 , 1-val_avg_o_loss:0.8812 , 1-val_avg_c_loss:0.8784 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8756 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.26it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.24it/s]
# [2024-03-21 18:23:11,600]::4171747451::DEBUG::Epoch: 63 , 1-MAE: 0.8825 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8759 , 1-val_avg_e_loss:0.8981 , 1-val_avg_a_loss:0.8744 , 1-val_avg_n_loss:0.8820
# 100%|██████████| 1269/1269 [01:13<00:00, 17.21it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.27it/s]
# [2024-03-21 18:24:35,961]::4171747451::DEBUG::Epoch: 64 , 1-MAE: 0.8831 , 1-val_avg_o_loss:0.8817 , 1-val_avg_c_loss:0.8766 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8732 , 1-val_avg_n_loss:0.8840
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.19it/s]
# [2024-03-21 18:26:01,450]::4171747451::DEBUG::Epoch: 65 , 1-MAE: 0.8812 , 1-val_avg_o_loss:0.8695 , 1-val_avg_c_loss:0.8783 , 1-val_avg_e_loss:0.8993 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8835
# 100%|██████████| 1269/1269 [01:13<00:00, 17.19it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.31it/s]
# [2024-03-21 18:27:25,760]::4171747451::DEBUG::Epoch: 66 , 1-MAE: 0.8834 , 1-val_avg_o_loss:0.8819 , 1-val_avg_c_loss:0.8782 , 1-val_avg_e_loss:0.8988 , 1-val_avg_a_loss:0.8738 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.25it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.76it/s]
# [2024-03-21 18:28:49,825]::4171747451::DEBUG::Epoch: 67 , 1-MAE: 0.8831 , 1-val_avg_o_loss:0.8793 , 1-val_avg_c_loss:0.8763 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.19it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.33it/s]
# [2024-03-21 18:30:14,269]::4171747451::DEBUG::Epoch: 68 , 1-MAE: 0.8838 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.8992 , 1-val_avg_a_loss:0.8747 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:14<00:00, 17.13it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.26it/s]
# [2024-03-21 18:31:39,005]::4171747451::DEBUG::Epoch: 69 , 1-MAE: 0.8812 , 1-val_avg_o_loss:0.8815 , 1-val_avg_c_loss:0.8749 , 1-val_avg_e_loss:0.8966 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8777
# 100%|██████████| 1269/1269 [01:13<00:00, 17.19it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.24it/s]
# [2024-03-21 18:33:04,323]::4171747451::DEBUG::Epoch: 70 , 1-MAE: 0.8840 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.38it/s]
# [2024-03-21 18:34:28,906]::4171747451::DEBUG::Epoch: 71 , 1-MAE: 0.8831 , 1-val_avg_o_loss:0.8804 , 1-val_avg_c_loss:0.8774 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8823
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.49it/s]
# [2024-03-21 18:35:53,432]::4171747451::DEBUG::Epoch: 72 , 1-MAE: 0.8826 , 1-val_avg_o_loss:0.8813 , 1-val_avg_c_loss:0.8787 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8686 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.13it/s]
# [2024-03-21 18:37:18,004]::4171747451::DEBUG::Epoch: 73 , 1-MAE: 0.8837 , 1-val_avg_o_loss:0.8817 , 1-val_avg_c_loss:0.8771 , 1-val_avg_e_loss:0.8998 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8842
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.67it/s]
# [2024-03-21 18:38:42,524]::4171747451::DEBUG::Epoch: 74 , 1-MAE: 0.8824 , 1-val_avg_o_loss:0.8813 , 1-val_avg_c_loss:0.8778 , 1-val_avg_e_loss:0.9002 , 1-val_avg_a_loss:0.8682 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.53it/s]
# [2024-03-21 18:40:07,807]::4171747451::DEBUG::Epoch: 75 , 1-MAE: 0.8825 , 1-val_avg_o_loss:0.8818 , 1-val_avg_c_loss:0.8780 , 1-val_avg_e_loss:0.8992 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8783
# 100%|██████████| 1269/1269 [01:13<00:00, 17.15it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.11it/s]
# [2024-03-21 18:41:32,510]::4171747451::DEBUG::Epoch: 76 , 1-MAE: 0.8841 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.04it/s]
# [2024-03-21 18:42:57,124]::4171747451::DEBUG::Epoch: 77 , 1-MAE: 0.8827 , 1-val_avg_o_loss:0.8817 , 1-val_avg_c_loss:0.8782 , 1-val_avg_e_loss:0.8994 , 1-val_avg_a_loss:0.8719 , 1-val_avg_n_loss:0.8823
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.34it/s]
# [2024-03-21 18:44:21,651]::4171747451::DEBUG::Epoch: 78 , 1-MAE: 0.8836 , 1-val_avg_o_loss:0.8806 , 1-val_avg_c_loss:0.8782 , 1-val_avg_e_loss:0.8992 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.11it/s]
# [2024-03-21 18:45:46,257]::4171747451::DEBUG::Epoch: 79 , 1-MAE: 0.8830 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8785 , 1-val_avg_e_loss:0.8998 , 1-val_avg_a_loss:0.8717 , 1-val_avg_n_loss:0.8829
# 100%|██████████| 1269/1269 [01:13<00:00, 17.22it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.07it/s]
# [2024-03-21 18:47:11,231]::4171747451::DEBUG::Epoch: 80 , 1-MAE: 0.8839 , 1-val_avg_o_loss:0.8818 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.9002 , 1-val_avg_a_loss:0.8746 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.83it/s]
# [2024-03-21 18:48:35,906]::4171747451::DEBUG::Epoch: 81 , 1-MAE: 0.8826 , 1-val_avg_o_loss:0.8796 , 1-val_avg_c_loss:0.8766 , 1-val_avg_e_loss:0.8986 , 1-val_avg_a_loss:0.8742 , 1-val_avg_n_loss:0.8842
# 100%|██████████| 1269/1269 [01:13<00:00, 17.15it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.23it/s]
# [2024-03-21 18:50:00,570]::4171747451::DEBUG::Epoch: 82 , 1-MAE: 0.8833 , 1-val_avg_o_loss:0.8811 , 1-val_avg_c_loss:0.8767 , 1-val_avg_e_loss:0.8998 , 1-val_avg_a_loss:0.8747 , 1-val_avg_n_loss:0.8842
# 100%|██████████| 1269/1269 [01:14<00:00, 17.11it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.23it/s]
# [2024-03-21 18:51:25,429]::4171747451::DEBUG::Epoch: 83 , 1-MAE: 0.8817 , 1-val_avg_o_loss:0.8818 , 1-val_avg_c_loss:0.8772 , 1-val_avg_e_loss:0.8943 , 1-val_avg_a_loss:0.8707 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.15it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.22it/s]
# [2024-03-21 18:52:50,106]::4171747451::DEBUG::Epoch: 84 , 1-MAE: 0.8835 , 1-val_avg_o_loss:0.8821 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8746 , 1-val_avg_n_loss:0.8830
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.12it/s]
# [2024-03-21 18:54:15,390]::4171747451::DEBUG::Epoch: 85 , 1-MAE: 0.8837 , 1-val_avg_o_loss:0.8815 , 1-val_avg_c_loss:0.8785 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8738 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:14<00:00, 17.14it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.10it/s]
# [2024-03-21 18:55:40,126]::4171747451::DEBUG::Epoch: 86 , 1-MAE: 0.8804 , 1-val_avg_o_loss:0.8776 , 1-val_avg_c_loss:0.8699 , 1-val_avg_e_loss:0.8961 , 1-val_avg_a_loss:0.8749 , 1-val_avg_n_loss:0.8835
# 100%|██████████| 1269/1269 [01:13<00:00, 17.23it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.53it/s]
# [2024-03-21 18:57:04,356]::4171747451::DEBUG::Epoch: 87 , 1-MAE: 0.8837 , 1-val_avg_o_loss:0.8819 , 1-val_avg_c_loss:0.8766 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.77it/s]
# [2024-03-21 18:58:28,720]::4171747451::DEBUG::Epoch: 88 , 1-MAE: 0.8819 , 1-val_avg_o_loss:0.8795 , 1-val_avg_c_loss:0.8762 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8750 , 1-val_avg_n_loss:0.8786
# 100%|██████████| 1269/1269 [01:14<00:00, 17.14it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.85it/s]
# [2024-03-21 18:59:53,537]::4171747451::DEBUG::Epoch: 89 , 1-MAE: 0.8832 , 1-val_avg_o_loss:0.8814 , 1-val_avg_c_loss:0.8762 , 1-val_avg_e_loss:0.9002 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8831
# 100%|██████████| 1269/1269 [01:14<00:00, 17.14it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.30it/s]
# [2024-03-21 19:01:18,891]::4171747451::DEBUG::Epoch: 90 , 1-MAE: 0.8832 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8761 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8733 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.18it/s]
# [2024-03-21 19:02:43,458]::4171747451::DEBUG::Epoch: 91 , 1-MAE: 0.8839 , 1-val_avg_o_loss:0.8818 , 1-val_avg_c_loss:0.8783 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.15it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.85it/s]
# [2024-03-21 19:04:07,961]::4171747451::DEBUG::Epoch: 92 , 1-MAE: 0.8839 , 1-val_avg_o_loss:0.8819 , 1-val_avg_c_loss:0.8778 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8841
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.58it/s]
# [2024-03-21 19:05:32,522]::4171747451::DEBUG::Epoch: 93 , 1-MAE: 0.8839 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8841
# 100%|██████████| 1269/1269 [01:13<00:00, 17.22it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.14it/s]
# [2024-03-21 19:06:56,678]::4171747451::DEBUG::Epoch: 94 , 1-MAE: 0.8822 , 1-val_avg_o_loss:0.8800 , 1-val_avg_c_loss:0.8780 , 1-val_avg_e_loss:0.8980 , 1-val_avg_a_loss:0.8713 , 1-val_avg_n_loss:0.8839
# 100%|██████████| 1269/1269 [01:13<00:00, 17.19it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.93it/s]
# [2024-03-21 19:08:21,710]::4171747451::DEBUG::Epoch: 95 , 1-MAE: 0.8836 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8787 , 1-val_avg_e_loss:0.8989 , 1-val_avg_a_loss:0.8746 , 1-val_avg_n_loss:0.8840
# 100%|██████████| 1269/1269 [01:13<00:00, 17.23it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.06it/s]
# [2024-03-21 19:09:46,041]::4171747451::DEBUG::Epoch: 96 , 1-MAE: 0.8835 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8768 , 1-val_avg_e_loss:0.9002 , 1-val_avg_a_loss:0.8742 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.16it/s]
# [2024-03-21 19:11:10,544]::4171747451::DEBUG::Epoch: 97 , 1-MAE: 0.8834 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8784 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8738 , 1-val_avg_n_loss:0.8827
# 100%|██████████| 1269/1269 [01:14<00:00, 17.14it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.36it/s]
# [2024-03-21 19:12:35,234]::4171747451::DEBUG::Epoch: 98 , 1-MAE: 0.8829 , 1-val_avg_o_loss:0.8819 , 1-val_avg_c_loss:0.8740 , 1-val_avg_e_loss:0.8997 , 1-val_avg_a_loss:0.8746 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.69it/s]
# [2024-03-21 19:13:59,757]::4171747451::DEBUG::Epoch: 99 , 1-MAE: 0.8838 , 1-val_avg_o_loss:0.8819 , 1-val_avg_c_loss:0.8783 , 1-val_avg_e_loss:0.8992 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.28it/s]
# [2024-03-21 19:15:24,793]::4171747451::DEBUG::Epoch: 100 , 1-MAE: 0.8833 , 1-val_avg_o_loss:0.8815 , 1-val_avg_c_loss:0.8783 , 1-val_avg_e_loss:0.9002 , 1-val_avg_a_loss:0.8723 , 1-val_avg_n_loss:0.8842
# 100%|██████████| 1269/1269 [01:13<00:00, 17.23it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.89it/s]
# [2024-03-21 19:16:48,955]::4171747451::DEBUG::Epoch: 101 , 1-MAE: 0.8841 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8783 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.22it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.58it/s]
# [2024-03-21 19:18:12,990]::4171747451::DEBUG::Epoch: 102 , 1-MAE: 0.8834 , 1-val_avg_o_loss:0.8819 , 1-val_avg_c_loss:0.8773 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8738 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:14<00:00, 17.13it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.79it/s]
# [2024-03-21 19:19:37,601]::4171747451::DEBUG::Epoch: 103 , 1-MAE: 0.8827 , 1-val_avg_o_loss:0.8793 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.8992 , 1-val_avg_a_loss:0.8750 , 1-val_avg_n_loss:0.8813
# 100%|██████████| 1269/1269 [01:13<00:00, 17.22it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.91it/s]
# [2024-03-21 19:21:01,771]::4171747451::DEBUG::Epoch: 104 , 1-MAE: 0.8831 , 1-val_avg_o_loss:0.8791 , 1-val_avg_c_loss:0.8777 , 1-val_avg_e_loss:0.8996 , 1-val_avg_a_loss:0.8745 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.23it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.97it/s]
# [2024-03-21 19:22:26,576]::4171747451::DEBUG::Epoch: 105 , 1-MAE: 0.8822 , 1-val_avg_o_loss:0.8813 , 1-val_avg_c_loss:0.8755 , 1-val_avg_e_loss:0.8997 , 1-val_avg_a_loss:0.8750 , 1-val_avg_n_loss:0.8796
# 100%|██████████| 1269/1269 [01:13<00:00, 17.21it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.81it/s]
# [2024-03-21 19:23:51,081]::4171747451::DEBUG::Epoch: 106 , 1-MAE: 0.8817 , 1-val_avg_o_loss:0.8789 , 1-val_avg_c_loss:0.8731 , 1-val_avg_e_loss:0.8998 , 1-val_avg_a_loss:0.8729 , 1-val_avg_n_loss:0.8838
# 100%|██████████| 1269/1269 [01:14<00:00, 17.14it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.24it/s]
# [2024-03-21 19:25:15,783]::4171747451::DEBUG::Epoch: 107 , 1-MAE: 0.8839 , 1-val_avg_o_loss:0.8815 , 1-val_avg_c_loss:0.8785 , 1-val_avg_e_loss:0.8993 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.74it/s]
# [2024-03-21 19:26:40,251]::4171747451::DEBUG::Epoch: 108 , 1-MAE: 0.8834 , 1-val_avg_o_loss:0.8801 , 1-val_avg_c_loss:0.8782 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8745 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.28it/s]
# [2024-03-21 19:28:04,845]::4171747451::DEBUG::Epoch: 109 , 1-MAE: 0.8829 , 1-val_avg_o_loss:0.8812 , 1-val_avg_c_loss:0.8771 , 1-val_avg_e_loss:0.9000 , 1-val_avg_a_loss:0.8721 , 1-val_avg_n_loss:0.8842
# 100%|██████████| 1269/1269 [01:14<00:00, 17.12it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.44it/s]
# [2024-03-21 19:29:30,272]::4171747451::DEBUG::Epoch: 110 , 1-MAE: 0.8838 , 1-val_avg_o_loss:0.8820 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8749 , 1-val_avg_n_loss:0.8837
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.89it/s]
# [2024-03-21 19:30:54,743]::4171747451::DEBUG::Epoch: 111 , 1-MAE: 0.8837 , 1-val_avg_o_loss:0.8812 , 1-val_avg_c_loss:0.8779 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8753 , 1-val_avg_n_loss:0.8841
# 100%|██████████| 1269/1269 [01:13<00:00, 17.23it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.86it/s]
# [2024-03-21 19:32:18,904]::4171747451::DEBUG::Epoch: 112 , 1-MAE: 0.8834 , 1-val_avg_o_loss:0.8799 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.8990 , 1-val_avg_a_loss:0.8750 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.18it/s]
# 100%|██████████| 425/425 [00:10<00:00, 41.90it/s]
# [2024-03-21 19:33:43,508]::4171747451::DEBUG::Epoch: 113 , 1-MAE: 0.8827 , 1-val_avg_o_loss:0.8817 , 1-val_avg_c_loss:0.8775 , 1-val_avg_e_loss:0.8965 , 1-val_avg_a_loss:0.8734 , 1-val_avg_n_loss:0.8844
# 100%|██████████| 1269/1269 [01:14<00:00, 17.15it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.26it/s]
# [2024-03-21 19:35:08,220]::4171747451::DEBUG::Epoch: 114 , 1-MAE: 0.8840 , 1-val_avg_o_loss:0.8817 , 1-val_avg_c_loss:0.8782 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.17it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.95it/s]
# [2024-03-21 19:36:33,325]::4171747451::DEBUG::Epoch: 115 , 1-MAE: 0.8834 , 1-val_avg_o_loss:0.8787 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.8998 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8843
# 100%|██████████| 1269/1269 [01:13<00:00, 17.21it/s]
# 100%|██████████| 425/425 [00:09<00:00, 42.93it/s]
# [2024-03-21 19:37:57,572]::4171747451::DEBUG::Epoch: 116 , 1-MAE: 0.8840 , 1-val_avg_o_loss:0.8819 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8845
# 100%|██████████| 1269/1269 [01:13<00:00, 17.16it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.23it/s]
# [2024-03-21 19:39:22,202]::4171747451::DEBUG::Epoch: 117 , 1-MAE: 0.8831 , 1-val_avg_o_loss:0.8808 , 1-val_avg_c_loss:0.8783 , 1-val_avg_e_loss:0.9001 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8809
# 100%|██████████| 1269/1269 [01:13<00:00, 17.21it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.16it/s]
# [2024-03-21 19:40:46,330]::4171747451::DEBUG::Epoch: 118 , 1-MAE: 0.8840 , 1-val_avg_o_loss:0.8817 , 1-val_avg_c_loss:0.8786 , 1-val_avg_e_loss:0.8998 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.8846
# 100%|██████████| 1269/1269 [01:13<00:00, 17.20it/s]
# 100%|██████████| 425/425 [00:10<00:00, 42.16it/s]
# [2024-03-21 19:42:10,772]::4171747451::DEBUG::Epoch: 119 , 1-MAE: 0.8829 , 1-val_avg_o_loss:0.8801 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.8978 , 1-val_avg_a_loss:0.8745 , 1-val_avg_n_loss:0.8841
# 100%|██████████| 1269/1269 [01:14<00:00, 17.11it/s]
# 100%|██████████| 425/425 [00:09<00:00, 43.03it/s]
# [2024-03-21 19:43:36,228]::4171747451::DEBUG::Epoch: 120 , 1-MAE: 0.8828 , 1-val_avg_o_loss:0.8797 , 1-val_avg_c_loss:0.8781 , 1-val_avg_e_loss:0.8965 , 1-val_avg_a_loss:0.8755 , 1-val_avg_n_loss:0.8843

# %%
# from torchinfo import summary

# summary(model, input_size = (4,15,4,3,224,224))

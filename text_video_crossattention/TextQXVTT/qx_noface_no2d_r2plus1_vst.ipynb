# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import os
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import random
import cv2
# from vgg16 import VGG16_LSTM
import pickle
import torch.nn as nn
import torch
import datetime
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms, utils, models
from torch.utils.data import Dataset, DataLoader
from facenet_pytorch import MTCNN
import logging
import torch
import torch.nn as nn
from qx_noface_no2d_video_swin_transformer01 import SwinTransformer3D
import gc
from einops import rearrange
from tqdm import tqdm
# from kw_r2plus1d_video_swin_transformer import SwinTransformer3D
batchsz = 4
frame_nums=15
start_epoch = 0
test_flage=False
model_name ="fullshot and xlm-roberta"
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('[%(asctime)s]::%(module)s::%(levelname)s::%(message)s')
streamHandler = logging.StreamHandler()
streamHandler.setFormatter(formatter)
fileHandler = logging.FileHandler('./LOG/personalityLog.log')
fileHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.addHandler(fileHandler)
USE_CUDA = torch.cuda.is_available()
# device = torch.device('cuda:1' if USE_CUDA else 'cpu')

# %%
logger.debug('============={}+Video swin transformerTrain Strat!============='.format(model_name))
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:1' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:', device)
# Out:
# [2024-03-19 21:38:09,257]::387438924::DEBUG::=============fullshot and xlm-roberta+Video swin transformerTrain Strat!=============
# True
# 학습을 진행하는 기기: cuda:1

# %%
def select_frame_data(datas,frame_num):
    data_set=[]
    begin_num=0
    x=128/frame_num
    indexes=[None] * frame_num
    for i in range(frame_num):
        indexes[i]=int(begin_num)
        begin_num+=x
    for data in datas:
        video_frames = [None] * 2
        video_frames[0]=[]
        video_frames[1]=[]
        for index in indexes:
            video_frames[0].append(data[0][index])
        video_frames[1].append(data[1])
        data_set.append(video_frames)
        del video_frames
        del data 
        gc.collect()
    del datas
    gc.collect()
    return data_set
print(1)
# Out:
# 1

# %%
def getdata(pathname,datatype):
    if datatype=="train":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            # train_data_set.extend(pickle.load(output_file))
            final_data_set.extend(pickle.load(output_file))
            # print(i)
        return final_data_set
    elif datatype=="valid":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            valid_data_set=[]
            final_data_set.extend(pickle.load(output_file))
            del valid_data_set
        return final_data_set
print(1)
# Out:
# 1

# %%
def datasize(type,batchsz):
    if type=='train':
        i=5076#5967
        while True:
            if i%batchsz==0:
                return i
            else:
                i-=1
    else:
        i=1700#1986
        while True:
            if i%batchsz==0:
                return i
            else:
                i-=1
print(1)
# Out:
# 1

# %%
save_model_file_path = './save_swintransformer_folder/{}_{}.{}'
mtcnn= MTCNN(image_size=224, margin=0, min_face_size= 20, thresholds=[0.6, 0.7, 0.7], post_process=True)
# test_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/test_set.dat","test")
# test_set_data=test_set_data[:datasize("test",batchsz)]
print(1)
# Out:
# 1

# %%
def reshape_to_expected_traininput(dataset: List[Tuple[ np.ndarray, np.ndarray]]) -> Tuple[
     np.ndarray, np.ndarray]:
    result=[]
    for i in range(0, len(dataset[0])):
        result.append((dataset[0][i],dataset[1][i],dataset[2][i],dataset[3][i],dataset[4][i],dataset[5][i]))
    result = result[:datasize("train",batchsz)]
    x0_list = []
    x1_list = []
    x2_list = []
    x3_list = []
    x4_list = []
    x5_list = []
    for i in range(0, len(result)):
        x0_list.append(result[i][0])
        x1_list.append(result[i][1])
        x2_list.append(result[i][2])
        x3_list.append(result[i][3])
        x4_list.append(result[i][4])
        x5_list.append(result[i][5])
    return (np.stack(x0_list), np.stack(x1_list), np.stack(x2_list),np.stack(x3_list), np.stack(x4_list), np.stack(x5_list))
print(1)
# Out:
# 1

# %%
def reshape_to_expected_validinput(dataset: List[Tuple[ np.ndarray, np.ndarray]]) -> Tuple[
     np.ndarray, np.ndarray]:
    result=[]
    for i in range(0, len(dataset[0])):
        result.append((dataset[0][i],dataset[1][i],dataset[2][i],dataset[3][i],dataset[4][i],dataset[5][i]))
    result = result[:datasize("valid",batchsz)]
    x0_list = []
    x1_list = []
    x2_list = []
    x3_list = []
    x4_list = []
    x5_list = []
    for i in range(0, len(result)):
        x0_list.append(result[i][0])
        x1_list.append(result[i][1])
        x2_list.append(result[i][2])
        x3_list.append(result[i][3])
        x4_list.append(result[i][4])
        x5_list.append(result[i][5])
    return (np.stack(x0_list), np.stack(x1_list), np.stack(x2_list),np.stack(x3_list), np.stack(x4_list), np.stack(x5_list))
print(1)
# Out:
# 1

# %%
validation_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/multidata/1700valid_set.dat","valid")
validation_set_data=reshape_to_expected_validinput(validation_set_data)
print(1)
# Out:
# 1

# %%
train_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/multidata/5076train_set.dat","train")
train_set_data=reshape_to_expected_traininput(train_set_data)
print(1)
# Out:
# 1

# %%
def imagecrop(imagedata,batchsz):
    # convert_tensor= transforms.ToTensor()
    output=[]
    for j in range(batchsz):#비디오 데이터 batchsz(9) 개 있다
        firstoutput=[]
        for i in range(len(imagedata[j])):#imagedata에 15개의 프레임이 있다
            # temp = convert_tensor(imagedata[i])
            #이미지를 나누
            temp = imagedata[j][i].unfold(1,112,112).unfold(2,112,112)
            temp = rearrange(temp, 'c h1 w1 h w -> (h1 w1) c h w')
            firstoutput.append(temp)
        firstoutput = torch.stack(firstoutput,0)
        output.append(firstoutput)
    output = torch.stack(output,0)
    return output
print(1)
# Out:
# 1

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
])
print(1)
# Out:
# 1

# %%
class ChalearnDataset(Dataset):
    def __init__(self,textdata,fullshot,tagdata,transform=None):
        self.textdata=textdata
        self.fullshot=fullshot
        self.tagdata=tagdata
        self.transform = transform  # 표준화 여부
    def __len__(self):
        return len(self.fullshot)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()#텐서의 경우 목록으로 돌아가기
        textdata = self.textdata[idx]
        # textdata = torch.FloatTensor(textdata)
        fullshot=self.fullshot[idx]
        fullshot=torch.FloatTensor(fullshot)
        # image_data=image_data.reshape(15,3,224,224)
        big_five_sorces=self.tagdata[idx]
        big_five_sorces = torch.FloatTensor(big_five_sorces)
        return textdata,fullshot,big_five_sorces
print(1)
# Out:
# 1

# %%
num_workerssz = 20
lr = 3e-05
epochs = 120
#device = torch.device('cuda')
# train_set_data = reshape_to_expected_input(train_set_data)
# val_set_data = reshape_to_expected_input(validation_set_data)
print(1)
# Out:
# 1

# %%
train_set_data = ChalearnDataset(textdata=train_set_data[4],fullshot = train_set_data[1],tagdata=train_set_data[5],transform=transform)
val_set_data = ChalearnDataset(textdata=validation_set_data[4],fullshot = validation_set_data[1], tagdata=validation_set_data[5],transform=transform)
train_dataloader = DataLoader(dataset=train_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
val_dataloader = DataLoader(dataset=val_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
max_value=0
print(1)
# Out:
# 1

# %%
model=SwinTransformer3D()#num_frames=frame_nums,batchsz = batchsz
model.to(device)
criterion = torch.nn.L1Loss().to(device)  # 손실함수
optimizer = torch.optim.AdamW(model.parameters(), lr=lr) # 옵티마이저

if test_flage==True:
    checkpoint=torch.load(save_model_file_path.format('model',start_epoch,'pth'), map_location=device)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    # criterion.load_state_dict(checkpoint["loss"])
train_avg_loss0=[]
val_avg_loss0=[]
print(1)
# Out:
# Some weights of AlbertModel were not initialized from the model checkpoint at text_model/ and are newly initialized: ['albert.pooler.weight', 'albert.pooler.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/ssrlab/anaconda3/envs/qx/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 1

# %%
# from torchinfo import summary

# summary(model, input_size = ((8,15,224,224,3),(8,24,1319,1)), col_names = ['input_size','output_size','num_params'])

# %%
def extract_ocean(data,batch_size):
    o=[]
    c=[]
    e=[]
    a=[]
    n=[]
    for i in range(batch_size):
        o.append(data[i][0].item())
        c.append(data[i][1].item())
        e.append(data[i][2].item())
        a.append(data[i][3].item())
        n.append(data[i][4].item())
    o = torch.tensor(o) 
    c = torch.tensor(c) 
    e = torch.tensor(e) 
    a = torch.tensor(a) 
    n = torch.tensor(n) 
    return o,c,e,a,n

# %%
with torch.cuda.device(1):
    for i in range(start_epoch, epochs):
        train_avg_loss = 0
        val_avg_loss = 0
        train_avg_o_loss = 0
        train_avg_c_loss = 0
        train_avg_e_loss = 0
        train_avg_a_loss = 0
        train_avg_n_loss = 0
        val_avg_o_loss = 0
        val_avg_c_loss = 0
        val_avg_e_loss = 0
        val_avg_a_loss = 0
        val_avg_n_loss = 0
        for textdata,fullshot,big_five_data in tqdm(train_dataloader):
            big_five_data=big_five_data.permute(0,2,1)
            big_five_data=big_five_data.squeeze()
            # textdata = textdata.to(device)
            fullshot = fullshot.to(device)
            big_five_data = big_five_data.to(device)
            optimizer.zero_grad()  # 기울기가 0이 됩니다.
            hypothesis = model(fullshot,textdata)  # 모델의 예측 결과를 저장합니다.
            loss = criterion(hypothesis, big_five_data)  # 예측된 결과와 실제 태그 사이의 손실 값을 저장합니다.
            loss.backward()  # 역방향 전파입니다. 
            optimizer.step()  
            train_avg_loss += loss  
        train_avg_loss=train_avg_loss/len(train_dataloader)
        with torch.no_grad():#validate
            for textdata,fullshot,big_five_data in tqdm(val_dataloader):
                big_five_data=big_five_data.permute(0,2,1)
                big_five_data=big_five_data.squeeze()
                # textdata = textdata.to(device)
                fullshot = fullshot.to(device)
                big_five_data = big_five_data.to(device)
                hypothesis = model(fullshot,textdata)
                val_loss = criterion(hypothesis, big_five_data)
                hypothesiso,hypothesisc,hypothesise,hypothesisa,hypothesisn=extract_ocean(hypothesis,batchsz)
                big_five_datao,big_five_datac,big_five_datae,big_five_dataa,big_five_datan=extract_ocean(big_five_data,batchsz)
                val_o_loss = criterion(hypothesiso, big_five_datao) 
                val_c_loss = criterion(hypothesisc, big_five_datac) 
                val_e_loss = criterion(hypothesise, big_five_datae) 
                val_a_loss = criterion(hypothesisa, big_five_dataa) 
                val_n_loss = criterion(hypothesisn, big_five_datan)  
                val_avg_loss += val_loss
                val_avg_o_loss += val_o_loss
                val_avg_c_loss += val_c_loss
                val_avg_e_loss += val_e_loss
                val_avg_a_loss += val_a_loss
                val_avg_n_loss += val_n_loss
            val_avg_loss=val_avg_loss/len(val_dataloader)
            val_avg_o_loss=val_avg_o_loss/len(val_dataloader)
            val_avg_c_loss=val_avg_c_loss/len(val_dataloader)
            val_avg_e_loss=val_avg_e_loss/len(val_dataloader)
            val_avg_a_loss=val_avg_a_loss/len(val_dataloader)
            val_avg_n_loss=val_avg_n_loss/len(val_dataloader)
        torch.cuda.empty_cache()
        # if (1-val_avg_loss)>=(1-max_value):
        max_value=val_avg_loss
        start_epoch+=1
        if (i + 1) % 5 == 0:
            torch.save({
                    'epoch': i+1,
                    'model': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'loss': val_avg_loss,
                }, save_model_file_path.format('model',start_epoch,'pth'))
        logger.debug('Epoch: {} , 1-MAE: {:.4f} , 1-val_avg_o_loss:{:.4f} , 1-val_avg_c_loss:{:.4f} , 1-val_avg_e_loss:{:.4f} , 1-val_avg_a_loss:{:.4f} , 1-val_avg_n_loss:{:.4f}'.format(i+1, 1-val_avg_loss, 1-val_avg_o_loss, 1-val_avg_c_loss, 1-val_avg_e_loss, 1-val_avg_a_loss,1-val_avg_n_loss))
# Out:
#   0%|          | 0/1269 [00:00<?, ?it/s]We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# 100%|██████████| 1269/1269 [05:39<00:00,  3.74it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.92it/s]
# [2024-03-19 21:46:10,490]::1375840674::DEBUG::Epoch: 1 , 1-MAE: 0.8685 , 1-val_avg_o_loss:0.8110 , 1-val_avg_c_loss:0.8704 , 1-val_avg_e_loss:0.8988 , 1-val_avg_a_loss:0.8761 , 1-val_avg_n_loss:0.8860
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.90it/s]
# [2024-03-19 21:52:32,426]::1375840674::DEBUG::Epoch: 2 , 1-MAE: 0.8684 , 1-val_avg_o_loss:0.8764 , 1-val_avg_c_loss:0.8928 , 1-val_avg_e_loss:0.8840 , 1-val_avg_a_loss:0.8327 , 1-val_avg_n_loss:0.8563
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.96it/s]
# [2024-03-19 21:58:54,860]::1375840674::DEBUG::Epoch: 3 , 1-MAE: 0.8828 , 1-val_avg_o_loss:0.8827 , 1-val_avg_c_loss:0.8759 , 1-val_avg_e_loss:0.8908 , 1-val_avg_a_loss:0.8958 , 1-val_avg_n_loss:0.8687
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-19 22:05:16,477]::1375840674::DEBUG::Epoch: 4 , 1-MAE: 0.8890 , 1-val_avg_o_loss:0.8825 , 1-val_avg_c_loss:0.8851 , 1-val_avg_e_loss:0.9089 , 1-val_avg_a_loss:0.8783 , 1-val_avg_n_loss:0.8904
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-19 22:11:40,034]::1375840674::DEBUG::Epoch: 5 , 1-MAE: 0.9003 , 1-val_avg_o_loss:0.9053 , 1-val_avg_c_loss:0.9015 , 1-val_avg_e_loss:0.9091 , 1-val_avg_a_loss:0.9017 , 1-val_avg_n_loss:0.8837
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.88it/s]
# [2024-03-19 22:18:02,637]::1375840674::DEBUG::Epoch: 6 , 1-MAE: 0.9038 , 1-val_avg_o_loss:0.9060 , 1-val_avg_c_loss:0.9040 , 1-val_avg_e_loss:0.9106 , 1-val_avg_a_loss:0.8870 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.92it/s]
# [2024-03-19 22:24:25,268]::1375840674::DEBUG::Epoch: 7 , 1-MAE: 0.9087 , 1-val_avg_o_loss:0.9106 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9111 , 1-val_avg_a_loss:0.9052 , 1-val_avg_n_loss:0.9104
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.99it/s]
# [2024-03-19 22:30:47,714]::1375840674::DEBUG::Epoch: 8 , 1-MAE: 0.9088 , 1-val_avg_o_loss:0.9091 , 1-val_avg_c_loss:0.9070 , 1-val_avg_e_loss:0.9106 , 1-val_avg_a_loss:0.9092 , 1-val_avg_n_loss:0.9082
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.91it/s]
# [2024-03-19 22:37:10,346]::1375840674::DEBUG::Epoch: 9 , 1-MAE: 0.9092 , 1-val_avg_o_loss:0.9118 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9105 , 1-val_avg_a_loss:0.9070 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.91it/s]
# [2024-03-19 22:43:34,294]::1375840674::DEBUG::Epoch: 10 , 1-MAE: 0.9040 , 1-val_avg_o_loss:0.9037 , 1-val_avg_c_loss:0.8998 , 1-val_avg_e_loss:0.9066 , 1-val_avg_a_loss:0.9017 , 1-val_avg_n_loss:0.9083
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.90it/s]
# [2024-03-19 22:49:57,171]::1375840674::DEBUG::Epoch: 11 , 1-MAE: 0.9019 , 1-val_avg_o_loss:0.9074 , 1-val_avg_c_loss:0.9050 , 1-val_avg_e_loss:0.8932 , 1-val_avg_a_loss:0.8993 , 1-val_avg_n_loss:0.9048
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.93it/s]
# [2024-03-19 22:56:19,456]::1375840674::DEBUG::Epoch: 12 , 1-MAE: 0.9044 , 1-val_avg_o_loss:0.9117 , 1-val_avg_c_loss:0.9070 , 1-val_avg_e_loss:0.9095 , 1-val_avg_a_loss:0.9073 , 1-val_avg_n_loss:0.8866
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.95it/s]
# [2024-03-19 23:02:41,561]::1375840674::DEBUG::Epoch: 13 , 1-MAE: 0.9097 , 1-val_avg_o_loss:0.9099 , 1-val_avg_c_loss:0.9074 , 1-val_avg_e_loss:0.9105 , 1-val_avg_a_loss:0.9094 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.97it/s]
# [2024-03-19 23:09:03,263]::1375840674::DEBUG::Epoch: 14 , 1-MAE: 0.9100 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9041 , 1-val_avg_e_loss:0.9148 , 1-val_avg_a_loss:0.9088 , 1-val_avg_n_loss:0.9101
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.94it/s]
# [2024-03-19 23:15:26,316]::1375840674::DEBUG::Epoch: 15 , 1-MAE: 0.9095 , 1-val_avg_o_loss:0.9115 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9107 , 1-val_avg_n_loss:0.9062
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.93it/s]
# [2024-03-19 23:21:48,349]::1375840674::DEBUG::Epoch: 16 , 1-MAE: 0.9056 , 1-val_avg_o_loss:0.9106 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.8999 , 1-val_avg_a_loss:0.9097 , 1-val_avg_n_loss:0.9017
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.03it/s]
# [2024-03-19 23:28:09,878]::1375840674::DEBUG::Epoch: 17 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9120 , 1-val_avg_c_loss:0.9074 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9100 , 1-val_avg_n_loss:0.9123
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.94it/s]
# [2024-03-19 23:34:31,955]::1375840674::DEBUG::Epoch: 18 , 1-MAE: 0.9080 , 1-val_avg_o_loss:0.9110 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9083 , 1-val_avg_a_loss:0.9068 , 1-val_avg_n_loss:0.9073
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.02it/s]
# [2024-03-19 23:40:54,041]::1375840674::DEBUG::Epoch: 19 , 1-MAE: 0.9095 , 1-val_avg_o_loss:0.9117 , 1-val_avg_c_loss:0.9052 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9104 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-19 23:47:17,040]::1375840674::DEBUG::Epoch: 20 , 1-MAE: 0.9091 , 1-val_avg_o_loss:0.9116 , 1-val_avg_c_loss:0.9047 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9097 , 1-val_avg_n_loss:0.9076
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.95it/s]
# [2024-03-19 23:53:39,188]::1375840674::DEBUG::Epoch: 21 , 1-MAE: 0.9090 , 1-val_avg_o_loss:0.9094 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9089 , 1-val_avg_a_loss:0.9111 , 1-val_avg_n_loss:0.9101
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.87it/s]
# [2024-03-20 00:00:01,557]::1375840674::DEBUG::Epoch: 22 , 1-MAE: 0.9071 , 1-val_avg_o_loss:0.9104 , 1-val_avg_c_loss:0.8995 , 1-val_avg_e_loss:0.9074 , 1-val_avg_a_loss:0.9120 , 1-val_avg_n_loss:0.9062
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.96it/s]
# [2024-03-20 00:06:24,103]::1375840674::DEBUG::Epoch: 23 , 1-MAE: 0.9095 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9051 , 1-val_avg_e_loss:0.9108 , 1-val_avg_a_loss:0.9119 , 1-val_avg_n_loss:0.9072
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.00it/s]
# [2024-03-20 00:12:45,766]::1375840674::DEBUG::Epoch: 24 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9112 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9099 , 1-val_avg_a_loss:0.9109 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.92it/s]
# [2024-03-20 00:19:09,295]::1375840674::DEBUG::Epoch: 25 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9111 , 1-val_avg_c_loss:0.9002 , 1-val_avg_e_loss:0.9112 , 1-val_avg_a_loss:0.9117 , 1-val_avg_n_loss:0.9087
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 00:25:31,947]::1375840674::DEBUG::Epoch: 26 , 1-MAE: 0.9096 , 1-val_avg_o_loss:0.9118 , 1-val_avg_c_loss:0.9055 , 1-val_avg_e_loss:0.9092 , 1-val_avg_a_loss:0.9119 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.97it/s]
# [2024-03-20 00:31:53,863]::1375840674::DEBUG::Epoch: 27 , 1-MAE: 0.9093 , 1-val_avg_o_loss:0.9120 , 1-val_avg_c_loss:0.9049 , 1-val_avg_e_loss:0.9118 , 1-val_avg_a_loss:0.9098 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 00:38:16,471]::1375840674::DEBUG::Epoch: 28 , 1-MAE: 0.9103 , 1-val_avg_o_loss:0.9127 , 1-val_avg_c_loss:0.9058 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9126 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.03it/s]
# [2024-03-20 00:44:38,219]::1375840674::DEBUG::Epoch: 29 , 1-MAE: 0.9100 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9018 , 1-val_avg_e_loss:0.9118 , 1-val_avg_a_loss:0.9134 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 00:51:01,472]::1375840674::DEBUG::Epoch: 30 , 1-MAE: 0.9099 , 1-val_avg_o_loss:0.9100 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9121 , 1-val_avg_a_loss:0.9126 , 1-val_avg_n_loss:0.9083
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.97it/s]
# [2024-03-20 00:57:23,890]::1375840674::DEBUG::Epoch: 31 , 1-MAE: 0.9097 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9059 , 1-val_avg_e_loss:0.9108 , 1-val_avg_a_loss:0.9103 , 1-val_avg_n_loss:0.9093
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.99it/s]
# [2024-03-20 01:03:45,999]::1375840674::DEBUG::Epoch: 32 , 1-MAE: 0.9098 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9052 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9107 , 1-val_avg_n_loss:0.9079
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.95it/s]
# [2024-03-20 01:10:08,430]::1375840674::DEBUG::Epoch: 33 , 1-MAE: 0.9081 , 1-val_avg_o_loss:0.9092 , 1-val_avg_c_loss:0.9040 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9122 , 1-val_avg_n_loss:0.9040
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.90it/s]
# [2024-03-20 01:16:31,337]::1375840674::DEBUG::Epoch: 34 , 1-MAE: 0.9103 , 1-val_avg_o_loss:0.9115 , 1-val_avg_c_loss:0.9059 , 1-val_avg_e_loss:0.9127 , 1-val_avg_a_loss:0.9124 , 1-val_avg_n_loss:0.9090
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.90it/s]
# [2024-03-20 01:22:55,365]::1375840674::DEBUG::Epoch: 35 , 1-MAE: 0.9101 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9055 , 1-val_avg_e_loss:0.9118 , 1-val_avg_a_loss:0.9115 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.97it/s]
# [2024-03-20 01:29:17,425]::1375840674::DEBUG::Epoch: 36 , 1-MAE: 0.9096 , 1-val_avg_o_loss:0.9109 , 1-val_avg_c_loss:0.9050 , 1-val_avg_e_loss:0.9118 , 1-val_avg_a_loss:0.9118 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.05it/s]
# [2024-03-20 01:35:38,930]::1375840674::DEBUG::Epoch: 37 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9134 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9113 , 1-val_avg_a_loss:0.9119 , 1-val_avg_n_loss:0.9098
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.89it/s]
# [2024-03-20 01:42:01,463]::1375840674::DEBUG::Epoch: 38 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9067 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9121 , 1-val_avg_n_loss:0.9087
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.88it/s]
# [2024-03-20 01:48:24,543]::1375840674::DEBUG::Epoch: 39 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9055 , 1-val_avg_e_loss:0.9123 , 1-val_avg_a_loss:0.9134 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.91it/s]
# [2024-03-20 01:54:47,920]::1375840674::DEBUG::Epoch: 40 , 1-MAE: 0.9104 , 1-val_avg_o_loss:0.9118 , 1-val_avg_c_loss:0.9067 , 1-val_avg_e_loss:0.9115 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9096
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.91it/s]
# [2024-03-20 02:01:10,112]::1375840674::DEBUG::Epoch: 41 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9130 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.00it/s]
# [2024-03-20 02:07:32,024]::1375840674::DEBUG::Epoch: 42 , 1-MAE: 0.9104 , 1-val_avg_o_loss:0.9134 , 1-val_avg_c_loss:0.9039 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9138 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.96it/s]
# [2024-03-20 02:13:53,886]::1375840674::DEBUG::Epoch: 43 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9121 , 1-val_avg_a_loss:0.9135 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.90it/s]
# [2024-03-20 02:20:16,467]::1375840674::DEBUG::Epoch: 44 , 1-MAE: 0.9101 , 1-val_avg_o_loss:0.9113 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9128 , 1-val_avg_n_loss:0.9078
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.87it/s]
# [2024-03-20 02:26:40,181]::1375840674::DEBUG::Epoch: 45 , 1-MAE: 0.9104 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9109 , 1-val_avg_a_loss:0.9122 , 1-val_avg_n_loss:0.9090
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.95it/s]
# [2024-03-20 02:33:02,273]::1375840674::DEBUG::Epoch: 46 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9118 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9127 , 1-val_avg_a_loss:0.9137 , 1-val_avg_n_loss:0.9090
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.88it/s]
# [2024-03-20 02:39:24,735]::1375840674::DEBUG::Epoch: 47 , 1-MAE: 0.9100 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9050 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9128 , 1-val_avg_n_loss:0.9069
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.86it/s]
# [2024-03-20 02:45:47,854]::1375840674::DEBUG::Epoch: 48 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9132 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9133 , 1-val_avg_n_loss:0.9090
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.89it/s]
# [2024-03-20 02:52:10,705]::1375840674::DEBUG::Epoch: 49 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9127 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9135 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.79it/s]
# [2024-03-20 02:58:35,177]::1375840674::DEBUG::Epoch: 50 , 1-MAE: 0.9110 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9127 , 1-val_avg_n_loss:0.9098
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.87it/s]
# [2024-03-20 03:04:57,538]::1375840674::DEBUG::Epoch: 51 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9117 , 1-val_avg_c_loss:0.9076 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9126 , 1-val_avg_n_loss:0.9101
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.92it/s]
# [2024-03-20 03:11:20,249]::1375840674::DEBUG::Epoch: 52 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9132 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.91it/s]
# [2024-03-20 03:17:42,760]::1375840674::DEBUG::Epoch: 53 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9130 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.92it/s]
# [2024-03-20 03:24:05,065]::1375840674::DEBUG::Epoch: 54 , 1-MAE: 0.9113 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9134 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.00it/s]
# [2024-03-20 03:30:28,706]::1375840674::DEBUG::Epoch: 55 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9129 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.93it/s]
# [2024-03-20 03:36:50,738]::1375840674::DEBUG::Epoch: 56 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9071 , 1-val_avg_e_loss:0.9127 , 1-val_avg_a_loss:0.9128 , 1-val_avg_n_loss:0.9105
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.99it/s]
# [2024-03-20 03:43:13,146]::1375840674::DEBUG::Epoch: 57 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9067 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9120 , 1-val_avg_n_loss:0.9089
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.91it/s]
# [2024-03-20 03:49:35,421]::1375840674::DEBUG::Epoch: 58 , 1-MAE: 0.9100 , 1-val_avg_o_loss:0.9114 , 1-val_avg_c_loss:0.9053 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9080
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 03:55:57,833]::1375840674::DEBUG::Epoch: 59 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9120 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9128 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.89it/s]
# [2024-03-20 04:02:21,739]::1375840674::DEBUG::Epoch: 60 , 1-MAE: 0.9110 , 1-val_avg_o_loss:0.9118 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9137 , 1-val_avg_n_loss:0.9095
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.99it/s]
# [2024-03-20 04:08:44,338]::1375840674::DEBUG::Epoch: 61 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9139 , 1-val_avg_a_loss:0.9119 , 1-val_avg_n_loss:0.9111
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.97it/s]
# [2024-03-20 04:15:06,834]::1375840674::DEBUG::Epoch: 62 , 1-MAE: 0.9105 , 1-val_avg_o_loss:0.9116 , 1-val_avg_c_loss:0.9056 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9127 , 1-val_avg_n_loss:0.9098
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.97it/s]
# [2024-03-20 04:21:28,847]::1375840674::DEBUG::Epoch: 63 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9067 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9137 , 1-val_avg_n_loss:0.9093
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.89it/s]
# [2024-03-20 04:27:51,323]::1375840674::DEBUG::Epoch: 64 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9127 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9123 , 1-val_avg_n_loss:0.9095
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.95it/s]
# [2024-03-20 04:34:14,688]::1375840674::DEBUG::Epoch: 65 , 1-MAE: 0.9110 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9059 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9130 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.04it/s]
# [2024-03-20 04:40:36,687]::1375840674::DEBUG::Epoch: 66 , 1-MAE: 0.9103 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9040 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9121 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.01it/s]
# [2024-03-20 04:46:58,442]::1375840674::DEBUG::Epoch: 67 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9130 , 1-val_avg_n_loss:0.9090
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.89it/s]
# [2024-03-20 04:53:20,754]::1375840674::DEBUG::Epoch: 68 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9122 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9115 , 1-val_avg_a_loss:0.9133 , 1-val_avg_n_loss:0.9102
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.97it/s]
# [2024-03-20 04:59:43,257]::1375840674::DEBUG::Epoch: 69 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9068 , 1-val_avg_e_loss:0.9127 , 1-val_avg_a_loss:0.9131 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 05:06:06,554]::1375840674::DEBUG::Epoch: 70 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9136 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9132 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.99it/s]
# [2024-03-20 05:12:29,058]::1375840674::DEBUG::Epoch: 71 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9069 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9113 , 1-val_avg_n_loss:0.9104
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.92it/s]
# [2024-03-20 05:18:51,502]::1375840674::DEBUG::Epoch: 72 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9122 , 1-val_avg_n_loss:0.9105
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.01it/s]
# [2024-03-20 05:25:13,634]::1375840674::DEBUG::Epoch: 73 , 1-MAE: 0.9114 , 1-val_avg_o_loss:0.9132 , 1-val_avg_c_loss:0.9069 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9136 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.02it/s]
# [2024-03-20 05:31:35,406]::1375840674::DEBUG::Epoch: 74 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9120 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.01it/s]
# [2024-03-20 05:37:58,240]::1375840674::DEBUG::Epoch: 75 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9116 , 1-val_avg_n_loss:0.9109
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 05:44:19,907]::1375840674::DEBUG::Epoch: 76 , 1-MAE: 0.9107 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9131 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.91it/s]
# [2024-03-20 05:50:42,821]::1375840674::DEBUG::Epoch: 77 , 1-MAE: 0.9110 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9131 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.89it/s]
# [2024-03-20 05:57:05,737]::1375840674::DEBUG::Epoch: 78 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9114 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.95it/s]
# [2024-03-20 06:03:28,605]::1375840674::DEBUG::Epoch: 79 , 1-MAE: 0.9105 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9117 , 1-val_avg_a_loss:0.9123 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.90it/s]
# [2024-03-20 06:09:52,581]::1375840674::DEBUG::Epoch: 80 , 1-MAE: 0.9114 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9073 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9126 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 06:16:15,062]::1375840674::DEBUG::Epoch: 81 , 1-MAE: 0.9110 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9143 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9096
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.02it/s]
# [2024-03-20 06:22:36,671]::1375840674::DEBUG::Epoch: 82 , 1-MAE: 0.9107 , 1-val_avg_o_loss:0.9122 , 1-val_avg_c_loss:0.9058 , 1-val_avg_e_loss:0.9127 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.01it/s]
# [2024-03-20 06:28:58,468]::1375840674::DEBUG::Epoch: 83 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9123 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9135 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.96it/s]
# [2024-03-20 06:35:20,347]::1375840674::DEBUG::Epoch: 84 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9134 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.88it/s]
# [2024-03-20 06:41:44,691]::1375840674::DEBUG::Epoch: 85 , 1-MAE: 0.9114 , 1-val_avg_o_loss:0.9137 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9132 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.94it/s]
# [2024-03-20 06:48:07,360]::1375840674::DEBUG::Epoch: 86 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9059 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9128 , 1-val_avg_n_loss:0.9091
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.00it/s]
# [2024-03-20 06:54:29,250]::1375840674::DEBUG::Epoch: 87 , 1-MAE: 0.9113 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9068 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.02it/s]
# [2024-03-20 07:00:51,238]::1375840674::DEBUG::Epoch: 88 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9127 , 1-val_avg_n_loss:0.9102
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.02it/s]
# [2024-03-20 07:07:12,995]::1375840674::DEBUG::Epoch: 89 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9120 , 1-val_avg_n_loss:0.9102
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.94it/s]
# [2024-03-20 07:13:36,035]::1375840674::DEBUG::Epoch: 90 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9132 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9142 , 1-val_avg_a_loss:0.9130 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 07:19:58,568]::1375840674::DEBUG::Epoch: 91 , 1-MAE: 0.9107 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9055 , 1-val_avg_e_loss:0.9135 , 1-val_avg_a_loss:0.9116 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.01it/s]
# [2024-03-20 07:26:20,532]::1375840674::DEBUG::Epoch: 92 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9133 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.91it/s]
# [2024-03-20 07:32:43,424]::1375840674::DEBUG::Epoch: 93 , 1-MAE: 0.9110 , 1-val_avg_o_loss:0.9124 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9132 , 1-val_avg_n_loss:0.9111
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.93it/s]
# [2024-03-20 07:39:06,305]::1375840674::DEBUG::Epoch: 94 , 1-MAE: 0.9104 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9052 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9120 , 1-val_avg_n_loss:0.9094
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.99it/s]
# [2024-03-20 07:45:29,979]::1375840674::DEBUG::Epoch: 95 , 1-MAE: 0.9107 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9127 , 1-val_avg_a_loss:0.9126 , 1-val_avg_n_loss:0.9098
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.92it/s]
# [2024-03-20 07:51:52,719]::1375840674::DEBUG::Epoch: 96 , 1-MAE: 0.9106 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9121 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.95it/s]
# [2024-03-20 07:58:15,340]::1375840674::DEBUG::Epoch: 97 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9119 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9133 , 1-val_avg_n_loss:0.9110
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.95it/s]
# [2024-03-20 08:04:37,308]::1375840674::DEBUG::Epoch: 98 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9128 , 1-val_avg_n_loss:0.9109
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.95it/s]
# [2024-03-20 08:10:59,444]::1375840674::DEBUG::Epoch: 99 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9129 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.92it/s]
# [2024-03-20 08:17:23,285]::1375840674::DEBUG::Epoch: 100 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9129 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1269/1269 [05:38<00:00,  3.74it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.84it/s]
# [2024-03-20 08:23:46,791]::1375840674::DEBUG::Epoch: 101 , 1-MAE: 0.9115 , 1-val_avg_o_loss:0.9119 , 1-val_avg_c_loss:0.9070 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9135 , 1-val_avg_n_loss:0.9110
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.89it/s]
# [2024-03-20 08:30:09,230]::1375840674::DEBUG::Epoch: 102 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9132 , 1-val_avg_n_loss:0.9102
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.93it/s]
# [2024-03-20 08:36:31,395]::1375840674::DEBUG::Epoch: 103 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9116 , 1-val_avg_c_loss:0.9063 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9134 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 08:42:53,281]::1375840674::DEBUG::Epoch: 104 , 1-MAE: 0.9105 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9126 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.88it/s]
# [2024-03-20 08:49:16,968]::1375840674::DEBUG::Epoch: 105 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9062 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9126 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.84it/s]
# [2024-03-20 08:55:40,162]::1375840674::DEBUG::Epoch: 106 , 1-MAE: 0.9104 , 1-val_avg_o_loss:0.9116 , 1-val_avg_c_loss:0.9054 , 1-val_avg_e_loss:0.9125 , 1-val_avg_a_loss:0.9127 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.90it/s]
# [2024-03-20 09:02:02,457]::1375840674::DEBUG::Epoch: 107 , 1-MAE: 0.9110 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9126 , 1-val_avg_n_loss:0.9101
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.93it/s]
# [2024-03-20 09:08:24,387]::1375840674::DEBUG::Epoch: 108 , 1-MAE: 0.9110 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9056 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9094
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.91it/s]
# [2024-03-20 09:14:46,565]::1375840674::DEBUG::Epoch: 109 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9130 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.99it/s]
# [2024-03-20 09:21:09,352]::1375840674::DEBUG::Epoch: 110 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9131 , 1-val_avg_c_loss:0.9059 , 1-val_avg_e_loss:0.9133 , 1-val_avg_a_loss:0.9124 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.04it/s]
# [2024-03-20 09:27:31,088]::1375840674::DEBUG::Epoch: 111 , 1-MAE: 0.9104 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9120 , 1-val_avg_n_loss:0.9092
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:43<00:00,  9.88it/s]
# [2024-03-20 09:33:53,396]::1375840674::DEBUG::Epoch: 112 , 1-MAE: 0.9105 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9055 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9114 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.94it/s]
# [2024-03-20 09:40:15,762]::1375840674::DEBUG::Epoch: 113 , 1-MAE: 0.9113 , 1-val_avg_o_loss:0.9133 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9138 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9103
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.99it/s]
# [2024-03-20 09:46:37,905]::1375840674::DEBUG::Epoch: 114 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9130 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9126 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.98it/s]
# [2024-03-20 09:53:01,064]::1375840674::DEBUG::Epoch: 115 , 1-MAE: 0.9109 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9061 , 1-val_avg_e_loss:0.9135 , 1-val_avg_a_loss:0.9123 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.03it/s]
# [2024-03-20 09:59:22,937]::1375840674::DEBUG::Epoch: 116 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9126 , 1-val_avg_c_loss:0.9059 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9124 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1269/1269 [05:37<00:00,  3.76it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.00it/s]
# [2024-03-20 10:05:44,675]::1375840674::DEBUG::Epoch: 117 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9055 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9131 , 1-val_avg_n_loss:0.9102
# 100%|██████████| 1269/1269 [05:37<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00,  9.94it/s]
# [2024-03-20 10:12:06,753]::1375840674::DEBUG::Epoch: 118 , 1-MAE: 0.9103 , 1-val_avg_o_loss:0.9115 , 1-val_avg_c_loss:0.9053 , 1-val_avg_e_loss:0.9129 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9094
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.03it/s]
# [2024-03-20 10:18:29,060]::1375840674::DEBUG::Epoch: 119 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9125 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9121 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1269/1269 [05:38<00:00,  3.75it/s]
# 100%|██████████| 425/425 [00:42<00:00, 10.01it/s]
# [2024-03-20 10:24:52,415]::1375840674::DEBUG::Epoch: 120 , 1-MAE: 0.9108 , 1-val_avg_o_loss:0.9121 , 1-val_avg_c_loss:0.9057 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9132 , 1-val_avg_n_loss:0.9103

# %%
# from torchinfo import summary

# summary(model, input_size = (4,15,4,3,224,224))

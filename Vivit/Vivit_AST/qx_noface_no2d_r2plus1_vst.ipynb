# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import os
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import random
import cv2
# from vgg16 import VGG16_LSTM
import pickle
import torch.nn as nn
import torch
import datetime
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms, utils, models
from torch.utils.data import Dataset, DataLoader
from facenet_pytorch import MTCNN
import logging
import torch
import torch.nn as nn
from vivit import ViViTBackbone
import gc
from einops import rearrange
from tqdm import tqdm
# from kw_r2plus1d_video_swin_transformer import SwinTransformer3D
batchsz = 4
frame_nums=15
start_epoch = 0
test_flage=False
model_name ="fullshot+R2plus1D 6 Layer"
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('[%(asctime)s]::%(module)s::%(levelname)s::%(message)s')
streamHandler = logging.StreamHandler()
streamHandler.setFormatter(formatter)
fileHandler = logging.FileHandler('./LOG/personalityLog.log')
fileHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.addHandler(fileHandler)
USE_CUDA = torch.cuda.is_available()
# device = torch.device('cuda:1' if USE_CUDA else 'cpu')

# %%
logger.debug('============={}+2D Video Vision Transformer Strat!============='.format(model_name))
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:0' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:', device)
# Out:
# [2024-07-01 10:49:54,394]::2730006395::DEBUG::=============fullshot+R2plus1D 6 Layer+2D Video Vision Transformer Strat!=============
# True
# 학습을 진행하는 기기: cuda:0

# %%
def getdata(pathname,datatype):
    if datatype=="train":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            # train_data_set.extend(pickle.load(output_file))
            final_data_set.extend(pickle.load(output_file))
            # print(i)
        return final_data_set
    elif datatype=="valid":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            valid_data_set=[]
            final_data_set.extend(pickle.load(output_file))
            del valid_data_set
        return final_data_set
print(1)
# Out:
# 1

# %%
save_model_file_path = './save_swintransformer_folder/{}_{}.{}'
mtcnn= MTCNN(image_size=224, margin=0, min_face_size= 20, thresholds=[0.6, 0.7, 0.7], post_process=True)
# test_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/test_set.dat","test")
# test_set_data=test_set_data[:datasize("test",batchsz)]
print(1)
# Out:
# 1

# %%
validation_set_data=getdata("/home/ssrlab/qx/video-swin-transformer-pytorch/data/15Frames/margin011/valid_set.dat","valid")
# validation_set_data=reshape_to_expected_validinput(validation_set_data)
print(1)
# Out:
# 1

# %%
train_set_data=getdata("/home/ssrlab/qx/video-swin-transformer-pytorch/data/15Frames/margin011/train_set.dat","train")
# train_set_data=reshape_to_expected_traininput(train_set_data)
print(1)
# Out:
# 1

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
])
print(1)
# Out:
# 1

# %%
class ChalearnDataset(Dataset):
    def __init__(self,audiodata,fullshot,tagdata,transform=None):
        self.audiodata=audiodata
        self.fullshot=fullshot
        self.tagdata=tagdata
        self.transform = transform  # 표준화 여부
    def __len__(self):
        return len(self.fullshot)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()#텐서의 경우 목록으로 돌아가기
        audiodata = self.audiodata[idx]
        audiodata = torch.FloatTensor(audiodata)
        fullshot=self.fullshot[idx]
        fullshot=torch.FloatTensor(fullshot)
        big_five_sorces=self.tagdata[idx]
        big_five_sorces = torch.FloatTensor(big_five_sorces)
        return audiodata,fullshot,big_five_sorces
print(1)
# Out:
# 1

# %%
num_workerssz = 20
lr = 3e-05
epochs = 120
print(1)
# Out:
# 1

# %%
train_set_data = ChalearnDataset(audiodata=train_set_data[0],fullshot = train_set_data[1],tagdata=train_set_data[5],transform=transform)
val_set_data = ChalearnDataset(audiodata=validation_set_data[0],fullshot = validation_set_data[1],tagdata=validation_set_data[5],transform=transform)
train_dataloader = DataLoader(dataset=train_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
val_dataloader = DataLoader(dataset=val_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
max_value=0
print(1)
# Out:
# 1

# %%
model=ViViTBackbone(2, 14, 14, 2, 2, 2, 5, 96, 6, 8, 8, model=3)#num_frames=frame_nums,batchsz = batchsz
model.to(device)
criterion = torch.nn.L1Loss().to(device)  # 손실함수
optimizer = torch.optim.AdamW(model.parameters(), lr=lr) # 옵티마이저

if test_flage==True:
    checkpoint=torch.load(save_model_file_path.format('model',start_epoch,'pth'), map_location=device)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    # criterion.load_state_dict(checkpoint["loss"])
train_avg_loss0=[]
val_avg_loss0=[]
print(1)
# Out:
# ---------------AST Model Summary---------------
# ImageNet pretraining: True, AudioSet pretraining: True
# frequncey stride=10, time stride=10
# number of patches=131
# 1

# %%
from torchinfo import summary

summary(model, input_size = ((4, 3,15, 224, 224),(4,24,1319,1)), col_names = ['input_size','output_size','num_params'])
# Out:
# =======================================================================================================================================
# Layer (type:depth-idx)                                       Input Shape               Output Shape              Param #
# =======================================================================================================================================
# ViViTBackbone                                                [4, 3, 15, 224, 224]      [4, 5]                    3,146,016
# ├─ASTModel: 1-1                                              [4, 1319, 24]             [4, 768]                  885,120
# │    └─DistilledVisionTransformer: 2-1                       --                        --                        1,641,680
# │    │    └─PatchEmbed: 3-1                                  [4, 1, 24, 1319]          [4, 131, 768]             197,376
# │    │    └─Dropout: 3-2                                     [4, 133, 768]             [4, 133, 768]             --
# │    │    └─ModuleList: 3-3                                  --                        --                        85,054,464
# │    │    └─LayerNorm: 3-4                                   [4, 133, 768]             [4, 133, 768]             1,536
# │    └─Sequential: 2-2                                       [4, 768]                  [4, 768]                  --
# │    │    └─LayerNorm: 3-5                                   [4, 768]                  [4, 768]                  1,536
# │    │    └─Linear: 3-6                                      [4, 768]                  [4, 768]                  590,592
# ├─Conv1d: 1-2                                                [4, 768, 1]               [4, 96, 1]                73,824
# ├─VideoResNet: 1-3                                           [4, 3, 15, 224, 224]      [4, 512, 2, 14, 14]       205,200
# │    └─R2Plus1dStem: 2-3                                     [4, 3, 15, 224, 224]      [4, 64, 15, 112, 112]     --
# │    │    └─Conv3d: 3-7                                      [4, 3, 15, 224, 224]      [4, 45, 15, 112, 112]     6,615
# │    │    └─BatchNorm3d: 3-8                                 [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     90
# │    │    └─ReLU: 3-9                                        [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     --
# │    │    └─Conv3d: 3-10                                     [4, 45, 15, 112, 112]     [4, 64, 15, 112, 112]     8,640
# │    │    └─BatchNorm3d: 3-11                                [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     128
# │    │    └─ReLU: 3-12                                       [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    └─Sequential: 2-4                                       [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    │    └─BasicBlock: 3-13                                 [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    │    └─BasicBlock: 3-14                                 [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    └─Sequential: 2-5                                       [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       --
# │    │    └─BasicBlock: 3-15                                 [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       583,960
# │    │    └─BasicBlock: 3-16                                 [4, 128, 8, 56, 56]       [4, 128, 8, 56, 56]       886,400
# │    └─Sequential: 2-6                                       [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       --
# │    │    └─BasicBlock: 3-17                                 [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       2,332,464
# │    │    └─BasicBlock: 3-18                                 [4, 256, 4, 28, 28]       [4, 256, 4, 28, 28]       3,542,272
# │    └─Sequential: 2-7                                       [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       --
# │    │    └─BasicBlock: 3-19                                 [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       9,333,092
# │    │    └─BasicBlock: 3-20                                 [4, 512, 2, 14, 14]       [4, 512, 2, 14, 14]       14,162,432
# ├─Sequential: 1-4                                            [4, 512, 2, 14, 14]       [4, 1, 49, 96]            --
# │    └─Rearrange: 2-8                                        [4, 512, 2, 14, 14]       [4, 1, 49, 4096]          --
# │    └─Linear: 2-9                                           [4, 1, 49, 4096]          [4, 1, 49, 96]            393,312
# ├─Dropout: 1-5                                               [4, 1, 49, 96]            [4, 1, 49, 96]            --
# ├─FSATransformerEncoder: 1-6                                 [4, 1, 49, 96]            [4, 49, 96]               --
# │    └─ModuleList: 2-10                                      --                        --                        20,840
# │    │    └─ModuleList: 3-21                                 --                        --                        20,840
# │    │    └─ModuleList: 3-22                                 --                        --                        20,840
# │    │    └─ModuleList: 3-23                                 --                        --                        20,840
# │    │    └─ModuleList: 3-24                                 --                        --                        20,840
# │    │    └─ModuleList: 3-25                                 --                        --                        20,840
# │    └─ModuleList: 2-11                                      --                        --                        --
# │    │    └─CrossAttentionLayer: 3-26                        [4, 49, 96]               [4, 49, 96]               136,545
# ├─Identity: 1-7                                              [4, 96]                   [4, 96]                   --
# ├─Sequential: 1-8                                            [4, 96]                   [4, 5]                    --
# │    └─LayerNorm: 2-12                                       [4, 96]                   [4, 96]                   192
# │    └─Linear: 2-13                                          [4, 96]                   [4, 5]                    485
# =======================================================================================================================================
# Total params: 123,753,043
# Trainable params: 123,753,042
# Non-trainable params: 1
# Total mult-adds (G): 624.14
# =======================================================================================================================================
# Input size (MB): 36.63
# Forward/backward pass size (MB): 15569.64
# Params size (MB): 471.42
# Estimated Total Size (MB): 16077.69
# =======================================================================================================================================

# %%
def extract_ocean(data,batch_size):
    o=[]
    c=[]
    e=[]
    a=[]
    n=[]
    for i in range(batch_size):
        o.append(data[i][0].item())
        c.append(data[i][1].item())
        e.append(data[i][2].item())
        a.append(data[i][3].item())
        n.append(data[i][4].item())
    o = torch.tensor(o) 
    c = torch.tensor(c) 
    e = torch.tensor(e) 
    a = torch.tensor(a) 
    n = torch.tensor(n) 
    return o,c,e,a,n

# %%
def imagecrop(imagedata,batchsz):
    # convert_tensor= transforms.ToTensor()
    output=[]
    imagedata=imagedata.permute(0,2,1,3,4)
    for j in range(batchsz):#비디오 데이터 batchsz(9) 개 있다
        firstoutput=[]
        for i in range(len(imagedata[j])):#imagedata에 15개의 프레임이 있다
            # temp = convert_tensor(imagedata[i])
            #이미지를 나누
            temp = imagedata[j][i].unfold(1,2,2).unfold(2,2,2)
            temp = rearrange(temp, 'c h1 w1 h w -> (h1 w1) c h w')
            firstoutput.append(temp)
        firstoutput = torch.stack(firstoutput,0)
        output.append(firstoutput)
    output = torch.stack(output,0)
    return output

# %%
with torch.cuda.device(0):
    max_value = float('inf')
    for i in range(start_epoch, epochs):
        train_avg_loss = 0
        val_avg_loss = 0
        train_avg_o_loss = 0
        train_avg_c_loss = 0
        train_avg_e_loss = 0
        train_avg_a_loss = 0
        train_avg_n_loss = 0
        val_avg_o_loss = 0
        val_avg_c_loss = 0
        val_avg_e_loss = 0
        val_avg_a_loss = 0
        val_avg_n_loss = 0
        for audiodata,fullshot,big_five_data in tqdm(train_dataloader):
            fullshot=fullshot.permute(0,4,1,2,3)
            big_five_data=big_five_data.permute(0,2,1)
            big_five_data=big_five_data.squeeze()
            audiodata = audiodata.to(device)
            # fullshot=imagecrop(fullshot,batchsz)
            fullshot = fullshot.to(device)
            big_five_data = big_five_data.to(device)
            optimizer.zero_grad()  # 기울기가 0이 됩니다.
            hypothesis = model(fullshot,audiodata) # 모델의 예측 결과를 저장합니다.
            loss = criterion(hypothesis, big_five_data)  # 예측된 결과와 실제 태그 사이의 손실 값을 저장합니다.
            loss.backward()  # 역방향 전파입니다. 
            optimizer.step()  
            train_avg_loss += loss  
        train_avg_loss=train_avg_loss/len(train_dataloader)
        with torch.no_grad():#validate
            for audiodata,fullshot,big_five_data in tqdm(val_dataloader):
                fullshot=fullshot.permute(0,4,1,2,3)
                # fullshot=imagecrop(fullshot,batchsz)
                big_five_data=big_five_data.permute(0,2,1)
                big_five_data=big_five_data.squeeze()
                audiodata = audiodata.to(device)
                fullshot = fullshot.to(device)
                big_five_data = big_five_data.to(device)
                hypothesis = model(fullshot,audiodata)
                val_loss = criterion(hypothesis, big_five_data)
                hypothesiso,hypothesisc,hypothesise,hypothesisa,hypothesisn=extract_ocean(hypothesis,batchsz)
                big_five_datao,big_five_datac,big_five_datae,big_five_dataa,big_five_datan=extract_ocean(big_five_data,batchsz)
                val_o_loss = criterion(hypothesiso, big_five_datao) 
                val_c_loss = criterion(hypothesisc, big_five_datac) 
                val_e_loss = criterion(hypothesise, big_five_datae) 
                val_a_loss = criterion(hypothesisa, big_five_dataa) 
                val_n_loss = criterion(hypothesisn, big_five_datan)  
                val_avg_loss += val_loss
                val_avg_o_loss += val_o_loss
                val_avg_c_loss += val_c_loss
                val_avg_e_loss += val_e_loss
                val_avg_a_loss += val_a_loss
                val_avg_n_loss += val_n_loss
            val_avg_loss=val_avg_loss/len(val_dataloader)
            val_avg_o_loss=val_avg_o_loss/len(val_dataloader)
            val_avg_c_loss=val_avg_c_loss/len(val_dataloader)
            val_avg_e_loss=val_avg_e_loss/len(val_dataloader)
            val_avg_a_loss=val_avg_a_loss/len(val_dataloader)
            val_avg_n_loss=val_avg_n_loss/len(val_dataloader)
        torch.cuda.empty_cache()
        # if (1-val_avg_loss)>=(1-max_value):
        start_epoch+=1
        if val_avg_loss < max_value:
            max_value=val_avg_loss
            torch.save({
                'epoch': i+1,
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'loss': val_avg_loss,
            }, save_model_file_path.format('model',start_epoch,'pth'))
        logger.debug('Epoch: {} , 1-MAE: {:.4f} , 1-val_avg_o_loss:{:.4f} , 1-val_avg_c_loss:{:.4f} , 1-val_avg_e_loss:{:.4f} , 1-val_avg_a_loss:{:.4f} , 1-val_avg_n_loss:{:.4f}'.format(i+1, 1-val_avg_loss, 1-val_avg_o_loss, 1-val_avg_c_loss, 1-val_avg_e_loss, 1-val_avg_a_loss,1-val_avg_n_loss))
# Out:
# 100%|██████████| 1263/1263 [04:50<00:00,  4.34it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.43it/s]
# [2024-07-01 10:55:31,278]::130357557::DEBUG::Epoch: 1 , 1-MAE: 0.8932 , 1-val_avg_o_loss:0.9030 , 1-val_avg_c_loss:0.8995 , 1-val_avg_e_loss:0.8854 , 1-val_avg_a_loss:0.8760 , 1-val_avg_n_loss:0.9021
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.33it/s]
# [2024-07-01 11:00:58,927]::130357557::DEBUG::Epoch: 2 , 1-MAE: 0.9025 , 1-val_avg_o_loss:0.8916 , 1-val_avg_c_loss:0.9030 , 1-val_avg_e_loss:0.9060 , 1-val_avg_a_loss:0.9021 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 11:06:27,407]::130357557::DEBUG::Epoch: 3 , 1-MAE: 0.9086 , 1-val_avg_o_loss:0.9134 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.8952 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:33<00:00, 12.46it/s]
# [2024-07-01 11:11:53,882]::130357557::DEBUG::Epoch: 4 , 1-MAE: 0.9061 , 1-val_avg_o_loss:0.8934 , 1-val_avg_c_loss:0.9071 , 1-val_avg_e_loss:0.9116 , 1-val_avg_a_loss:0.9117 , 1-val_avg_n_loss:0.9066
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.43it/s]
# [2024-07-01 11:17:22,353]::130357557::DEBUG::Epoch: 5 , 1-MAE: 0.9098 , 1-val_avg_o_loss:0.9059 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9144 , 1-val_avg_n_loss:0.9066
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.37it/s]
# [2024-07-01 11:22:50,977]::130357557::DEBUG::Epoch: 6 , 1-MAE: 0.9127 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9086 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9111 , 1-val_avg_n_loss:0.9131
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 11:28:18,458]::130357557::DEBUG::Epoch: 7 , 1-MAE: 0.9092 , 1-val_avg_o_loss:0.9104 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9154 , 1-val_avg_a_loss:0.8993 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 11:33:46,571]::130357557::DEBUG::Epoch: 8 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9159 , 1-val_avg_c_loss:0.9109 , 1-val_avg_e_loss:0.9139 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9132
# 100%|██████████| 1263/1263 [04:52<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 11:39:14,525]::130357557::DEBUG::Epoch: 9 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9149 , 1-val_avg_c_loss:0.9103 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9071
# 100%|██████████| 1263/1263 [04:53<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 11:44:43,011]::130357557::DEBUG::Epoch: 10 , 1-MAE: 0.9074 , 1-val_avg_o_loss:0.8909 , 1-val_avg_c_loss:0.9107 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9092 , 1-val_avg_n_loss:0.9132
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 11:50:11,600]::130357557::DEBUG::Epoch: 11 , 1-MAE: 0.9145 , 1-val_avg_o_loss:0.9188 , 1-val_avg_c_loss:0.9106 , 1-val_avg_e_loss:0.9160 , 1-val_avg_a_loss:0.9127 , 1-val_avg_n_loss:0.9146
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 11:55:40,037]::130357557::DEBUG::Epoch: 12 , 1-MAE: 0.9146 , 1-val_avg_o_loss:0.9173 , 1-val_avg_c_loss:0.9106 , 1-val_avg_e_loss:0.9159 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 12:01:07,844]::130357557::DEBUG::Epoch: 13 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9179 , 1-val_avg_c_loss:0.9131 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9131 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:53<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.29it/s]
# [2024-07-01 12:06:36,321]::130357557::DEBUG::Epoch: 14 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9149 , 1-val_avg_c_loss:0.9101 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9137
# 100%|██████████| 1263/1263 [04:52<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.28it/s]
# [2024-07-01 12:12:04,480]::130357557::DEBUG::Epoch: 15 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9120 , 1-val_avg_e_loss:0.9126 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9129
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.34it/s]
# [2024-07-01 12:17:31,989]::130357557::DEBUG::Epoch: 16 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9071 , 1-val_avg_e_loss:0.9142 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9142
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.33it/s]
# [2024-07-01 12:22:59,912]::130357557::DEBUG::Epoch: 17 , 1-MAE: 0.9151 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9125 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9145
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.39it/s]
# [2024-07-01 12:28:27,483]::130357557::DEBUG::Epoch: 18 , 1-MAE: 0.9150 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9115 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9194 , 1-val_avg_n_loss:0.9127
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.33it/s]
# [2024-07-01 12:33:55,021]::130357557::DEBUG::Epoch: 19 , 1-MAE: 0.9120 , 1-val_avg_o_loss:0.9022 , 1-val_avg_c_loss:0.9120 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9179 , 1-val_avg_n_loss:0.9138
# 100%|██████████| 1263/1263 [04:51<00:00,  4.34it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.30it/s]
# [2024-07-01 12:39:21,667]::130357557::DEBUG::Epoch: 20 , 1-MAE: 0.9148 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9108 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9127
# 100%|██████████| 1263/1263 [04:52<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.39it/s]
# [2024-07-01 12:44:49,614]::130357557::DEBUG::Epoch: 21 , 1-MAE: 0.9153 , 1-val_avg_o_loss:0.9195 , 1-val_avg_c_loss:0.9112 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9138
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 12:50:16,724]::130357557::DEBUG::Epoch: 22 , 1-MAE: 0.9147 , 1-val_avg_o_loss:0.9160 , 1-val_avg_c_loss:0.9097 , 1-val_avg_e_loss:0.9159 , 1-val_avg_a_loss:0.9183 , 1-val_avg_n_loss:0.9135
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.34it/s]
# [2024-07-01 12:55:44,962]::130357557::DEBUG::Epoch: 23 , 1-MAE: 0.9158 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9125 , 1-val_avg_e_loss:0.9156 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9148
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.39it/s]
# [2024-07-01 13:01:11,900]::130357557::DEBUG::Epoch: 24 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9116 , 1-val_avg_c_loss:0.9120 , 1-val_avg_e_loss:0.9167 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9120
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 13:06:38,640]::130357557::DEBUG::Epoch: 25 , 1-MAE: 0.9147 , 1-val_avg_o_loss:0.9165 , 1-val_avg_c_loss:0.9120 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9162 , 1-val_avg_n_loss:0.9139
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 13:12:06,147]::130357557::DEBUG::Epoch: 26 , 1-MAE: 0.9153 , 1-val_avg_o_loss:0.9186 , 1-val_avg_c_loss:0.9125 , 1-val_avg_e_loss:0.9124 , 1-val_avg_a_loss:0.9200 , 1-val_avg_n_loss:0.9130
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 13:17:33,019]::130357557::DEBUG::Epoch: 27 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9118 , 1-val_avg_c_loss:0.9127 , 1-val_avg_e_loss:0.9154 , 1-val_avg_a_loss:0.9189 , 1-val_avg_n_loss:0.9124
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 13:23:00,429]::130357557::DEBUG::Epoch: 28 , 1-MAE: 0.9158 , 1-val_avg_o_loss:0.9175 , 1-val_avg_c_loss:0.9126 , 1-val_avg_e_loss:0.9155 , 1-val_avg_a_loss:0.9190 , 1-val_avg_n_loss:0.9144
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.32it/s]
# [2024-07-01 13:28:28,011]::130357557::DEBUG::Epoch: 29 , 1-MAE: 0.9147 , 1-val_avg_o_loss:0.9176 , 1-val_avg_c_loss:0.9126 , 1-val_avg_e_loss:0.9135 , 1-val_avg_a_loss:0.9154 , 1-val_avg_n_loss:0.9145
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.43it/s]
# [2024-07-01 13:33:56,294]::130357557::DEBUG::Epoch: 30 , 1-MAE: 0.9164 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9123 , 1-val_avg_e_loss:0.9157 , 1-val_avg_a_loss:0.9204 , 1-val_avg_n_loss:0.9149
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.34it/s]
# [2024-07-01 13:39:24,259]::130357557::DEBUG::Epoch: 31 , 1-MAE: 0.9150 , 1-val_avg_o_loss:0.9186 , 1-val_avg_c_loss:0.9111 , 1-val_avg_e_loss:0.9163 , 1-val_avg_a_loss:0.9186 , 1-val_avg_n_loss:0.9105
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 13:44:51,668]::130357557::DEBUG::Epoch: 32 , 1-MAE: 0.9153 , 1-val_avg_o_loss:0.9190 , 1-val_avg_c_loss:0.9120 , 1-val_avg_e_loss:0.9136 , 1-val_avg_a_loss:0.9190 , 1-val_avg_n_loss:0.9130
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.39it/s]
# [2024-07-01 13:50:18,755]::130357557::DEBUG::Epoch: 33 , 1-MAE: 0.9162 , 1-val_avg_o_loss:0.9182 , 1-val_avg_c_loss:0.9141 , 1-val_avg_e_loss:0.9164 , 1-val_avg_a_loss:0.9189 , 1-val_avg_n_loss:0.9136
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.39it/s]
# [2024-07-01 13:55:45,830]::130357557::DEBUG::Epoch: 34 , 1-MAE: 0.9155 , 1-val_avg_o_loss:0.9187 , 1-val_avg_c_loss:0.9118 , 1-val_avg_e_loss:0.9170 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9125
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.43it/s]
# [2024-07-01 14:01:13,417]::130357557::DEBUG::Epoch: 35 , 1-MAE: 0.9155 , 1-val_avg_o_loss:0.9147 , 1-val_avg_c_loss:0.9131 , 1-val_avg_e_loss:0.9163 , 1-val_avg_a_loss:0.9200 , 1-val_avg_n_loss:0.9136
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 14:06:41,822]::130357557::DEBUG::Epoch: 36 , 1-MAE: 0.9164 , 1-val_avg_o_loss:0.9193 , 1-val_avg_c_loss:0.9129 , 1-val_avg_e_loss:0.9162 , 1-val_avg_a_loss:0.9194 , 1-val_avg_n_loss:0.9142
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 14:12:10,253]::130357557::DEBUG::Epoch: 37 , 1-MAE: 0.9164 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9131 , 1-val_avg_e_loss:0.9162 , 1-val_avg_a_loss:0.9200 , 1-val_avg_n_loss:0.9144
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.28it/s]
# [2024-07-01 14:17:37,385]::130357557::DEBUG::Epoch: 38 , 1-MAE: 0.9157 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9139 , 1-val_avg_e_loss:0.9166 , 1-val_avg_a_loss:0.9202 , 1-val_avg_n_loss:0.9123
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.37it/s]
# [2024-07-01 14:23:04,318]::130357557::DEBUG::Epoch: 39 , 1-MAE: 0.9157 , 1-val_avg_o_loss:0.9170 , 1-val_avg_c_loss:0.9127 , 1-val_avg_e_loss:0.9157 , 1-val_avg_a_loss:0.9192 , 1-val_avg_n_loss:0.9137
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 14:28:31,286]::130357557::DEBUG::Epoch: 40 , 1-MAE: 0.9162 , 1-val_avg_o_loss:0.9183 , 1-val_avg_c_loss:0.9133 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9202 , 1-val_avg_n_loss:0.9143
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.31it/s]
# [2024-07-01 14:33:59,100]::130357557::DEBUG::Epoch: 41 , 1-MAE: 0.9165 , 1-val_avg_o_loss:0.9197 , 1-val_avg_c_loss:0.9138 , 1-val_avg_e_loss:0.9160 , 1-val_avg_a_loss:0.9192 , 1-val_avg_n_loss:0.9139
# 100%|██████████| 1263/1263 [04:52<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.37it/s]
# [2024-07-01 14:39:27,816]::130357557::DEBUG::Epoch: 42 , 1-MAE: 0.9168 , 1-val_avg_o_loss:0.9190 , 1-val_avg_c_loss:0.9138 , 1-val_avg_e_loss:0.9170 , 1-val_avg_a_loss:0.9198 , 1-val_avg_n_loss:0.9143
# 100%|██████████| 1263/1263 [04:52<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 14:44:55,981]::130357557::DEBUG::Epoch: 43 , 1-MAE: 0.9161 , 1-val_avg_o_loss:0.9183 , 1-val_avg_c_loss:0.9129 , 1-val_avg_e_loss:0.9162 , 1-val_avg_a_loss:0.9183 , 1-val_avg_n_loss:0.9149
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.37it/s]
# [2024-07-01 14:50:23,173]::130357557::DEBUG::Epoch: 44 , 1-MAE: 0.9161 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9138 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9190 , 1-val_avg_n_loss:0.9141
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:33<00:00, 12.46it/s]
# [2024-07-01 14:55:50,127]::130357557::DEBUG::Epoch: 45 , 1-MAE: 0.9159 , 1-val_avg_o_loss:0.9181 , 1-val_avg_c_loss:0.9130 , 1-val_avg_e_loss:0.9146 , 1-val_avg_a_loss:0.9198 , 1-val_avg_n_loss:0.9139
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.30it/s]
# [2024-07-01 15:01:18,890]::130357557::DEBUG::Epoch: 46 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9190 , 1-val_avg_c_loss:0.9143 , 1-val_avg_e_loss:0.9165 , 1-val_avg_a_loss:0.9200 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 15:06:46,155]::130357557::DEBUG::Epoch: 47 , 1-MAE: 0.9167 , 1-val_avg_o_loss:0.9190 , 1-val_avg_c_loss:0.9138 , 1-val_avg_e_loss:0.9172 , 1-val_avg_a_loss:0.9195 , 1-val_avg_n_loss:0.9140
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 15:12:13,190]::130357557::DEBUG::Epoch: 48 , 1-MAE: 0.9166 , 1-val_avg_o_loss:0.9178 , 1-val_avg_c_loss:0.9140 , 1-val_avg_e_loss:0.9167 , 1-val_avg_a_loss:0.9198 , 1-val_avg_n_loss:0.9145
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 15:17:40,607]::130357557::DEBUG::Epoch: 49 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9199 , 1-val_avg_c_loss:0.9126 , 1-val_avg_e_loss:0.9171 , 1-val_avg_a_loss:0.9203 , 1-val_avg_n_loss:0.9151
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.33it/s]
# [2024-07-01 15:23:08,265]::130357557::DEBUG::Epoch: 50 , 1-MAE: 0.9165 , 1-val_avg_o_loss:0.9170 , 1-val_avg_c_loss:0.9141 , 1-val_avg_e_loss:0.9161 , 1-val_avg_a_loss:0.9201 , 1-val_avg_n_loss:0.9150
# 100%|██████████| 1263/1263 [04:52<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 15:28:36,379]::130357557::DEBUG::Epoch: 51 , 1-MAE: 0.9166 , 1-val_avg_o_loss:0.9177 , 1-val_avg_c_loss:0.9142 , 1-val_avg_e_loss:0.9169 , 1-val_avg_a_loss:0.9195 , 1-val_avg_n_loss:0.9146
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 15:34:04,282]::130357557::DEBUG::Epoch: 52 , 1-MAE: 0.9164 , 1-val_avg_o_loss:0.9180 , 1-val_avg_c_loss:0.9134 , 1-val_avg_e_loss:0.9167 , 1-val_avg_a_loss:0.9192 , 1-val_avg_n_loss:0.9147
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.33it/s]
# [2024-07-01 15:39:31,716]::130357557::DEBUG::Epoch: 53 , 1-MAE: 0.9164 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9141 , 1-val_avg_e_loss:0.9161 , 1-val_avg_a_loss:0.9198 , 1-val_avg_n_loss:0.9163
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:33<00:00, 12.47it/s]
# [2024-07-01 15:44:59,678]::130357557::DEBUG::Epoch: 54 , 1-MAE: 0.9171 , 1-val_avg_o_loss:0.9194 , 1-val_avg_c_loss:0.9125 , 1-val_avg_e_loss:0.9177 , 1-val_avg_a_loss:0.9206 , 1-val_avg_n_loss:0.9154
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 15:50:27,308]::130357557::DEBUG::Epoch: 55 , 1-MAE: 0.9171 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9145 , 1-val_avg_e_loss:0.9171 , 1-val_avg_a_loss:0.9198 , 1-val_avg_n_loss:0.9155
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.39it/s]
# [2024-07-01 15:55:54,107]::130357557::DEBUG::Epoch: 56 , 1-MAE: 0.9167 , 1-val_avg_o_loss:0.9188 , 1-val_avg_c_loss:0.9128 , 1-val_avg_e_loss:0.9166 , 1-val_avg_a_loss:0.9206 , 1-val_avg_n_loss:0.9148
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.27it/s]
# [2024-07-01 16:01:21,663]::130357557::DEBUG::Epoch: 57 , 1-MAE: 0.9167 , 1-val_avg_o_loss:0.9188 , 1-val_avg_c_loss:0.9121 , 1-val_avg_e_loss:0.9165 , 1-val_avg_a_loss:0.9208 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:52<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.42it/s]
# [2024-07-01 16:06:49,481]::130357557::DEBUG::Epoch: 58 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9137 , 1-val_avg_e_loss:0.9174 , 1-val_avg_a_loss:0.9208 , 1-val_avg_n_loss:0.9146
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.33it/s]
# [2024-07-01 16:12:17,364]::130357557::DEBUG::Epoch: 59 , 1-MAE: 0.9167 , 1-val_avg_o_loss:0.9187 , 1-val_avg_c_loss:0.9137 , 1-val_avg_e_loss:0.9177 , 1-val_avg_a_loss:0.9180 , 1-val_avg_n_loss:0.9154
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 16:17:44,847]::130357557::DEBUG::Epoch: 60 , 1-MAE: 0.9166 , 1-val_avg_o_loss:0.9186 , 1-val_avg_c_loss:0.9140 , 1-val_avg_e_loss:0.9163 , 1-val_avg_a_loss:0.9182 , 1-val_avg_n_loss:0.9160
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 16:23:12,767]::130357557::DEBUG::Epoch: 61 , 1-MAE: 0.9169 , 1-val_avg_o_loss:0.9182 , 1-val_avg_c_loss:0.9137 , 1-val_avg_e_loss:0.9171 , 1-val_avg_a_loss:0.9201 , 1-val_avg_n_loss:0.9155
# 100%|██████████| 1263/1263 [04:52<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.43it/s]
# [2024-07-01 16:28:40,653]::130357557::DEBUG::Epoch: 62 , 1-MAE: 0.9168 , 1-val_avg_o_loss:0.9191 , 1-val_avg_c_loss:0.9131 , 1-val_avg_e_loss:0.9171 , 1-val_avg_a_loss:0.9200 , 1-val_avg_n_loss:0.9146
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 16:34:09,031]::130357557::DEBUG::Epoch: 63 , 1-MAE: 0.9172 , 1-val_avg_o_loss:0.9194 , 1-val_avg_c_loss:0.9147 , 1-val_avg_e_loss:0.9164 , 1-val_avg_a_loss:0.9199 , 1-val_avg_n_loss:0.9155
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.29it/s]
# [2024-07-01 16:39:36,393]::130357557::DEBUG::Epoch: 64 , 1-MAE: 0.9171 , 1-val_avg_o_loss:0.9184 , 1-val_avg_c_loss:0.9141 , 1-val_avg_e_loss:0.9173 , 1-val_avg_a_loss:0.9203 , 1-val_avg_n_loss:0.9153
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.32it/s]
# [2024-07-01 16:45:03,929]::130357557::DEBUG::Epoch: 65 , 1-MAE: 0.9164 , 1-val_avg_o_loss:0.9168 , 1-val_avg_c_loss:0.9134 , 1-val_avg_e_loss:0.9174 , 1-val_avg_a_loss:0.9193 , 1-val_avg_n_loss:0.9150
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.32it/s]
# [2024-07-01 16:50:31,642]::130357557::DEBUG::Epoch: 66 , 1-MAE: 0.9160 , 1-val_avg_o_loss:0.9165 , 1-val_avg_c_loss:0.9131 , 1-val_avg_e_loss:0.9166 , 1-val_avg_a_loss:0.9192 , 1-val_avg_n_loss:0.9146
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 16:55:59,296]::130357557::DEBUG::Epoch: 67 , 1-MAE: 0.9168 , 1-val_avg_o_loss:0.9191 , 1-val_avg_c_loss:0.9134 , 1-val_avg_e_loss:0.9174 , 1-val_avg_a_loss:0.9179 , 1-val_avg_n_loss:0.9161
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.34it/s]
# [2024-07-01 17:01:26,307]::130357557::DEBUG::Epoch: 68 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9195 , 1-val_avg_c_loss:0.9136 , 1-val_avg_e_loss:0.9166 , 1-val_avg_a_loss:0.9202 , 1-val_avg_n_loss:0.9149
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.34it/s]
# [2024-07-01 17:06:53,649]::130357557::DEBUG::Epoch: 69 , 1-MAE: 0.9168 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9129 , 1-val_avg_e_loss:0.9171 , 1-val_avg_a_loss:0.9199 , 1-val_avg_n_loss:0.9156
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 17:12:21,450]::130357557::DEBUG::Epoch: 70 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9189 , 1-val_avg_c_loss:0.9124 , 1-val_avg_e_loss:0.9178 , 1-val_avg_a_loss:0.9199 , 1-val_avg_n_loss:0.9159
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 17:17:48,665]::130357557::DEBUG::Epoch: 71 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9183 , 1-val_avg_c_loss:0.9139 , 1-val_avg_e_loss:0.9172 , 1-val_avg_a_loss:0.9200 , 1-val_avg_n_loss:0.9154
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.28it/s]
# [2024-07-01 17:23:16,709]::130357557::DEBUG::Epoch: 72 , 1-MAE: 0.9165 , 1-val_avg_o_loss:0.9186 , 1-val_avg_c_loss:0.9126 , 1-val_avg_e_loss:0.9174 , 1-val_avg_a_loss:0.9190 , 1-val_avg_n_loss:0.9151
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.37it/s]
# [2024-07-01 17:28:44,273]::130357557::DEBUG::Epoch: 73 , 1-MAE: 0.9169 , 1-val_avg_o_loss:0.9186 , 1-val_avg_c_loss:0.9129 , 1-val_avg_e_loss:0.9173 , 1-val_avg_a_loss:0.9197 , 1-val_avg_n_loss:0.9158
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 17:34:11,937]::130357557::DEBUG::Epoch: 74 , 1-MAE: 0.9169 , 1-val_avg_o_loss:0.9186 , 1-val_avg_c_loss:0.9141 , 1-val_avg_e_loss:0.9181 , 1-val_avg_a_loss:0.9185 , 1-val_avg_n_loss:0.9153
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.30it/s]
# [2024-07-01 17:39:39,914]::130357557::DEBUG::Epoch: 75 , 1-MAE: 0.9160 , 1-val_avg_o_loss:0.9177 , 1-val_avg_c_loss:0.9134 , 1-val_avg_e_loss:0.9176 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9139
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.37it/s]
# [2024-07-01 17:45:08,477]::130357557::DEBUG::Epoch: 76 , 1-MAE: 0.9173 , 1-val_avg_o_loss:0.9192 , 1-val_avg_c_loss:0.9139 , 1-val_avg_e_loss:0.9175 , 1-val_avg_a_loss:0.9206 , 1-val_avg_n_loss:0.9151
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.34it/s]
# [2024-07-01 17:50:36,440]::130357557::DEBUG::Epoch: 77 , 1-MAE: 0.9167 , 1-val_avg_o_loss:0.9177 , 1-val_avg_c_loss:0.9141 , 1-val_avg_e_loss:0.9171 , 1-val_avg_a_loss:0.9195 , 1-val_avg_n_loss:0.9153
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 17:56:04,291]::130357557::DEBUG::Epoch: 78 , 1-MAE: 0.9164 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9135 , 1-val_avg_e_loss:0.9157 , 1-val_avg_a_loss:0.9198 , 1-val_avg_n_loss:0.9145
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:33<00:00, 12.45it/s]
# [2024-07-01 18:01:31,348]::130357557::DEBUG::Epoch: 79 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9187 , 1-val_avg_c_loss:0.9134 , 1-val_avg_e_loss:0.9178 , 1-val_avg_a_loss:0.9198 , 1-val_avg_n_loss:0.9153
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.32it/s]
# [2024-07-01 18:06:59,697]::130357557::DEBUG::Epoch: 80 , 1-MAE: 0.9174 , 1-val_avg_o_loss:0.9191 , 1-val_avg_c_loss:0.9140 , 1-val_avg_e_loss:0.9174 , 1-val_avg_a_loss:0.9205 , 1-val_avg_n_loss:0.9157
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.31it/s]
# [2024-07-01 18:12:27,601]::130357557::DEBUG::Epoch: 81 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9187 , 1-val_avg_c_loss:0.9139 , 1-val_avg_e_loss:0.9172 , 1-val_avg_a_loss:0.9203 , 1-val_avg_n_loss:0.9149
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.31it/s]
# [2024-07-01 18:17:55,921]::130357557::DEBUG::Epoch: 82 , 1-MAE: 0.9174 , 1-val_avg_o_loss:0.9192 , 1-val_avg_c_loss:0.9135 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9200 , 1-val_avg_n_loss:0.9161
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.32it/s]
# [2024-07-01 18:23:23,805]::130357557::DEBUG::Epoch: 83 , 1-MAE: 0.9173 , 1-val_avg_o_loss:0.9180 , 1-val_avg_c_loss:0.9144 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9203 , 1-val_avg_n_loss:0.9160
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.33it/s]
# [2024-07-01 18:28:51,654]::130357557::DEBUG::Epoch: 84 , 1-MAE: 0.9172 , 1-val_avg_o_loss:0.9184 , 1-val_avg_c_loss:0.9141 , 1-val_avg_e_loss:0.9184 , 1-val_avg_a_loss:0.9198 , 1-val_avg_n_loss:0.9156
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 18:34:19,501]::130357557::DEBUG::Epoch: 85 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9195 , 1-val_avg_c_loss:0.9128 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9195 , 1-val_avg_n_loss:0.9154
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.33it/s]
# [2024-07-01 18:39:46,985]::130357557::DEBUG::Epoch: 86 , 1-MAE: 0.9167 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9135 , 1-val_avg_e_loss:0.9171 , 1-val_avg_a_loss:0.9187 , 1-val_avg_n_loss:0.9155
# 100%|██████████| 1263/1263 [04:53<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.43it/s]
# [2024-07-01 18:45:15,064]::130357557::DEBUG::Epoch: 87 , 1-MAE: 0.9165 , 1-val_avg_o_loss:0.9180 , 1-val_avg_c_loss:0.9133 , 1-val_avg_e_loss:0.9164 , 1-val_avg_a_loss:0.9193 , 1-val_avg_n_loss:0.9156
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.32it/s]
# [2024-07-01 18:50:43,606]::130357557::DEBUG::Epoch: 88 , 1-MAE: 0.9174 , 1-val_avg_o_loss:0.9191 , 1-val_avg_c_loss:0.9140 , 1-val_avg_e_loss:0.9176 , 1-val_avg_a_loss:0.9205 , 1-val_avg_n_loss:0.9157
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:33<00:00, 12.46it/s]
# [2024-07-01 18:56:11,734]::130357557::DEBUG::Epoch: 89 , 1-MAE: 0.9175 , 1-val_avg_o_loss:0.9196 , 1-val_avg_c_loss:0.9143 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9201 , 1-val_avg_n_loss:0.9158
# 100%|██████████| 1263/1263 [04:53<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.28it/s]
# [2024-07-01 19:01:40,253]::130357557::DEBUG::Epoch: 90 , 1-MAE: 0.9167 , 1-val_avg_o_loss:0.9182 , 1-val_avg_c_loss:0.9140 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9191 , 1-val_avg_n_loss:0.9144
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 19:07:07,934]::130357557::DEBUG::Epoch: 91 , 1-MAE: 0.9167 , 1-val_avg_o_loss:0.9183 , 1-val_avg_c_loss:0.9129 , 1-val_avg_e_loss:0.9175 , 1-val_avg_a_loss:0.9199 , 1-val_avg_n_loss:0.9147
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.33it/s]
# [2024-07-01 19:12:35,561]::130357557::DEBUG::Epoch: 92 , 1-MAE: 0.9166 , 1-val_avg_o_loss:0.9181 , 1-val_avg_c_loss:0.9130 , 1-val_avg_e_loss:0.9179 , 1-val_avg_a_loss:0.9181 , 1-val_avg_n_loss:0.9158
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 19:18:03,131]::130357557::DEBUG::Epoch: 93 , 1-MAE: 0.9168 , 1-val_avg_o_loss:0.9180 , 1-val_avg_c_loss:0.9135 , 1-val_avg_e_loss:0.9172 , 1-val_avg_a_loss:0.9203 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.39it/s]
# [2024-07-01 19:23:30,511]::130357557::DEBUG::Epoch: 94 , 1-MAE: 0.9167 , 1-val_avg_o_loss:0.9174 , 1-val_avg_c_loss:0.9134 , 1-val_avg_e_loss:0.9178 , 1-val_avg_a_loss:0.9203 , 1-val_avg_n_loss:0.9146
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 19:28:57,950]::130357557::DEBUG::Epoch: 95 , 1-MAE: 0.9171 , 1-val_avg_o_loss:0.9182 , 1-val_avg_c_loss:0.9140 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9199 , 1-val_avg_n_loss:0.9156
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.44it/s]
# [2024-07-01 19:34:24,999]::130357557::DEBUG::Epoch: 96 , 1-MAE: 0.9169 , 1-val_avg_o_loss:0.9182 , 1-val_avg_c_loss:0.9134 , 1-val_avg_e_loss:0.9174 , 1-val_avg_a_loss:0.9202 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 19:39:52,848]::130357557::DEBUG::Epoch: 97 , 1-MAE: 0.9166 , 1-val_avg_o_loss:0.9180 , 1-val_avg_c_loss:0.9132 , 1-val_avg_e_loss:0.9179 , 1-val_avg_a_loss:0.9197 , 1-val_avg_n_loss:0.9141
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 19:45:20,186]::130357557::DEBUG::Epoch: 98 , 1-MAE: 0.9171 , 1-val_avg_o_loss:0.9184 , 1-val_avg_c_loss:0.9139 , 1-val_avg_e_loss:0.9177 , 1-val_avg_a_loss:0.9205 , 1-val_avg_n_loss:0.9150
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 19:50:47,677]::130357557::DEBUG::Epoch: 99 , 1-MAE: 0.9169 , 1-val_avg_o_loss:0.9180 , 1-val_avg_c_loss:0.9131 , 1-val_avg_e_loss:0.9176 , 1-val_avg_a_loss:0.9197 , 1-val_avg_n_loss:0.9159
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.29it/s]
# [2024-07-01 19:56:15,651]::130357557::DEBUG::Epoch: 100 , 1-MAE: 0.9165 , 1-val_avg_o_loss:0.9183 , 1-val_avg_c_loss:0.9131 , 1-val_avg_e_loss:0.9177 , 1-val_avg_a_loss:0.9189 , 1-val_avg_n_loss:0.9146
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 20:01:42,377]::130357557::DEBUG::Epoch: 101 , 1-MAE: 0.9163 , 1-val_avg_o_loss:0.9183 , 1-val_avg_c_loss:0.9138 , 1-val_avg_e_loss:0.9172 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.34it/s]
# [2024-07-01 20:07:10,308]::130357557::DEBUG::Epoch: 102 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9184 , 1-val_avg_c_loss:0.9133 , 1-val_avg_e_loss:0.9178 , 1-val_avg_a_loss:0.9209 , 1-val_avg_n_loss:0.9146
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.44it/s]
# [2024-07-01 20:12:37,099]::130357557::DEBUG::Epoch: 103 , 1-MAE: 0.9170 , 1-val_avg_o_loss:0.9190 , 1-val_avg_c_loss:0.9132 , 1-val_avg_e_loss:0.9182 , 1-val_avg_a_loss:0.9193 , 1-val_avg_n_loss:0.9154
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 20:18:04,877]::130357557::DEBUG::Epoch: 104 , 1-MAE: 0.9171 , 1-val_avg_o_loss:0.9190 , 1-val_avg_c_loss:0.9136 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9197 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:51<00:00,  4.33it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 20:23:32,035]::130357557::DEBUG::Epoch: 105 , 1-MAE: 0.9174 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9144 , 1-val_avg_e_loss:0.9182 , 1-val_avg_a_loss:0.9199 , 1-val_avg_n_loss:0.9159
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 20:28:59,760]::130357557::DEBUG::Epoch: 106 , 1-MAE: 0.9174 , 1-val_avg_o_loss:0.9191 , 1-val_avg_c_loss:0.9139 , 1-val_avg_e_loss:0.9179 , 1-val_avg_a_loss:0.9206 , 1-val_avg_n_loss:0.9155
# 100%|██████████| 1263/1263 [04:52<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.43it/s]
# [2024-07-01 20:34:27,631]::130357557::DEBUG::Epoch: 107 , 1-MAE: 0.9171 , 1-val_avg_o_loss:0.9179 , 1-val_avg_c_loss:0.9134 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9207 , 1-val_avg_n_loss:0.9153
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 20:39:55,342]::130357557::DEBUG::Epoch: 108 , 1-MAE: 0.9172 , 1-val_avg_o_loss:0.9189 , 1-val_avg_c_loss:0.9140 , 1-val_avg_e_loss:0.9178 , 1-val_avg_a_loss:0.9199 , 1-val_avg_n_loss:0.9155
# 100%|██████████| 1263/1263 [04:52<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.34it/s]
# [2024-07-01 20:45:23,345]::130357557::DEBUG::Epoch: 109 , 1-MAE: 0.9168 , 1-val_avg_o_loss:0.9180 , 1-val_avg_c_loss:0.9136 , 1-val_avg_e_loss:0.9173 , 1-val_avg_a_loss:0.9195 , 1-val_avg_n_loss:0.9156
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 20:50:51,043]::130357557::DEBUG::Epoch: 110 , 1-MAE: 0.9172 , 1-val_avg_o_loss:0.9186 , 1-val_avg_c_loss:0.9136 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9209 , 1-val_avg_n_loss:0.9151
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.37it/s]
# [2024-07-01 20:56:18,786]::130357557::DEBUG::Epoch: 111 , 1-MAE: 0.9168 , 1-val_avg_o_loss:0.9174 , 1-val_avg_c_loss:0.9140 , 1-val_avg_e_loss:0.9178 , 1-val_avg_a_loss:0.9199 , 1-val_avg_n_loss:0.9148
# 100%|██████████| 1263/1263 [04:53<00:00,  4.31it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.40it/s]
# [2024-07-01 21:01:46,937]::130357557::DEBUG::Epoch: 112 , 1-MAE: 0.9171 , 1-val_avg_o_loss:0.9187 , 1-val_avg_c_loss:0.9135 , 1-val_avg_e_loss:0.9175 , 1-val_avg_a_loss:0.9202 , 1-val_avg_n_loss:0.9157
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.35it/s]
# [2024-07-01 21:07:14,515]::130357557::DEBUG::Epoch: 113 , 1-MAE: 0.9172 , 1-val_avg_o_loss:0.9189 , 1-val_avg_c_loss:0.9135 , 1-val_avg_e_loss:0.9177 , 1-val_avg_a_loss:0.9201 , 1-val_avg_n_loss:0.9157
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.36it/s]
# [2024-07-01 21:12:42,177]::130357557::DEBUG::Epoch: 114 , 1-MAE: 0.9171 , 1-val_avg_o_loss:0.9187 , 1-val_avg_c_loss:0.9136 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9203 , 1-val_avg_n_loss:0.9148
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.32it/s]
# [2024-07-01 21:18:09,712]::130357557::DEBUG::Epoch: 115 , 1-MAE: 0.9166 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9128 , 1-val_avg_e_loss:0.9167 , 1-val_avg_a_loss:0.9197 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.38it/s]
# [2024-07-01 21:23:37,034]::130357557::DEBUG::Epoch: 116 , 1-MAE: 0.9172 , 1-val_avg_o_loss:0.9185 , 1-val_avg_c_loss:0.9140 , 1-val_avg_e_loss:0.9179 , 1-val_avg_a_loss:0.9203 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.30it/s]
# [2024-07-01 21:29:04,992]::130357557::DEBUG::Epoch: 117 , 1-MAE: 0.9173 , 1-val_avg_o_loss:0.9188 , 1-val_avg_c_loss:0.9136 , 1-val_avg_e_loss:0.9185 , 1-val_avg_a_loss:0.9201 , 1-val_avg_n_loss:0.9153
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.37it/s]
# [2024-07-01 21:34:32,713]::130357557::DEBUG::Epoch: 118 , 1-MAE: 0.9169 , 1-val_avg_o_loss:0.9184 , 1-val_avg_c_loss:0.9136 , 1-val_avg_e_loss:0.9177 , 1-val_avg_a_loss:0.9199 , 1-val_avg_n_loss:0.9152
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.39it/s]
# [2024-07-01 21:40:00,352]::130357557::DEBUG::Epoch: 119 , 1-MAE: 0.9169 , 1-val_avg_o_loss:0.9184 , 1-val_avg_c_loss:0.9134 , 1-val_avg_e_loss:0.9180 , 1-val_avg_a_loss:0.9192 , 1-val_avg_n_loss:0.9155
# 100%|██████████| 1263/1263 [04:52<00:00,  4.32it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.37it/s]
# [2024-07-01 21:45:27,809]::130357557::DEBUG::Epoch: 120 , 1-MAE: 0.9165 , 1-val_avg_o_loss:0.9182 , 1-val_avg_c_loss:0.9125 , 1-val_avg_e_loss:0.9176 , 1-val_avg_a_loss:0.9192 , 1-val_avg_n_loss:0.9148

# %%
# from torchinfo import summary

# summary(model, input_size = (4,15,4,3,224,224))

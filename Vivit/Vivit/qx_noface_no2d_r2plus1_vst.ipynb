# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import os
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import random
import cv2
# from vgg16 import VGG16_LSTM
import pickle
import torch.nn as nn
import torch
import datetime
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms, utils, models
from torch.utils.data import Dataset, DataLoader
from facenet_pytorch import MTCNN
import logging
import torch
import torch.nn as nn
from vivit import ViViTBackbone
import gc
from einops import rearrange
from tqdm import tqdm
# from kw_r2plus1d_video_swin_transformer import SwinTransformer3D
batchsz = 4
frame_nums=15
start_epoch = 0
test_flage=False
model_name ="fullshot"
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('[%(asctime)s]::%(module)s::%(levelname)s::%(message)s')
streamHandler = logging.StreamHandler()
streamHandler.setFormatter(formatter)
fileHandler = logging.FileHandler('./LOG/personalityLog.log')
fileHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.addHandler(fileHandler)
USE_CUDA = torch.cuda.is_available()
# device = torch.device('cuda:1' if USE_CUDA else 'cpu')

# %%
logger.debug('============={}+Video Vision Transformer Strat!============='.format(model_name))
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:1' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:', device)
# Out:
# [2024-07-03 10:21:18,205]::3493104939::DEBUG::=============fullshot+Video Vision Transformer Strat!=============
# True
# 학습을 진행하는 기기: cuda:1

# %%
def getdata(pathname,datatype):
    if datatype=="train":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            # train_data_set.extend(pickle.load(output_file))
            final_data_set.extend(pickle.load(output_file))
            # print(i)
        return final_data_set
    elif datatype=="valid":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            valid_data_set=[]
            final_data_set.extend(pickle.load(output_file))
            del valid_data_set
        return final_data_set
print(1)
# Out:
# 1

# %%
save_model_file_path = './save_swintransformer_folder/{}_{}.{}'
mtcnn= MTCNN(image_size=224, margin=0, min_face_size= 20, thresholds=[0.6, 0.7, 0.7], post_process=True)
# test_set_data=getdata("/home/ssrlab/qx/code/test/video-swin-transformer-pytorch/data/15Frames/test_set.dat","test")
# test_set_data=test_set_data[:datasize("test",batchsz)]
print(1)
# Out:
# 1

# %%
validation_set_data=getdata("/home/ssrlab/qx/video-swin-transformer-pytorch/data/15Frames/margin011/valid_set.dat","valid")
# validation_set_data=reshape_to_expected_validinput(validation_set_data)
print(1)
# Out:
# 1

# %%
train_set_data=getdata("/home/ssrlab/qx/video-swin-transformer-pytorch/data/15Frames/margin011/train_set.dat","train")
# train_set_data=reshape_to_expected_traininput(train_set_data)
print(1)
# Out:
# 1

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
])
print(1)
# Out:
# 1

# %%
class ChalearnDataset(Dataset):
    def __init__(self,fullshot,tagdata,transform=None):
        self.fullshot=fullshot
        self.tagdata=tagdata
        self.transform = transform  # 표준화 여부
    def __len__(self):
        return len(self.fullshot)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()#텐서의 경우 목록으로 돌아가기
        fullshot=self.fullshot[idx]
        fullshot=torch.FloatTensor(fullshot)
        big_five_sorces=self.tagdata[idx]
        big_five_sorces = torch.FloatTensor(big_five_sorces)
        return fullshot,big_five_sorces
print(1)
# Out:
# 1

# %%
num_workerssz = 20
lr = 3e-05
epochs = 120
print(1)
# Out:
# 1

# %%
train_set_data = ChalearnDataset(fullshot = train_set_data[1],tagdata=train_set_data[5],transform=transform)
val_set_data = ChalearnDataset(fullshot = validation_set_data[1],tagdata=validation_set_data[5],transform=transform)
train_dataloader = DataLoader(dataset=train_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
val_dataloader = DataLoader(dataset=val_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
max_value=0
print(1)
# Out:
# 1

# %%
model=ViViTBackbone(2, 14, 14, 2, 2, 2, 5, 96, 6, 10, 8, model=2)#num_frames=frame_nums,batchsz = batchsz
model.to(device)
criterion = torch.nn.L1Loss().to(device)  # 손실함수
optimizer = torch.optim.AdamW(model.parameters(), lr=lr) # 옵티마이저

if test_flage==True:
    checkpoint=torch.load(save_model_file_path.format('model',start_epoch,'pth'), map_location=device)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    # criterion.load_state_dict(checkpoint["loss"])
train_avg_loss0=[]
val_avg_loss0=[]
print(1)
# Out:
# 1

# %%
from torchinfo import summary

summary(model, input_size = ((4, 3,15, 224, 224)), col_names = ['input_size','output_size','num_params'])
# Out:
# ==================================================================================================================================
# Layer (type:depth-idx)                                  Input Shape               Output Shape              Param #
# ==================================================================================================================================
# ViViTBackbone                                           [4, 3, 15, 224, 224]      [4, 5]                    3,540,005
# ├─VideoResNet: 1-1                                      [4, 3, 15, 224, 224]      [4, 512, 2, 14, 14]       205,200
# │    └─R2Plus1dStem: 2-1                                [4, 3, 15, 224, 224]      [4, 64, 15, 112, 112]     --
# │    │    └─Conv3d: 3-1                                 [4, 3, 15, 224, 224]      [4, 45, 15, 112, 112]     6,615
# │    │    └─BatchNorm3d: 3-2                            [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     90
# │    │    └─ReLU: 3-3                                   [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     --
# │    │    └─Conv3d: 3-4                                 [4, 45, 15, 112, 112]     [4, 64, 15, 112, 112]     8,640
# │    │    └─BatchNorm3d: 3-5                            [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     128
# │    │    └─ReLU: 3-6                                   [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    └─Sequential: 2-2                                  [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    │    └─BasicBlock: 3-7                             [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    │    └─BasicBlock: 3-8                             [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    └─Sequential: 2-3                                  [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       --
# │    │    └─BasicBlock: 3-9                             [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       583,960
# │    │    └─BasicBlock: 3-10                            [4, 128, 8, 56, 56]       [4, 128, 8, 56, 56]       886,400
# │    └─Sequential: 2-4                                  [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       --
# │    │    └─BasicBlock: 3-11                            [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       2,332,464
# │    │    └─BasicBlock: 3-12                            [4, 256, 4, 28, 28]       [4, 256, 4, 28, 28]       3,542,272
# │    └─Sequential: 2-5                                  [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       --
# │    │    └─BasicBlock: 3-13                            [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       9,333,092
# │    │    └─BasicBlock: 3-14                            [4, 512, 2, 14, 14]       [4, 512, 2, 14, 14]       14,162,432
# ├─Model2: 1-2                                           [4, 2, 512, 14, 14]       [4, 5]                    9,792
# │    └─Sequential: 2-6                                  [4, 2, 512, 14, 14]       [4, 2, 49, 96]            --
# │    │    └─Rearrange: 3-15                             [4, 2, 512, 14, 14]       [4, 2, 49, 2048]          --
# │    │    └─Linear: 3-16                                [4, 2, 49, 2048]          [4, 2, 49, 96]            196,704
# │    └─Dropout: 2-7                                     [4, 2, 50, 96]            [4, 2, 50, 96]            --
# │    └─Transformer: 2-8                                 [8, 50, 96]               [8, 50, 96]               --
# │    │    └─ModuleList: 3-17                            --                        --                        1,922,688
# │    │    └─LayerNorm: 3-18                             [8, 50, 96]               [8, 50, 96]               192
# │    └─Transformer: 2-9                                 [4, 3, 96]                [4, 3, 96]                --
# │    │    └─ModuleList: 3-19                            --                        --                        1,922,688
# │    │    └─LayerNorm: 3-20                             [4, 3, 96]                [4, 3, 96]                192
# │    └─Sequential: 2-10                                 [4, 96]                   [4, 5]                    --
# │    │    └─LayerNorm: 3-21                             [4, 96]                   [4, 96]                   192
# │    │    └─Linear: 3-22                                [4, 96]                   [4, 5]                    485
# ==================================================================================================================================
# Total params: 39,098,263
# Trainable params: 39,098,263
# Non-trainable params: 0
# Total mult-adds (G): 623.70
# ==================================================================================================================================
# Input size (MB): 36.13
# Forward/backward pass size (MB): 15356.13
# Params size (MB): 141.37
# Estimated Total Size (MB): 15533.63
# ==================================================================================================================================

# %%
def extract_ocean(data,batch_size):
    o=[]
    c=[]
    e=[]
    a=[]
    n=[]
    for i in range(batch_size):
        o.append(data[i][0].item())
        c.append(data[i][1].item())
        e.append(data[i][2].item())
        a.append(data[i][3].item())
        n.append(data[i][4].item())
    o = torch.tensor(o) 
    c = torch.tensor(c) 
    e = torch.tensor(e) 
    a = torch.tensor(a) 
    n = torch.tensor(n) 
    return o,c,e,a,n

# %%
def imagecrop(imagedata,batchsz):
    # convert_tensor= transforms.ToTensor()
    output=[]
    imagedata=imagedata.permute(0,2,1,3,4)
    for j in range(batchsz):#비디오 데이터 batchsz(9) 개 있다
        firstoutput=[]
        for i in range(len(imagedata[j])):#imagedata에 15개의 프레임이 있다
            # temp = convert_tensor(imagedata[i])
            #이미지를 나누
            temp = imagedata[j][i].unfold(1,2,2).unfold(2,2,2)
            temp = rearrange(temp, 'c h1 w1 h w -> (h1 w1) c h w')
            firstoutput.append(temp)
        firstoutput = torch.stack(firstoutput,0)
        output.append(firstoutput)
    output = torch.stack(output,0)
    return output

# %%
with torch.cuda.device(1):
    max_value = float('inf')
    for i in range(start_epoch, epochs):
        train_avg_loss = 0
        val_avg_loss = 0
        train_avg_o_loss = 0
        train_avg_c_loss = 0
        train_avg_e_loss = 0
        train_avg_a_loss = 0
        train_avg_n_loss = 0
        val_avg_o_loss = 0
        val_avg_c_loss = 0
        val_avg_e_loss = 0
        val_avg_a_loss = 0
        val_avg_n_loss = 0
        for fullshot,big_five_data in tqdm(train_dataloader):
            fullshot=fullshot.permute(0,4,1,2,3)
            big_five_data=big_five_data.permute(0,2,1)
            big_five_data=big_five_data.squeeze()
            # fullshot=imagecrop(fullshot,batchsz)
            fullshot = fullshot.to(device)
            big_five_data = big_five_data.to(device)
            optimizer.zero_grad()  # 기울기가 0이 됩니다.
            hypothesis = model(fullshot) # 모델의 예측 결과를 저장합니다.
            loss = criterion(hypothesis, big_five_data)  # 예측된 결과와 실제 태그 사이의 손실 값을 저장합니다.
            loss.backward()  # 역방향 전파입니다. 
            optimizer.step()  
            train_avg_loss += loss  
        train_avg_loss=train_avg_loss/len(train_dataloader)
        with torch.no_grad():#validate
            for fullshot,big_five_data in tqdm(val_dataloader):
                fullshot=fullshot.permute(0,4,1,2,3)
                # fullshot=imagecrop(fullshot,batchsz)
                big_five_data=big_five_data.permute(0,2,1)
                big_five_data=big_five_data.squeeze()
                fullshot = fullshot.to(device)
                big_five_data = big_five_data.to(device)
                hypothesis = model(fullshot)
                val_loss = criterion(hypothesis, big_five_data)
                hypothesiso,hypothesisc,hypothesise,hypothesisa,hypothesisn=extract_ocean(hypothesis,batchsz)
                big_five_datao,big_five_datac,big_five_datae,big_five_dataa,big_five_datan=extract_ocean(big_five_data,batchsz)
                val_o_loss = criterion(hypothesiso, big_five_datao) 
                val_c_loss = criterion(hypothesisc, big_five_datac) 
                val_e_loss = criterion(hypothesise, big_five_datae) 
                val_a_loss = criterion(hypothesisa, big_five_dataa) 
                val_n_loss = criterion(hypothesisn, big_five_datan)  
                val_avg_loss += val_loss
                val_avg_o_loss += val_o_loss
                val_avg_c_loss += val_c_loss
                val_avg_e_loss += val_e_loss
                val_avg_a_loss += val_a_loss
                val_avg_n_loss += val_n_loss
            val_avg_loss=val_avg_loss/len(val_dataloader)
            val_avg_o_loss=val_avg_o_loss/len(val_dataloader)
            val_avg_c_loss=val_avg_c_loss/len(val_dataloader)
            val_avg_e_loss=val_avg_e_loss/len(val_dataloader)
            val_avg_a_loss=val_avg_a_loss/len(val_dataloader)
            val_avg_n_loss=val_avg_n_loss/len(val_dataloader)
        torch.cuda.empty_cache()
        # if (1-val_avg_loss)>=(1-max_value):
        start_epoch+=1
        if val_avg_loss < max_value:
            max_value=val_avg_loss
            torch.save({
                'epoch': i+1,
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'loss': val_avg_loss,
            }, save_model_file_path.format('model',start_epoch,'pth'))
        logger.debug('Epoch: {} , 1-MAE: {:.4f} , 1-val_avg_o_loss:{:.4f} , 1-val_avg_c_loss:{:.4f} , 1-val_avg_e_loss:{:.4f} , 1-val_avg_a_loss:{:.4f} , 1-val_avg_n_loss:{:.4f}'.format(i+1, 1-val_avg_loss, 1-val_avg_o_loss, 1-val_avg_c_loss, 1-val_avg_e_loss, 1-val_avg_a_loss,1-val_avg_n_loss))
# Out:
# 100%|██████████| 1263/1263 [04:33<00:00,  4.62it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 10:26:37,806]::3799835291::DEBUG::Epoch: 1 , 1-MAE: 0.8869 , 1-val_avg_o_loss:0.8950 , 1-val_avg_c_loss:0.8911 , 1-val_avg_e_loss:0.8757 , 1-val_avg_a_loss:0.8730 , 1-val_avg_n_loss:0.8998
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 10:31:47,244]::3799835291::DEBUG::Epoch: 2 , 1-MAE: 0.8920 , 1-val_avg_o_loss:0.9048 , 1-val_avg_c_loss:0.8949 , 1-val_avg_e_loss:0.8658 , 1-val_avg_a_loss:0.8922 , 1-val_avg_n_loss:0.9024
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 10:36:57,132]::3799835291::DEBUG::Epoch: 3 , 1-MAE: 0.9009 , 1-val_avg_o_loss:0.9068 , 1-val_avg_c_loss:0.8959 , 1-val_avg_e_loss:0.9082 , 1-val_avg_a_loss:0.9055 , 1-val_avg_n_loss:0.8883
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 10:42:06,891]::3799835291::DEBUG::Epoch: 4 , 1-MAE: 0.9081 , 1-val_avg_o_loss:0.9106 , 1-val_avg_c_loss:0.9013 , 1-val_avg_e_loss:0.9131 , 1-val_avg_a_loss:0.9066 , 1-val_avg_n_loss:0.9090
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.01it/s]
# [2024-07-03 10:47:16,555]::3799835291::DEBUG::Epoch: 5 , 1-MAE: 0.8998 , 1-val_avg_o_loss:0.9117 , 1-val_avg_c_loss:0.8946 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.8754 , 1-val_avg_n_loss:0.9065
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 10:52:26,309]::3799835291::DEBUG::Epoch: 6 , 1-MAE: 0.9098 , 1-val_avg_o_loss:0.9082 , 1-val_avg_c_loss:0.9044 , 1-val_avg_e_loss:0.9122 , 1-val_avg_a_loss:0.9113 , 1-val_avg_n_loss:0.9130
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 10:57:36,183]::3799835291::DEBUG::Epoch: 7 , 1-MAE: 0.9112 , 1-val_avg_o_loss:0.9141 , 1-val_avg_c_loss:0.9069 , 1-val_avg_e_loss:0.9152 , 1-val_avg_a_loss:0.9110 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 11:02:45,926]::3799835291::DEBUG::Epoch: 8 , 1-MAE: 0.9117 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9074 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9157 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 11:07:55,867]::3799835291::DEBUG::Epoch: 9 , 1-MAE: 0.9120 , 1-val_avg_o_loss:0.9143 , 1-val_avg_c_loss:0.9076 , 1-val_avg_e_loss:0.9158 , 1-val_avg_a_loss:0.9117 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 11:13:05,602]::3799835291::DEBUG::Epoch: 10 , 1-MAE: 0.9103 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.8994 , 1-val_avg_e_loss:0.9110 , 1-val_avg_a_loss:0.9125 , 1-val_avg_n_loss:0.9129
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 11:18:14,988]::3799835291::DEBUG::Epoch: 11 , 1-MAE: 0.9119 , 1-val_avg_o_loss:0.9129 , 1-val_avg_c_loss:0.9105 , 1-val_avg_e_loss:0.9142 , 1-val_avg_a_loss:0.9097 , 1-val_avg_n_loss:0.9124
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 11:23:24,494]::3799835291::DEBUG::Epoch: 12 , 1-MAE: 0.9119 , 1-val_avg_o_loss:0.9153 , 1-val_avg_c_loss:0.9065 , 1-val_avg_e_loss:0.9164 , 1-val_avg_a_loss:0.9101 , 1-val_avg_n_loss:0.9114
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.15it/s]
# [2024-07-03 11:28:33,925]::3799835291::DEBUG::Epoch: 13 , 1-MAE: 0.9085 , 1-val_avg_o_loss:0.9007 , 1-val_avg_c_loss:0.9076 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9100 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 11:33:43,753]::3799835291::DEBUG::Epoch: 14 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9105 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9164 , 1-val_avg_n_loss:0.9075
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 11:38:53,773]::3799835291::DEBUG::Epoch: 15 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9150 , 1-val_avg_c_loss:0.9100 , 1-val_avg_e_loss:0.9155 , 1-val_avg_a_loss:0.9148 , 1-val_avg_n_loss:0.9128
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 11:44:03,239]::3799835291::DEBUG::Epoch: 16 , 1-MAE: 0.9128 , 1-val_avg_o_loss:0.9147 , 1-val_avg_c_loss:0.9075 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9148 , 1-val_avg_n_loss:0.9124
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.14it/s]
# [2024-07-03 11:49:12,612]::3799835291::DEBUG::Epoch: 17 , 1-MAE: 0.9111 , 1-val_avg_o_loss:0.9139 , 1-val_avg_c_loss:0.9115 , 1-val_avg_e_loss:0.9087 , 1-val_avg_a_loss:0.9152 , 1-val_avg_n_loss:0.9064
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.04it/s]
# [2024-07-03 11:54:22,605]::3799835291::DEBUG::Epoch: 18 , 1-MAE: 0.9122 , 1-val_avg_o_loss:0.9176 , 1-val_avg_c_loss:0.9064 , 1-val_avg_e_loss:0.9100 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9105
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.13it/s]
# [2024-07-03 11:59:32,562]::3799835291::DEBUG::Epoch: 19 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9148 , 1-val_avg_a_loss:0.9186 , 1-val_avg_n_loss:0.9098
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 12:04:42,441]::3799835291::DEBUG::Epoch: 20 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9149 , 1-val_avg_c_loss:0.9110 , 1-val_avg_e_loss:0.9120 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9109
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.11it/s]
# [2024-07-03 12:09:52,018]::3799835291::DEBUG::Epoch: 21 , 1-MAE: 0.9129 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9078 , 1-val_avg_e_loss:0.9145 , 1-val_avg_a_loss:0.9160 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.12it/s]
# [2024-07-03 12:15:01,366]::3799835291::DEBUG::Epoch: 22 , 1-MAE: 0.9115 , 1-val_avg_o_loss:0.9141 , 1-val_avg_c_loss:0.9066 , 1-val_avg_e_loss:0.9127 , 1-val_avg_a_loss:0.9143 , 1-val_avg_n_loss:0.9096
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 12:20:11,332]::3799835291::DEBUG::Epoch: 23 , 1-MAE: 0.9128 , 1-val_avg_o_loss:0.9138 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9162 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.11it/s]
# [2024-07-03 12:25:21,186]::3799835291::DEBUG::Epoch: 24 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9139 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9086
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.00it/s]
# [2024-07-03 12:30:31,825]::3799835291::DEBUG::Epoch: 25 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9172 , 1-val_avg_c_loss:0.9108 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9101
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 12:35:41,447]::3799835291::DEBUG::Epoch: 26 , 1-MAE: 0.9127 , 1-val_avg_o_loss:0.9160 , 1-val_avg_c_loss:0.9087 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9140 , 1-val_avg_n_loss:0.9104
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 12:40:51,510]::3799835291::DEBUG::Epoch: 27 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9172 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 12:46:01,183]::3799835291::DEBUG::Epoch: 28 , 1-MAE: 0.9128 , 1-val_avg_o_loss:0.9152 , 1-val_avg_c_loss:0.9077 , 1-val_avg_e_loss:0.9130 , 1-val_avg_a_loss:0.9170 , 1-val_avg_n_loss:0.9111
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.12it/s]
# [2024-07-03 12:51:10,693]::3799835291::DEBUG::Epoch: 29 , 1-MAE: 0.9107 , 1-val_avg_o_loss:0.9109 , 1-val_avg_c_loss:0.9060 , 1-val_avg_e_loss:0.9151 , 1-val_avg_a_loss:0.9102 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 12:56:20,255]::3799835291::DEBUG::Epoch: 30 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9159 , 1-val_avg_c_loss:0.9100 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9159 , 1-val_avg_n_loss:0.9110
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 13:01:29,872]::3799835291::DEBUG::Epoch: 31 , 1-MAE: 0.9120 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9082 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9122 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.01it/s]
# [2024-07-03 13:06:39,637]::3799835291::DEBUG::Epoch: 32 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9168 , 1-val_avg_c_loss:0.9055 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9181 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.11it/s]
# [2024-07-03 13:11:49,529]::3799835291::DEBUG::Epoch: 33 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9165 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9156 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 13:16:59,655]::3799835291::DEBUG::Epoch: 34 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9104 , 1-val_avg_e_loss:0.9146 , 1-val_avg_a_loss:0.9183 , 1-val_avg_n_loss:0.9097
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.04it/s]
# [2024-07-03 13:22:09,673]::3799835291::DEBUG::Epoch: 35 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9154 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9155 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9093
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 13:27:19,542]::3799835291::DEBUG::Epoch: 36 , 1-MAE: 0.9128 , 1-val_avg_o_loss:0.9171 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9099 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 13:32:29,924]::3799835291::DEBUG::Epoch: 37 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9175 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9166 , 1-val_avg_n_loss:0.9120
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.03it/s]
# [2024-07-03 13:37:40,128]::3799835291::DEBUG::Epoch: 38 , 1-MAE: 0.9133 , 1-val_avg_o_loss:0.9148 , 1-val_avg_c_loss:0.9083 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9181 , 1-val_avg_n_loss:0.9104
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 13:42:50,277]::3799835291::DEBUG::Epoch: 39 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9160 , 1-val_avg_c_loss:0.9081 , 1-val_avg_e_loss:0.9150 , 1-val_avg_a_loss:0.9177 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 13:48:00,427]::3799835291::DEBUG::Epoch: 40 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9097 , 1-val_avg_e_loss:0.9137 , 1-val_avg_a_loss:0.9156 , 1-val_avg_n_loss:0.9129
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.11it/s]
# [2024-07-03 13:53:10,448]::3799835291::DEBUG::Epoch: 41 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9151 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9126
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 13:58:20,969]::3799835291::DEBUG::Epoch: 42 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9153 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9181 , 1-val_avg_n_loss:0.9124
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 14:03:31,082]::3799835291::DEBUG::Epoch: 43 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9143 , 1-val_avg_c_loss:0.9098 , 1-val_avg_e_loss:0.9135 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 14:08:41,262]::3799835291::DEBUG::Epoch: 44 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9165 , 1-val_avg_c_loss:0.9092 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9109
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 14:13:51,290]::3799835291::DEBUG::Epoch: 45 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9169 , 1-val_avg_c_loss:0.9108 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.11it/s]
# [2024-07-03 14:19:01,833]::3799835291::DEBUG::Epoch: 46 , 1-MAE: 0.9147 , 1-val_avg_o_loss:0.9178 , 1-val_avg_c_loss:0.9106 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9183 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 14:24:11,849]::3799835291::DEBUG::Epoch: 47 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9165 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9151 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9125
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 14:29:21,955]::3799835291::DEBUG::Epoch: 48 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9097 , 1-val_avg_e_loss:0.9157 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.11it/s]
# [2024-07-03 14:34:31,885]::3799835291::DEBUG::Epoch: 49 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9171 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9156 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 14:39:41,864]::3799835291::DEBUG::Epoch: 50 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9154 , 1-val_avg_c_loss:0.9098 , 1-val_avg_e_loss:0.9158 , 1-val_avg_a_loss:0.9179 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.03it/s]
# [2024-07-03 14:44:51,530]::3799835291::DEBUG::Epoch: 51 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9162 , 1-val_avg_c_loss:0.9086 , 1-val_avg_e_loss:0.9143 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9120
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 14:50:00,966]::3799835291::DEBUG::Epoch: 52 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9161 , 1-val_avg_c_loss:0.9105 , 1-val_avg_e_loss:0.9158 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 14:55:10,513]::3799835291::DEBUG::Epoch: 53 , 1-MAE: 0.9143 , 1-val_avg_o_loss:0.9167 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9158 , 1-val_avg_a_loss:0.9179 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.11it/s]
# [2024-07-03 15:00:20,026]::3799835291::DEBUG::Epoch: 54 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9160 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9132 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9116
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 15:05:29,583]::3799835291::DEBUG::Epoch: 55 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9160 , 1-val_avg_c_loss:0.9073 , 1-val_avg_e_loss:0.9159 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9100
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 15:10:39,311]::3799835291::DEBUG::Epoch: 56 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9169 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9151 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 15:15:48,704]::3799835291::DEBUG::Epoch: 57 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9092 , 1-val_avg_e_loss:0.9152 , 1-val_avg_a_loss:0.9180 , 1-val_avg_n_loss:0.9114
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.02it/s]
# [2024-07-03 15:20:58,445]::3799835291::DEBUG::Epoch: 58 , 1-MAE: 0.9126 , 1-val_avg_o_loss:0.9159 , 1-val_avg_c_loss:0.9086 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9162 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.00it/s]
# [2024-07-03 15:26:08,263]::3799835291::DEBUG::Epoch: 59 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9155 , 1-val_avg_a_loss:0.9166 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.03it/s]
# [2024-07-03 15:31:18,553]::3799835291::DEBUG::Epoch: 60 , 1-MAE: 0.9135 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9148 , 1-val_avg_a_loss:0.9166 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.02it/s]
# [2024-07-03 15:36:28,902]::3799835291::DEBUG::Epoch: 61 , 1-MAE: 0.9144 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9104 , 1-val_avg_e_loss:0.9152 , 1-val_avg_a_loss:0.9177 , 1-val_avg_n_loss:0.9123
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.03it/s]
# [2024-07-03 15:41:39,198]::3799835291::DEBUG::Epoch: 62 , 1-MAE: 0.9128 , 1-val_avg_o_loss:0.9150 , 1-val_avg_c_loss:0.9086 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9149 , 1-val_avg_n_loss:0.9108
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 15:46:48,733]::3799835291::DEBUG::Epoch: 63 , 1-MAE: 0.9135 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9146 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 15:51:59,013]::3799835291::DEBUG::Epoch: 64 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9155 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 15:57:09,204]::3799835291::DEBUG::Epoch: 65 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9159 , 1-val_avg_c_loss:0.9097 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9106
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 16:02:19,321]::3799835291::DEBUG::Epoch: 66 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9147 , 1-val_avg_a_loss:0.9184 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.04it/s]
# [2024-07-03 16:07:29,587]::3799835291::DEBUG::Epoch: 67 , 1-MAE: 0.9143 , 1-val_avg_o_loss:0.9180 , 1-val_avg_c_loss:0.9086 , 1-val_avg_e_loss:0.9163 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9124
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 16:12:39,797]::3799835291::DEBUG::Epoch: 68 , 1-MAE: 0.9143 , 1-val_avg_o_loss:0.9169 , 1-val_avg_c_loss:0.9090 , 1-val_avg_e_loss:0.9162 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 16:17:49,599]::3799835291::DEBUG::Epoch: 69 , 1-MAE: 0.9144 , 1-val_avg_o_loss:0.9162 , 1-val_avg_c_loss:0.9099 , 1-val_avg_e_loss:0.9148 , 1-val_avg_a_loss:0.9183 , 1-val_avg_n_loss:0.9125
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 16:22:59,268]::3799835291::DEBUG::Epoch: 70 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9084 , 1-val_avg_e_loss:0.9152 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9122
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.04it/s]
# [2024-07-03 16:28:08,898]::3799835291::DEBUG::Epoch: 71 , 1-MAE: 0.9125 , 1-val_avg_o_loss:0.9117 , 1-val_avg_c_loss:0.9093 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9111
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 16:33:19,162]::3799835291::DEBUG::Epoch: 72 , 1-MAE: 0.9144 , 1-val_avg_o_loss:0.9176 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9157 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 16:38:29,547]::3799835291::DEBUG::Epoch: 73 , 1-MAE: 0.9128 , 1-val_avg_o_loss:0.9146 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9120 , 1-val_avg_a_loss:0.9177 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 16:43:39,814]::3799835291::DEBUG::Epoch: 74 , 1-MAE: 0.9134 , 1-val_avg_o_loss:0.9154 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9134 , 1-val_avg_a_loss:0.9177 , 1-val_avg_n_loss:0.9109
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 16:48:50,055]::3799835291::DEBUG::Epoch: 75 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9152 , 1-val_avg_a_loss:0.9171 , 1-val_avg_n_loss:0.9116
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 16:54:00,091]::3799835291::DEBUG::Epoch: 76 , 1-MAE: 0.9125 , 1-val_avg_o_loss:0.9159 , 1-val_avg_c_loss:0.9082 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9149 , 1-val_avg_n_loss:0.9087
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 16:59:09,674]::3799835291::DEBUG::Epoch: 77 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 11.97it/s]
# [2024-07-03 17:04:20,130]::3799835291::DEBUG::Epoch: 78 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9151 , 1-val_avg_c_loss:0.9092 , 1-val_avg_e_loss:0.9155 , 1-val_avg_a_loss:0.9170 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 17:09:29,751]::3799835291::DEBUG::Epoch: 79 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9154 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9175 , 1-val_avg_n_loss:0.9111
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 11.98it/s]
# [2024-07-03 17:14:40,144]::3799835291::DEBUG::Epoch: 80 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9167 , 1-val_avg_c_loss:0.9087 , 1-val_avg_e_loss:0.9158 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.11it/s]
# [2024-07-03 17:19:50,368]::3799835291::DEBUG::Epoch: 81 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9171 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9154 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 17:25:00,080]::3799835291::DEBUG::Epoch: 82 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9167 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 17:30:09,909]::3799835291::DEBUG::Epoch: 83 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9078 , 1-val_avg_e_loss:0.9143 , 1-val_avg_a_loss:0.9166 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.00it/s]
# [2024-07-03 17:35:19,614]::3799835291::DEBUG::Epoch: 84 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9083 , 1-val_avg_e_loss:0.9151 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9125
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.03it/s]
# [2024-07-03 17:40:29,675]::3799835291::DEBUG::Epoch: 85 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9173 , 1-val_avg_c_loss:0.9088 , 1-val_avg_e_loss:0.9163 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.04it/s]
# [2024-07-03 17:45:39,928]::3799835291::DEBUG::Epoch: 86 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9153 , 1-val_avg_c_loss:0.9088 , 1-val_avg_e_loss:0.9128 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 17:50:49,721]::3799835291::DEBUG::Epoch: 87 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9151 , 1-val_avg_c_loss:0.9087 , 1-val_avg_e_loss:0.9142 , 1-val_avg_a_loss:0.9168 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 17:55:59,850]::3799835291::DEBUG::Epoch: 88 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9165 , 1-val_avg_c_loss:0.9098 , 1-val_avg_e_loss:0.9157 , 1-val_avg_a_loss:0.9170 , 1-val_avg_n_loss:0.9122
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.04it/s]
# [2024-07-03 18:01:10,031]::3799835291::DEBUG::Epoch: 89 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9164 , 1-val_avg_c_loss:0.9092 , 1-val_avg_e_loss:0.9141 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 18:06:20,239]::3799835291::DEBUG::Epoch: 90 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9166 , 1-val_avg_c_loss:0.9097 , 1-val_avg_e_loss:0.9155 , 1-val_avg_a_loss:0.9181 , 1-val_avg_n_loss:0.9111
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 18:11:30,116]::3799835291::DEBUG::Epoch: 91 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9146 , 1-val_avg_a_loss:0.9180 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 18:16:40,125]::3799835291::DEBUG::Epoch: 92 , 1-MAE: 0.9143 , 1-val_avg_o_loss:0.9160 , 1-val_avg_c_loss:0.9103 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9127
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 18:21:49,863]::3799835291::DEBUG::Epoch: 93 , 1-MAE: 0.9131 , 1-val_avg_o_loss:0.9146 , 1-val_avg_c_loss:0.9084 , 1-val_avg_e_loss:0.9142 , 1-val_avg_a_loss:0.9177 , 1-val_avg_n_loss:0.9105
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.04it/s]
# [2024-07-03 18:26:59,660]::3799835291::DEBUG::Epoch: 94 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9152 , 1-val_avg_c_loss:0.9101 , 1-val_avg_e_loss:0.9154 , 1-val_avg_a_loss:0.9171 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 18:32:09,534]::3799835291::DEBUG::Epoch: 95 , 1-MAE: 0.9125 , 1-val_avg_o_loss:0.9128 , 1-val_avg_c_loss:0.9088 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9162 , 1-val_avg_n_loss:0.9107
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.14it/s]
# [2024-07-03 18:37:19,232]::3799835291::DEBUG::Epoch: 96 , 1-MAE: 0.9144 , 1-val_avg_o_loss:0.9168 , 1-val_avg_c_loss:0.9101 , 1-val_avg_e_loss:0.9159 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9125
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 18:42:29,141]::3799835291::DEBUG::Epoch: 97 , 1-MAE: 0.9145 , 1-val_avg_o_loss:0.9175 , 1-val_avg_c_loss:0.9099 , 1-val_avg_e_loss:0.9161 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 11.99it/s]
# [2024-07-03 18:47:39,212]::3799835291::DEBUG::Epoch: 98 , 1-MAE: 0.9143 , 1-val_avg_o_loss:0.9171 , 1-val_avg_c_loss:0.9102 , 1-val_avg_e_loss:0.9152 , 1-val_avg_a_loss:0.9170 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.00it/s]
# [2024-07-03 18:52:49,023]::3799835291::DEBUG::Epoch: 99 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9151 , 1-val_avg_c_loss:0.9107 , 1-val_avg_e_loss:0.9160 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 18:57:58,550]::3799835291::DEBUG::Epoch: 100 , 1-MAE: 0.9141 , 1-val_avg_o_loss:0.9167 , 1-val_avg_c_loss:0.9097 , 1-val_avg_e_loss:0.9156 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 19:03:08,004]::3799835291::DEBUG::Epoch: 101 , 1-MAE: 0.9139 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9099 , 1-val_avg_e_loss:0.9154 , 1-val_avg_a_loss:0.9170 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.03it/s]
# [2024-07-03 19:08:17,696]::3799835291::DEBUG::Epoch: 102 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9160 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9157 , 1-val_avg_a_loss:0.9168 , 1-val_avg_n_loss:0.9105
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 19:13:27,949]::3799835291::DEBUG::Epoch: 103 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9164 , 1-val_avg_a_loss:0.9167 , 1-val_avg_n_loss:0.9112
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.03it/s]
# [2024-07-03 19:18:37,519]::3799835291::DEBUG::Epoch: 104 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9082 , 1-val_avg_e_loss:0.9155 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9113
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 19:23:47,906]::3799835291::DEBUG::Epoch: 105 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9161 , 1-val_avg_c_loss:0.9096 , 1-val_avg_e_loss:0.9159 , 1-val_avg_a_loss:0.9169 , 1-val_avg_n_loss:0.9114
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.12it/s]
# [2024-07-03 19:28:57,905]::3799835291::DEBUG::Epoch: 106 , 1-MAE: 0.9146 , 1-val_avg_o_loss:0.9171 , 1-val_avg_c_loss:0.9099 , 1-val_avg_e_loss:0.9156 , 1-val_avg_a_loss:0.9178 , 1-val_avg_n_loss:0.9129
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 19:34:07,979]::3799835291::DEBUG::Epoch: 107 , 1-MAE: 0.9130 , 1-val_avg_o_loss:0.9139 , 1-val_avg_c_loss:0.9075 , 1-val_avg_e_loss:0.9151 , 1-val_avg_a_loss:0.9168 , 1-val_avg_n_loss:0.9116
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.02it/s]
# [2024-07-03 19:39:18,411]::3799835291::DEBUG::Epoch: 108 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9158 , 1-val_avg_c_loss:0.9094 , 1-val_avg_e_loss:0.9150 , 1-val_avg_a_loss:0.9174 , 1-val_avg_n_loss:0.9109
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.06it/s]
# [2024-07-03 19:44:28,876]::3799835291::DEBUG::Epoch: 109 , 1-MAE: 0.9142 , 1-val_avg_o_loss:0.9168 , 1-val_avg_c_loss:0.9091 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9176 , 1-val_avg_n_loss:0.9121
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 19:49:38,843]::3799835291::DEBUG::Epoch: 110 , 1-MAE: 0.9140 , 1-val_avg_o_loss:0.9156 , 1-val_avg_c_loss:0.9095 , 1-val_avg_e_loss:0.9156 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9118
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 19:54:48,498]::3799835291::DEBUG::Epoch: 111 , 1-MAE: 0.9135 , 1-val_avg_o_loss:0.9154 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9144 , 1-val_avg_a_loss:0.9173 , 1-val_avg_n_loss:0.9116
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.05it/s]
# [2024-07-03 19:59:58,740]::3799835291::DEBUG::Epoch: 112 , 1-MAE: 0.9135 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9162 , 1-val_avg_n_loss:0.9119
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.04it/s]
# [2024-07-03 20:05:09,056]::3799835291::DEBUG::Epoch: 113 , 1-MAE: 0.9128 , 1-val_avg_o_loss:0.9145 , 1-val_avg_c_loss:0.9079 , 1-val_avg_e_loss:0.9143 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9099
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.03it/s]
# [2024-07-03 20:10:18,688]::3799835291::DEBUG::Epoch: 114 , 1-MAE: 0.9138 , 1-val_avg_o_loss:0.9163 , 1-val_avg_c_loss:0.9087 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9171 , 1-val_avg_n_loss:0.9115
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 20:15:28,262]::3799835291::DEBUG::Epoch: 115 , 1-MAE: 0.9131 , 1-val_avg_o_loss:0.9150 , 1-val_avg_c_loss:0.9084 , 1-val_avg_e_loss:0.9140 , 1-val_avg_a_loss:0.9165 , 1-val_avg_n_loss:0.9116
# 100%|██████████| 1263/1263 [04:34<00:00,  4.60it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.07it/s]
# [2024-07-03 20:20:38,527]::3799835291::DEBUG::Epoch: 116 , 1-MAE: 0.9145 , 1-val_avg_o_loss:0.9159 , 1-val_avg_c_loss:0.9105 , 1-val_avg_e_loss:0.9153 , 1-val_avg_a_loss:0.9179 , 1-val_avg_n_loss:0.9129
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.08it/s]
# [2024-07-03 20:25:48,182]::3799835291::DEBUG::Epoch: 117 , 1-MAE: 0.9137 , 1-val_avg_o_loss:0.9161 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9148 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.10it/s]
# [2024-07-03 20:30:57,794]::3799835291::DEBUG::Epoch: 118 , 1-MAE: 0.9136 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9089 , 1-val_avg_e_loss:0.9145 , 1-val_avg_a_loss:0.9172 , 1-val_avg_n_loss:0.9117
# 100%|██████████| 1263/1263 [04:33<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:34<00:00, 12.09it/s]
# [2024-07-03 20:36:07,364]::3799835291::DEBUG::Epoch: 119 , 1-MAE: 0.9127 , 1-val_avg_o_loss:0.9155 , 1-val_avg_c_loss:0.9083 , 1-val_avg_e_loss:0.9119 , 1-val_avg_a_loss:0.9168 , 1-val_avg_n_loss:0.9111
# 100%|██████████| 1263/1263 [04:34<00:00,  4.61it/s]
# 100%|██████████| 423/423 [00:35<00:00, 12.03it/s]
# [2024-07-03 20:41:17,218]::3799835291::DEBUG::Epoch: 120 , 1-MAE: 0.9132 , 1-val_avg_o_loss:0.9157 , 1-val_avg_c_loss:0.9083 , 1-val_avg_e_loss:0.9149 , 1-val_avg_a_loss:0.9166 , 1-val_avg_n_loss:0.9107

# %%
# from torchinfo import summary

# summary(model, input_size = (4,15,4,3,224,224))

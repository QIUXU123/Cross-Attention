# %%
import librosa
import librosa.display
import numpy as np
import pandas as pd
import os
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import random
import cv2
# from vgg16 import VGG16_LSTM
import pickle
import torch.nn as nn
import torch
import datetime
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms, utils, models
from torch.utils.data import Dataset, DataLoader
from facenet_pytorch import MTCNN
import logging
import torch
import torch.nn as nn
from vivit import ViViTBackbone
import gc
from einops import rearrange
from tqdm import tqdm
batchsz = 4
frame_nums=15
start_epoch = 0
test_flage=False
model_name ="15framesfullshot"
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
formatter = logging.Formatter('[%(asctime)s]::%(module)s::%(levelname)s::%(message)s')
streamHandler = logging.StreamHandler()
streamHandler.setFormatter(formatter)
fileHandler = logging.FileHandler('./LOG/personalityLog.log')
fileHandler.setFormatter(formatter)
logger.addHandler(streamHandler)
logger.addHandler(fileHandler)
USE_CUDA = torch.cuda.is_available()
# Out:
# /tmp/ipykernel_2620801/3498005901.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
logger.debug('============={}+Video Vision Transformer Strat!============='.format(model_name))
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:0' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:', device)
# Out:
# [2024-08-22 17:57:16,274]::3184030073::DEBUG::=============15framesfullshot+Video Vision Transformer Strat!=============
# True
# 학습을 진행하는 기기: cuda:0

# %%
def getdata(pathname,datatype):
    if datatype=="train":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            final_data_set.extend(pickle.load(output_file))
        return final_data_set
    elif datatype=="valid":
        final_data_set=[]
        output_file=open(pathname, "rb")
        for i in range(1):
            final_data_set.extend(pickle.load(output_file))
        return final_data_set
print(1)
# Out:
# 1

# %%
save_model_file_path = './save_swintransformer_folder/{}_{}.{}'
print(1)
# Out:
# 1

# %%
validation_set_data=getdata("/data/qx/15FramesDatasetKr/test_set.dat","valid")
print(1)
# Out:
# 1

# %%
train_set_data=getdata("/data/qx/15FramesDatasetKr/train_set.dat","train")
print(1)
# Out:
# 1

# %%
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
])
print(1)
# Out:
# 1

# %%
class ChalearnDataset(Dataset):
    def __init__(self,fullshot,tagdata,transform=None):
        self.fullshot=fullshot
        self.tagdata=tagdata
        self.transform = transform  # 표준화 여부
    def __len__(self):
        return len(self.fullshot)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()#텐서의 경우 목록으로 돌아가기
        fullshot=self.fullshot[idx]
        fullshot=torch.FloatTensor(fullshot)
        big_five_sorces=self.tagdata[idx]
        big_five_sorces = torch.FloatTensor(big_five_sorces)
        return fullshot,big_five_sorces
print(1)
# Out:
# 1

# %%
num_workerssz = 20
lr = 3e-05
epochs = 120
print(1)
# Out:
# 1

# %%
train_set_data = ChalearnDataset(fullshot = train_set_data[1],tagdata=train_set_data[3],transform=transform)
val_set_data = ChalearnDataset(fullshot = validation_set_data[1],tagdata=validation_set_data[3],transform=transform)
train_dataloader = DataLoader(dataset=train_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
val_dataloader = DataLoader(dataset=val_set_data, batch_size=batchsz, shuffle=True, num_workers=num_workerssz)
max_value=0
print(1)
# Out:
# 1

# %%
model=ViViTBackbone(2, 14, 14, 2, 2, 2, 5, 96, 6, 10, 8, model=3)#num_frames=frame_nums,batchsz = batchsz
model=model.to(device)
criterion = torch.nn.L1Loss().to(device) # 손실함수
optimizer = torch.optim.AdamW(model.parameters(), lr=lr) # 옵티마이저

if test_flage==True:
    checkpoint=torch.load(save_model_file_path.format('model',start_epoch,'pth'), map_location=device)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint["optimizer"])
    criterion.load_state_dict(checkpoint["loss"])
train_avg_loss0=[]
val_avg_loss0=[]
print(1)
# Out:
# 1

# %%
from torchinfo import summary

summary(model, input_size = ((4, 3,15, 224, 224)), col_names = ['input_size','output_size','num_params'],verbose = 1)
# Out:
# =============================================================================================================================
# Layer (type:depth-idx)                             Input Shape               Output Shape              Param #
# =============================================================================================================================
# ViViTBackbone                                      [4, 3, 15, 224, 224]      [4, 5]                    3,146,016
# ├─VideoResNet: 1-1                                 [4, 3, 15, 224, 224]      [4, 512, 2, 14, 14]       205,200
# │    └─R2Plus1dStem: 2-1                           [4, 3, 15, 224, 224]      [4, 64, 15, 112, 112]     --
# │    │    └─Conv3d: 3-1                            [4, 3, 15, 224, 224]      [4, 45, 15, 112, 112]     6,615
# │    │    └─BatchNorm3d: 3-2                       [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     90
# │    │    └─ReLU: 3-3                              [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     --
# │    │    └─Conv3d: 3-4                            [4, 45, 15, 112, 112]     [4, 64, 15, 112, 112]     8,640
# │    │    └─BatchNorm3d: 3-5                       [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     128
# │    │    └─ReLU: 3-6                              [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    └─Sequential: 2-2                             [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    │    └─BasicBlock: 3-7                        [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    │    └─BasicBlock: 3-8                        [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    └─Sequential: 2-3                             [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       --
# │    │    └─BasicBlock: 3-9                        [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       583,960
# │    │    └─BasicBlock: 3-10                       [4, 128, 8, 56, 56]       [4, 128, 8, 56, 56]       886,400
# │    └─Sequential: 2-4                             [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       --
# │    │    └─BasicBlock: 3-11                       [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       2,332,464
# │    │    └─BasicBlock: 3-12                       [4, 256, 4, 28, 28]       [4, 256, 4, 28, 28]       3,542,272
# │    └─Sequential: 2-5                             [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       --
# │    │    └─BasicBlock: 3-13                       [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       9,333,092
# │    │    └─BasicBlock: 3-14                       [4, 512, 2, 14, 14]       [4, 512, 2, 14, 14]       14,162,432
# ├─Sequential: 1-2                                  [4, 512, 2, 14, 14]       [4, 1, 49, 96]            --
# │    └─Rearrange: 2-6                              [4, 512, 2, 14, 14]       [4, 1, 49, 4096]          --
# │    └─Linear: 2-7                                 [4, 1, 49, 4096]          [4, 1, 49, 96]            393,312
# ├─Dropout: 1-3                                     [4, 1, 49, 96]            [4, 1, 49, 96]            --
# ├─FSATransformerEncoder: 1-4                       [4, 1, 49, 96]            [4, 49, 96]               --
# │    └─ModuleList: 2-8                             --                        --                        --
# │    │    └─ModuleList: 3-15                       --                        --                        25,448
# │    │    └─ModuleList: 3-16                       --                        --                        25,448
# │    │    └─ModuleList: 3-17                       --                        --                        25,448
# │    │    └─ModuleList: 3-18                       --                        --                        25,448
# │    │    └─ModuleList: 3-19                       --                        --                        25,448
# │    │    └─ModuleList: 3-20                       --                        --                        25,448
# ├─Identity: 1-5                                    [4, 96]                   [4, 96]                   --
# ├─Sequential: 1-6                                  [4, 96]                   [4, 5]                    --
# │    └─LayerNorm: 2-9                              [4, 96]                   [4, 96]                   192
# │    └─Linear: 2-10                                [4, 96]                   [4, 5]                    485
# =============================================================================================================================
# Total params: 35,198,018
# Trainable params: 35,198,018
# Non-trainable params: 0
# Total mult-adds (G): 623.70
# =============================================================================================================================
# Input size (MB): 36.13
# Forward/backward pass size (MB): 15309.69
# Params size (MB): 127.39
# Estimated Total Size (MB): 15473.21
# =============================================================================================================================
# =============================================================================================================================
# Layer (type:depth-idx)                             Input Shape               Output Shape              Param #
# =============================================================================================================================
# ViViTBackbone                                      [4, 3, 15, 224, 224]      [4, 5]                    3,146,016
# ├─VideoResNet: 1-1                                 [4, 3, 15, 224, 224]      [4, 512, 2, 14, 14]       205,200
# │    └─R2Plus1dStem: 2-1                           [4, 3, 15, 224, 224]      [4, 64, 15, 112, 112]     --
# │    │    └─Conv3d: 3-1                            [4, 3, 15, 224, 224]      [4, 45, 15, 112, 112]     6,615
# │    │    └─BatchNorm3d: 3-2                       [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     90
# │    │    └─ReLU: 3-3                              [4, 45, 15, 112, 112]     [4, 45, 15, 112, 112]     --
# │    │    └─Conv3d: 3-4                            [4, 45, 15, 112, 112]     [4, 64, 15, 112, 112]     8,640
# │    │    └─BatchNorm3d: 3-5                       [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     128
# │    │    └─ReLU: 3-6                              [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    └─Sequential: 2-2                             [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     --
# │    │    └─BasicBlock: 3-7                        [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    │    └─BasicBlock: 3-8                        [4, 64, 15, 112, 112]     [4, 64, 15, 112, 112]     222,016
# │    └─Sequential: 2-3                             [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       --
# │    │    └─BasicBlock: 3-9                        [4, 64, 15, 112, 112]     [4, 128, 8, 56, 56]       583,960
# │    │    └─BasicBlock: 3-10                       [4, 128, 8, 56, 56]       [4, 128, 8, 56, 56]       886,400
# │    └─Sequential: 2-4                             [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       --
# │    │    └─BasicBlock: 3-11                       [4, 128, 8, 56, 56]       [4, 256, 4, 28, 28]       2,332,464
# │    │    └─BasicBlock: 3-12                       [4, 256, 4, 28, 28]       [4, 256, 4, 28, 28]       3,542,272
# │    └─Sequential: 2-5                             [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       --
# │    │    └─BasicBlock: 3-13                       [4, 256, 4, 28, 28]       [4, 512, 2, 14, 14]       9,333,092
# │    │    └─BasicBlock: 3-14                       [4, 512, 2, 14, 14]       [4, 512, 2, 14, 14]       14,162,432
# ├─Sequential: 1-2                                  [4, 512, 2, 14, 14]       [4, 1, 49, 96]            --
# │    └─Rearrange: 2-6                              [4, 512, 2, 14, 14]       [4, 1, 49, 4096]          --
# │    └─Linear: 2-7                                 [4, 1, 49, 4096]          [4, 1, 49, 96]            393,312
# ├─Dropout: 1-3                                     [4, 1, 49, 96]            [4, 1, 49, 96]            --
# ├─FSATransformerEncoder: 1-4                       [4, 1, 49, 96]            [4, 49, 96]               --
# │    └─ModuleList: 2-8                             --                        --                        --
# │    │    └─ModuleList: 3-15                       --                        --                        25,448
# │    │    └─ModuleList: 3-16                       --                        --                        25,448
# │    │    └─ModuleList: 3-17                       --                        --                        25,448
# │    │    └─ModuleList: 3-18                       --                        --                        25,448
# │    │    └─ModuleList: 3-19                       --                        --                        25,448
# │    │    └─ModuleList: 3-20                       --                        --                        25,448
# ├─Identity: 1-5                                    [4, 96]                   [4, 96]                   --
# ├─Sequential: 1-6                                  [4, 96]                   [4, 5]                    --
# │    └─LayerNorm: 2-9                              [4, 96]                   [4, 96]                   192
# │    └─Linear: 2-10                                [4, 96]                   [4, 5]                    485
# =============================================================================================================================
# Total params: 35,198,018
# Trainable params: 35,198,018
# Non-trainable params: 0
# Total mult-adds (G): 623.70
# =============================================================================================================================
# Input size (MB): 36.13
# Forward/backward pass size (MB): 15309.69
# Params size (MB): 127.39
# Estimated Total Size (MB): 15473.21
# =============================================================================================================================

# %%
def extract_ocean(data,batch_size):
    o=[]
    c=[]
    e=[]
    a=[]
    n=[]
    for i in range(batch_size):
        o.append(data[i][0].item())
        c.append(data[i][1].item())
        e.append(data[i][2].item())
        a.append(data[i][3].item())
        n.append(data[i][4].item())
    o = torch.tensor(o) 
    c = torch.tensor(c) 
    e = torch.tensor(e) 
    a = torch.tensor(a) 
    n = torch.tensor(n) 
    return o,c,e,a,n

# %%
max_value = float('inf')
for i in range(start_epoch, epochs):
    train_avg_loss = 0
    val_avg_loss = 0
    train_avg_o_loss = 0
    train_avg_c_loss = 0
    train_avg_e_loss = 0
    train_avg_a_loss = 0
    train_avg_n_loss = 0
    val_avg_o_loss = 0
    val_avg_c_loss = 0
    val_avg_e_loss = 0
    val_avg_a_loss = 0
    val_avg_n_loss = 0
    for fullshot,big_five_data in tqdm(train_dataloader):
        fullshot=fullshot.permute(0,4,1,2,3)
        big_five_data=big_five_data.permute(0,2,1)
        big_five_data=big_five_data.squeeze()
        fullshot = fullshot.to(device)
        big_five_data = big_five_data.to(device)
        optimizer.zero_grad()  # 기울기가 0이 됩니다.
        hypothesis = model(fullshot) # 모델의 예측 결과를 저장합니다.
        loss = criterion(hypothesis, big_five_data)  # 예측된 결과와 실제 태그 사이의 손실 값을 저장합니다.
        loss.backward()  # 역방향 전파입니다. 
        optimizer.step()  
        train_avg_loss += loss  
    train_avg_loss=train_avg_loss/len(train_dataloader)
    with torch.no_grad():#validate
        for fullshot,big_five_data in tqdm(val_dataloader):
            fullshot=fullshot.permute(0,4,1,2,3)
            big_five_data=big_five_data.permute(0,2,1)
            big_five_data=big_five_data.squeeze()
            fullshot = fullshot.to(device)
            big_five_data = big_five_data.to(device)
            hypothesis = model(fullshot)
            val_loss = criterion(hypothesis, big_five_data)
            hypothesiso,hypothesisc,hypothesise,hypothesisa,hypothesisn=extract_ocean(hypothesis,batchsz)
            big_five_datao,big_five_datac,big_five_datae,big_five_dataa,big_five_datan=extract_ocean(big_five_data,batchsz)
            val_o_loss = criterion(hypothesiso, big_five_datao) 
            val_c_loss = criterion(hypothesisc, big_five_datac) 
            val_e_loss = criterion(hypothesise, big_five_datae) 
            val_a_loss = criterion(hypothesisa, big_five_dataa) 
            val_n_loss = criterion(hypothesisn, big_five_datan)  
            val_avg_loss += val_loss
            val_avg_o_loss += val_o_loss
            val_avg_c_loss += val_c_loss
            val_avg_e_loss += val_e_loss
            val_avg_a_loss += val_a_loss
            val_avg_n_loss += val_n_loss
        val_avg_loss=val_avg_loss/len(val_dataloader)
        val_avg_o_loss=val_avg_o_loss/len(val_dataloader)
        val_avg_c_loss=val_avg_c_loss/len(val_dataloader)
        val_avg_e_loss=val_avg_e_loss/len(val_dataloader)
        val_avg_a_loss=val_avg_a_loss/len(val_dataloader)
        val_avg_n_loss=val_avg_n_loss/len(val_dataloader)
    torch.cuda.empty_cache()
    start_epoch+=1
    if val_avg_loss < max_value:
        max_value=val_avg_loss
        torch.save({
            'epoch': i+1,
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'loss': val_avg_loss,
        }, save_model_file_path.format('model',start_epoch,'pth'))
    logger.debug('Epoch: {} , 1-MAE: {:.4f} , 1-val_avg_o_loss:{:.4f} , 1-val_avg_c_loss:{:.4f} , 1-val_avg_e_loss:{:.4f} , 1-val_avg_a_loss:{:.4f} , 1-val_avg_n_loss:{:.4f}'.format(i+1, 1-val_avg_loss, 1-val_avg_o_loss, 1-val_avg_c_loss, 1-val_avg_e_loss, 1-val_avg_a_loss,1-val_avg_n_loss))
# Out:
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.23it/s]
# [2024-08-22 18:00:39,621]::1387131020::DEBUG::Epoch: 1 , 1-MAE: 0.8567 , 1-val_avg_o_loss:0.8795 , 1-val_avg_c_loss:0.8636 , 1-val_avg_e_loss:0.8526 , 1-val_avg_a_loss:0.8828 , 1-val_avg_n_loss:0.8051
# 100%|██████████| 758/758 [02:55<00:00,  4.31it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-22 18:03:53,506]::1387131020::DEBUG::Epoch: 2 , 1-MAE: 0.8681 , 1-val_avg_o_loss:0.8813 , 1-val_avg_c_loss:0.8765 , 1-val_avg_e_loss:0.8557 , 1-val_avg_a_loss:0.8910 , 1-val_avg_n_loss:0.8362
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 18:07:06,219]::1387131020::DEBUG::Epoch: 3 , 1-MAE: 0.8619 , 1-val_avg_o_loss:0.8670 , 1-val_avg_c_loss:0.8702 , 1-val_avg_e_loss:0.8504 , 1-val_avg_a_loss:0.8888 , 1-val_avg_n_loss:0.8332
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.25it/s]
# [2024-08-22 18:10:18,624]::1387131020::DEBUG::Epoch: 4 , 1-MAE: 0.8627 , 1-val_avg_o_loss:0.8739 , 1-val_avg_c_loss:0.8678 , 1-val_avg_e_loss:0.8421 , 1-val_avg_a_loss:0.8906 , 1-val_avg_n_loss:0.8392
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.16it/s]
# [2024-08-22 18:13:31,304]::1387131020::DEBUG::Epoch: 5 , 1-MAE: 0.8621 , 1-val_avg_o_loss:0.8683 , 1-val_avg_c_loss:0.8708 , 1-val_avg_e_loss:0.8461 , 1-val_avg_a_loss:0.8955 , 1-val_avg_n_loss:0.8297
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.12it/s]
# [2024-08-22 18:16:44,024]::1387131020::DEBUG::Epoch: 6 , 1-MAE: 0.8610 , 1-val_avg_o_loss:0.8728 , 1-val_avg_c_loss:0.8795 , 1-val_avg_e_loss:0.8395 , 1-val_avg_a_loss:0.8812 , 1-val_avg_n_loss:0.8321
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.13it/s]
# [2024-08-22 18:19:57,276]::1387131020::DEBUG::Epoch: 7 , 1-MAE: 0.8649 , 1-val_avg_o_loss:0.8770 , 1-val_avg_c_loss:0.8743 , 1-val_avg_e_loss:0.8417 , 1-val_avg_a_loss:0.8888 , 1-val_avg_n_loss:0.8428
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-22 18:23:09,907]::1387131020::DEBUG::Epoch: 8 , 1-MAE: 0.8616 , 1-val_avg_o_loss:0.8695 , 1-val_avg_c_loss:0.8765 , 1-val_avg_e_loss:0.8426 , 1-val_avg_a_loss:0.8890 , 1-val_avg_n_loss:0.8304
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 18:26:22,874]::1387131020::DEBUG::Epoch: 9 , 1-MAE: 0.8592 , 1-val_avg_o_loss:0.8683 , 1-val_avg_c_loss:0.8693 , 1-val_avg_e_loss:0.8446 , 1-val_avg_a_loss:0.8825 , 1-val_avg_n_loss:0.8315
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.12it/s]
# [2024-08-22 18:29:35,704]::1387131020::DEBUG::Epoch: 10 , 1-MAE: 0.8565 , 1-val_avg_o_loss:0.8715 , 1-val_avg_c_loss:0.8635 , 1-val_avg_e_loss:0.8409 , 1-val_avg_a_loss:0.8793 , 1-val_avg_n_loss:0.8273
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 18:32:48,722]::1387131020::DEBUG::Epoch: 11 , 1-MAE: 0.8626 , 1-val_avg_o_loss:0.8724 , 1-val_avg_c_loss:0.8755 , 1-val_avg_e_loss:0.8459 , 1-val_avg_a_loss:0.8849 , 1-val_avg_n_loss:0.8343
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.20it/s]
# [2024-08-22 18:36:01,562]::1387131020::DEBUG::Epoch: 12 , 1-MAE: 0.8594 , 1-val_avg_o_loss:0.8725 , 1-val_avg_c_loss:0.8665 , 1-val_avg_e_loss:0.8434 , 1-val_avg_a_loss:0.8842 , 1-val_avg_n_loss:0.8307
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 18:39:14,045]::1387131020::DEBUG::Epoch: 13 , 1-MAE: 0.8586 , 1-val_avg_o_loss:0.8718 , 1-val_avg_c_loss:0.8667 , 1-val_avg_e_loss:0.8415 , 1-val_avg_a_loss:0.8798 , 1-val_avg_n_loss:0.8331
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.17it/s]
# [2024-08-22 18:42:26,462]::1387131020::DEBUG::Epoch: 14 , 1-MAE: 0.8596 , 1-val_avg_o_loss:0.8719 , 1-val_avg_c_loss:0.8622 , 1-val_avg_e_loss:0.8445 , 1-val_avg_a_loss:0.8844 , 1-val_avg_n_loss:0.8353
# 100%|██████████| 758/758 [02:54<00:00,  4.35it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.17it/s]
# [2024-08-22 18:45:38,552]::1387131020::DEBUG::Epoch: 15 , 1-MAE: 0.8574 , 1-val_avg_o_loss:0.8709 , 1-val_avg_c_loss:0.8631 , 1-val_avg_e_loss:0.8410 , 1-val_avg_a_loss:0.8812 , 1-val_avg_n_loss:0.8309
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.24it/s]
# [2024-08-22 18:48:50,834]::1387131020::DEBUG::Epoch: 16 , 1-MAE: 0.8591 , 1-val_avg_o_loss:0.8705 , 1-val_avg_c_loss:0.8592 , 1-val_avg_e_loss:0.8448 , 1-val_avg_a_loss:0.8873 , 1-val_avg_n_loss:0.8338
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.17it/s]
# [2024-08-22 18:52:03,200]::1387131020::DEBUG::Epoch: 17 , 1-MAE: 0.8587 , 1-val_avg_o_loss:0.8718 , 1-val_avg_c_loss:0.8691 , 1-val_avg_e_loss:0.8417 , 1-val_avg_a_loss:0.8821 , 1-val_avg_n_loss:0.8285
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 18:55:15,805]::1387131020::DEBUG::Epoch: 18 , 1-MAE: 0.8609 , 1-val_avg_o_loss:0.8722 , 1-val_avg_c_loss:0.8664 , 1-val_avg_e_loss:0.8381 , 1-val_avg_a_loss:0.8890 , 1-val_avg_n_loss:0.8387
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.20it/s]
# [2024-08-22 18:58:28,957]::1387131020::DEBUG::Epoch: 19 , 1-MAE: 0.8588 , 1-val_avg_o_loss:0.8696 , 1-val_avg_c_loss:0.8652 , 1-val_avg_e_loss:0.8368 , 1-val_avg_a_loss:0.8876 , 1-val_avg_n_loss:0.8352
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.16it/s]
# [2024-08-22 19:01:41,282]::1387131020::DEBUG::Epoch: 20 , 1-MAE: 0.8585 , 1-val_avg_o_loss:0.8687 , 1-val_avg_c_loss:0.8644 , 1-val_avg_e_loss:0.8425 , 1-val_avg_a_loss:0.8867 , 1-val_avg_n_loss:0.8301
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.23it/s]
# [2024-08-22 19:04:53,960]::1387131020::DEBUG::Epoch: 21 , 1-MAE: 0.8544 , 1-val_avg_o_loss:0.8680 , 1-val_avg_c_loss:0.8621 , 1-val_avg_e_loss:0.8382 , 1-val_avg_a_loss:0.8751 , 1-val_avg_n_loss:0.8286
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.19it/s]
# [2024-08-22 19:08:06,574]::1387131020::DEBUG::Epoch: 22 , 1-MAE: 0.8579 , 1-val_avg_o_loss:0.8676 , 1-val_avg_c_loss:0.8687 , 1-val_avg_e_loss:0.8402 , 1-val_avg_a_loss:0.8831 , 1-val_avg_n_loss:0.8298
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 19:11:19,507]::1387131020::DEBUG::Epoch: 23 , 1-MAE: 0.8560 , 1-val_avg_o_loss:0.8661 , 1-val_avg_c_loss:0.8623 , 1-val_avg_e_loss:0.8392 , 1-val_avg_a_loss:0.8827 , 1-val_avg_n_loss:0.8299
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.16it/s]
# [2024-08-22 19:14:32,242]::1387131020::DEBUG::Epoch: 24 , 1-MAE: 0.8596 , 1-val_avg_o_loss:0.8716 , 1-val_avg_c_loss:0.8669 , 1-val_avg_e_loss:0.8403 , 1-val_avg_a_loss:0.8857 , 1-val_avg_n_loss:0.8337
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 19:17:44,430]::1387131020::DEBUG::Epoch: 25 , 1-MAE: 0.8593 , 1-val_avg_o_loss:0.8725 , 1-val_avg_c_loss:0.8667 , 1-val_avg_e_loss:0.8375 , 1-val_avg_a_loss:0.8848 , 1-val_avg_n_loss:0.8350
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.12it/s]
# [2024-08-22 19:20:57,175]::1387131020::DEBUG::Epoch: 26 , 1-MAE: 0.8560 , 1-val_avg_o_loss:0.8674 , 1-val_avg_c_loss:0.8643 , 1-val_avg_e_loss:0.8362 , 1-val_avg_a_loss:0.8809 , 1-val_avg_n_loss:0.8311
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-22 19:24:09,990]::1387131020::DEBUG::Epoch: 27 , 1-MAE: 0.8581 , 1-val_avg_o_loss:0.8709 , 1-val_avg_c_loss:0.8631 , 1-val_avg_e_loss:0.8400 , 1-val_avg_a_loss:0.8818 , 1-val_avg_n_loss:0.8344
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.19it/s]
# [2024-08-22 19:27:22,883]::1387131020::DEBUG::Epoch: 28 , 1-MAE: 0.8579 , 1-val_avg_o_loss:0.8695 , 1-val_avg_c_loss:0.8623 , 1-val_avg_e_loss:0.8413 , 1-val_avg_a_loss:0.8847 , 1-val_avg_n_loss:0.8317
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 19:30:35,835]::1387131020::DEBUG::Epoch: 29 , 1-MAE: 0.8554 , 1-val_avg_o_loss:0.8710 , 1-val_avg_c_loss:0.8595 , 1-val_avg_e_loss:0.8387 , 1-val_avg_a_loss:0.8832 , 1-val_avg_n_loss:0.8244
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.20it/s]
# [2024-08-22 19:33:49,000]::1387131020::DEBUG::Epoch: 30 , 1-MAE: 0.8569 , 1-val_avg_o_loss:0.8689 , 1-val_avg_c_loss:0.8646 , 1-val_avg_e_loss:0.8371 , 1-val_avg_a_loss:0.8811 , 1-val_avg_n_loss:0.8330
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.12it/s]
# [2024-08-22 19:37:01,729]::1387131020::DEBUG::Epoch: 31 , 1-MAE: 0.8545 , 1-val_avg_o_loss:0.8678 , 1-val_avg_c_loss:0.8615 , 1-val_avg_e_loss:0.8360 , 1-val_avg_a_loss:0.8781 , 1-val_avg_n_loss:0.8292
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 19:40:14,469]::1387131020::DEBUG::Epoch: 32 , 1-MAE: 0.8544 , 1-val_avg_o_loss:0.8670 , 1-val_avg_c_loss:0.8626 , 1-val_avg_e_loss:0.8351 , 1-val_avg_a_loss:0.8802 , 1-val_avg_n_loss:0.8270
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.16it/s]
# [2024-08-22 19:43:26,771]::1387131020::DEBUG::Epoch: 33 , 1-MAE: 0.8544 , 1-val_avg_o_loss:0.8713 , 1-val_avg_c_loss:0.8588 , 1-val_avg_e_loss:0.8332 , 1-val_avg_a_loss:0.8812 , 1-val_avg_n_loss:0.8277
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 19:46:39,535]::1387131020::DEBUG::Epoch: 34 , 1-MAE: 0.8552 , 1-val_avg_o_loss:0.8680 , 1-val_avg_c_loss:0.8617 , 1-val_avg_e_loss:0.8358 , 1-val_avg_a_loss:0.8817 , 1-val_avg_n_loss:0.8288
# 100%|██████████| 758/758 [02:55<00:00,  4.31it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.25it/s]
# [2024-08-22 19:49:52,957]::1387131020::DEBUG::Epoch: 35 , 1-MAE: 0.8537 , 1-val_avg_o_loss:0.8667 , 1-val_avg_c_loss:0.8620 , 1-val_avg_e_loss:0.8329 , 1-val_avg_a_loss:0.8795 , 1-val_avg_n_loss:0.8275
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.19it/s]
# [2024-08-22 19:53:05,961]::1387131020::DEBUG::Epoch: 36 , 1-MAE: 0.8553 , 1-val_avg_o_loss:0.8673 , 1-val_avg_c_loss:0.8617 , 1-val_avg_e_loss:0.8369 , 1-val_avg_a_loss:0.8837 , 1-val_avg_n_loss:0.8269
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 19:56:18,652]::1387131020::DEBUG::Epoch: 37 , 1-MAE: 0.8584 , 1-val_avg_o_loss:0.8730 , 1-val_avg_c_loss:0.8609 , 1-val_avg_e_loss:0.8415 , 1-val_avg_a_loss:0.8851 , 1-val_avg_n_loss:0.8315
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 19:59:30,803]::1387131020::DEBUG::Epoch: 38 , 1-MAE: 0.8548 , 1-val_avg_o_loss:0.8691 , 1-val_avg_c_loss:0.8601 , 1-val_avg_e_loss:0.8366 , 1-val_avg_a_loss:0.8796 , 1-val_avg_n_loss:0.8285
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.09it/s]
# [2024-08-22 20:02:43,748]::1387131020::DEBUG::Epoch: 39 , 1-MAE: 0.8575 , 1-val_avg_o_loss:0.8707 , 1-val_avg_c_loss:0.8629 , 1-val_avg_e_loss:0.8388 , 1-val_avg_a_loss:0.8821 , 1-val_avg_n_loss:0.8332
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.09it/s]
# [2024-08-22 20:05:56,843]::1387131020::DEBUG::Epoch: 40 , 1-MAE: 0.8571 , 1-val_avg_o_loss:0.8697 , 1-val_avg_c_loss:0.8635 , 1-val_avg_e_loss:0.8396 , 1-val_avg_a_loss:0.8830 , 1-val_avg_n_loss:0.8296
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 20:09:09,422]::1387131020::DEBUG::Epoch: 41 , 1-MAE: 0.8546 , 1-val_avg_o_loss:0.8669 , 1-val_avg_c_loss:0.8620 , 1-val_avg_e_loss:0.8357 , 1-val_avg_a_loss:0.8795 , 1-val_avg_n_loss:0.8290
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 20:12:22,595]::1387131020::DEBUG::Epoch: 42 , 1-MAE: 0.8545 , 1-val_avg_o_loss:0.8685 , 1-val_avg_c_loss:0.8607 , 1-val_avg_e_loss:0.8346 , 1-val_avg_a_loss:0.8796 , 1-val_avg_n_loss:0.8292
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.27it/s]
# [2024-08-22 20:15:35,024]::1387131020::DEBUG::Epoch: 43 , 1-MAE: 0.8545 , 1-val_avg_o_loss:0.8643 , 1-val_avg_c_loss:0.8611 , 1-val_avg_e_loss:0.8350 , 1-val_avg_a_loss:0.8809 , 1-val_avg_n_loss:0.8310
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 20:18:47,247]::1387131020::DEBUG::Epoch: 44 , 1-MAE: 0.8547 , 1-val_avg_o_loss:0.8678 , 1-val_avg_c_loss:0.8594 , 1-val_avg_e_loss:0.8397 , 1-val_avg_a_loss:0.8749 , 1-val_avg_n_loss:0.8315
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.29it/s]
# [2024-08-22 20:21:59,349]::1387131020::DEBUG::Epoch: 45 , 1-MAE: 0.8532 , 1-val_avg_o_loss:0.8638 , 1-val_avg_c_loss:0.8615 , 1-val_avg_e_loss:0.8330 , 1-val_avg_a_loss:0.8815 , 1-val_avg_n_loss:0.8265
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 20:25:11,698]::1387131020::DEBUG::Epoch: 46 , 1-MAE: 0.8537 , 1-val_avg_o_loss:0.8659 , 1-val_avg_c_loss:0.8577 , 1-val_avg_e_loss:0.8344 , 1-val_avg_a_loss:0.8830 , 1-val_avg_n_loss:0.8273
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 20:28:24,940]::1387131020::DEBUG::Epoch: 47 , 1-MAE: 0.8559 , 1-val_avg_o_loss:0.8693 , 1-val_avg_c_loss:0.8611 , 1-val_avg_e_loss:0.8386 , 1-val_avg_a_loss:0.8815 , 1-val_avg_n_loss:0.8288
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-22 20:31:37,499]::1387131020::DEBUG::Epoch: 48 , 1-MAE: 0.8549 , 1-val_avg_o_loss:0.8696 , 1-val_avg_c_loss:0.8609 , 1-val_avg_e_loss:0.8347 , 1-val_avg_a_loss:0.8825 , 1-val_avg_n_loss:0.8270
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.12it/s]
# [2024-08-22 20:34:50,830]::1387131020::DEBUG::Epoch: 49 , 1-MAE: 0.8564 , 1-val_avg_o_loss:0.8680 , 1-val_avg_c_loss:0.8589 , 1-val_avg_e_loss:0.8416 , 1-val_avg_a_loss:0.8822 , 1-val_avg_n_loss:0.8314
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 20:38:03,671]::1387131020::DEBUG::Epoch: 50 , 1-MAE: 0.8537 , 1-val_avg_o_loss:0.8672 , 1-val_avg_c_loss:0.8594 , 1-val_avg_e_loss:0.8355 , 1-val_avg_a_loss:0.8822 , 1-val_avg_n_loss:0.8245
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.23it/s]
# [2024-08-22 20:41:16,160]::1387131020::DEBUG::Epoch: 51 , 1-MAE: 0.8544 , 1-val_avg_o_loss:0.8670 , 1-val_avg_c_loss:0.8600 , 1-val_avg_e_loss:0.8371 , 1-val_avg_a_loss:0.8817 , 1-val_avg_n_loss:0.8261
# 100%|██████████| 758/758 [02:54<00:00,  4.35it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-22 20:44:28,339]::1387131020::DEBUG::Epoch: 52 , 1-MAE: 0.8537 , 1-val_avg_o_loss:0.8655 , 1-val_avg_c_loss:0.8604 , 1-val_avg_e_loss:0.8337 , 1-val_avg_a_loss:0.8813 , 1-val_avg_n_loss:0.8277
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 20:47:40,803]::1387131020::DEBUG::Epoch: 53 , 1-MAE: 0.8546 , 1-val_avg_o_loss:0.8658 , 1-val_avg_c_loss:0.8596 , 1-val_avg_e_loss:0.8372 , 1-val_avg_a_loss:0.8826 , 1-val_avg_n_loss:0.8278
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.13it/s]
# [2024-08-22 20:50:53,496]::1387131020::DEBUG::Epoch: 54 , 1-MAE: 0.8557 , 1-val_avg_o_loss:0.8681 , 1-val_avg_c_loss:0.8585 , 1-val_avg_e_loss:0.8400 , 1-val_avg_a_loss:0.8844 , 1-val_avg_n_loss:0.8274
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 20:54:05,880]::1387131020::DEBUG::Epoch: 55 , 1-MAE: 0.8526 , 1-val_avg_o_loss:0.8645 , 1-val_avg_c_loss:0.8591 , 1-val_avg_e_loss:0.8353 , 1-val_avg_a_loss:0.8806 , 1-val_avg_n_loss:0.8238
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.20it/s]
# [2024-08-22 20:57:19,030]::1387131020::DEBUG::Epoch: 56 , 1-MAE: 0.8547 , 1-val_avg_o_loss:0.8672 , 1-val_avg_c_loss:0.8601 , 1-val_avg_e_loss:0.8359 , 1-val_avg_a_loss:0.8819 , 1-val_avg_n_loss:0.8283
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 21:00:31,521]::1387131020::DEBUG::Epoch: 57 , 1-MAE: 0.8532 , 1-val_avg_o_loss:0.8647 , 1-val_avg_c_loss:0.8555 , 1-val_avg_e_loss:0.8376 , 1-val_avg_a_loss:0.8824 , 1-val_avg_n_loss:0.8259
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 21:03:43,916]::1387131020::DEBUG::Epoch: 58 , 1-MAE: 0.8529 , 1-val_avg_o_loss:0.8654 , 1-val_avg_c_loss:0.8618 , 1-val_avg_e_loss:0.8350 , 1-val_avg_a_loss:0.8785 , 1-val_avg_n_loss:0.8237
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.20it/s]
# [2024-08-22 21:06:56,426]::1387131020::DEBUG::Epoch: 59 , 1-MAE: 0.8529 , 1-val_avg_o_loss:0.8651 , 1-val_avg_c_loss:0.8569 , 1-val_avg_e_loss:0.8355 , 1-val_avg_a_loss:0.8803 , 1-val_avg_n_loss:0.8270
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.19it/s]
# [2024-08-22 21:10:09,142]::1387131020::DEBUG::Epoch: 60 , 1-MAE: 0.8534 , 1-val_avg_o_loss:0.8673 , 1-val_avg_c_loss:0.8593 , 1-val_avg_e_loss:0.8352 , 1-val_avg_a_loss:0.8790 , 1-val_avg_n_loss:0.8260
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-22 21:13:21,974]::1387131020::DEBUG::Epoch: 61 , 1-MAE: 0.8527 , 1-val_avg_o_loss:0.8671 , 1-val_avg_c_loss:0.8563 , 1-val_avg_e_loss:0.8331 , 1-val_avg_a_loss:0.8802 , 1-val_avg_n_loss:0.8268
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.13it/s]
# [2024-08-22 21:16:34,901]::1387131020::DEBUG::Epoch: 62 , 1-MAE: 0.8534 , 1-val_avg_o_loss:0.8669 , 1-val_avg_c_loss:0.8606 , 1-val_avg_e_loss:0.8364 , 1-val_avg_a_loss:0.8770 , 1-val_avg_n_loss:0.8260
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.10it/s]
# [2024-08-22 21:19:47,497]::1387131020::DEBUG::Epoch: 63 , 1-MAE: 0.8521 , 1-val_avg_o_loss:0.8626 , 1-val_avg_c_loss:0.8608 , 1-val_avg_e_loss:0.8329 , 1-val_avg_a_loss:0.8768 , 1-val_avg_n_loss:0.8273
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.20it/s]
# [2024-08-22 21:23:00,590]::1387131020::DEBUG::Epoch: 64 , 1-MAE: 0.8527 , 1-val_avg_o_loss:0.8648 , 1-val_avg_c_loss:0.8602 , 1-val_avg_e_loss:0.8337 , 1-val_avg_a_loss:0.8775 , 1-val_avg_n_loss:0.8276
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.17it/s]
# [2024-08-22 21:26:12,931]::1387131020::DEBUG::Epoch: 65 , 1-MAE: 0.8528 , 1-val_avg_o_loss:0.8665 , 1-val_avg_c_loss:0.8581 , 1-val_avg_e_loss:0.8338 , 1-val_avg_a_loss:0.8800 , 1-val_avg_n_loss:0.8254
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 21:29:25,467]::1387131020::DEBUG::Epoch: 66 , 1-MAE: 0.8526 , 1-val_avg_o_loss:0.8662 , 1-val_avg_c_loss:0.8573 , 1-val_avg_e_loss:0.8332 , 1-val_avg_a_loss:0.8806 , 1-val_avg_n_loss:0.8256
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.17it/s]
# [2024-08-22 21:32:38,678]::1387131020::DEBUG::Epoch: 67 , 1-MAE: 0.8554 , 1-val_avg_o_loss:0.8687 , 1-val_avg_c_loss:0.8566 , 1-val_avg_e_loss:0.8373 , 1-val_avg_a_loss:0.8834 , 1-val_avg_n_loss:0.8309
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 21:35:51,679]::1387131020::DEBUG::Epoch: 68 , 1-MAE: 0.8545 , 1-val_avg_o_loss:0.8670 , 1-val_avg_c_loss:0.8590 , 1-val_avg_e_loss:0.8355 , 1-val_avg_a_loss:0.8826 , 1-val_avg_n_loss:0.8286
# 100%|██████████| 758/758 [02:54<00:00,  4.35it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 21:39:03,764]::1387131020::DEBUG::Epoch: 69 , 1-MAE: 0.8546 , 1-val_avg_o_loss:0.8680 , 1-val_avg_c_loss:0.8595 , 1-val_avg_e_loss:0.8368 , 1-val_avg_a_loss:0.8799 , 1-val_avg_n_loss:0.8286
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 21:42:16,460]::1387131020::DEBUG::Epoch: 70 , 1-MAE: 0.8522 , 1-val_avg_o_loss:0.8650 , 1-val_avg_c_loss:0.8558 , 1-val_avg_e_loss:0.8353 , 1-val_avg_a_loss:0.8798 , 1-val_avg_n_loss:0.8252
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.17it/s]
# [2024-08-22 21:45:29,119]::1387131020::DEBUG::Epoch: 71 , 1-MAE: 0.8532 , 1-val_avg_o_loss:0.8672 , 1-val_avg_c_loss:0.8586 , 1-val_avg_e_loss:0.8336 , 1-val_avg_a_loss:0.8807 , 1-val_avg_n_loss:0.8259
# 100%|██████████| 758/758 [02:55<00:00,  4.31it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 21:48:42,508]::1387131020::DEBUG::Epoch: 72 , 1-MAE: 0.8539 , 1-val_avg_o_loss:0.8684 , 1-val_avg_c_loss:0.8588 , 1-val_avg_e_loss:0.8346 , 1-val_avg_a_loss:0.8805 , 1-val_avg_n_loss:0.8270
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.17it/s]
# [2024-08-22 21:51:54,920]::1387131020::DEBUG::Epoch: 73 , 1-MAE: 0.8525 , 1-val_avg_o_loss:0.8663 , 1-val_avg_c_loss:0.8562 , 1-val_avg_e_loss:0.8324 , 1-val_avg_a_loss:0.8801 , 1-val_avg_n_loss:0.8276
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.09it/s]
# [2024-08-22 21:55:07,496]::1387131020::DEBUG::Epoch: 74 , 1-MAE: 0.8530 , 1-val_avg_o_loss:0.8653 , 1-val_avg_c_loss:0.8599 , 1-val_avg_e_loss:0.8340 , 1-val_avg_a_loss:0.8757 , 1-val_avg_n_loss:0.8299
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.23it/s]
# [2024-08-22 21:58:19,646]::1387131020::DEBUG::Epoch: 75 , 1-MAE: 0.8516 , 1-val_avg_o_loss:0.8645 , 1-val_avg_c_loss:0.8562 , 1-val_avg_e_loss:0.8331 , 1-val_avg_a_loss:0.8784 , 1-val_avg_n_loss:0.8259
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-22 22:01:32,629]::1387131020::DEBUG::Epoch: 76 , 1-MAE: 0.8518 , 1-val_avg_o_loss:0.8650 , 1-val_avg_c_loss:0.8582 , 1-val_avg_e_loss:0.8318 , 1-val_avg_a_loss:0.8787 , 1-val_avg_n_loss:0.8252
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.17it/s]
# [2024-08-22 22:04:45,272]::1387131020::DEBUG::Epoch: 77 , 1-MAE: 0.8538 , 1-val_avg_o_loss:0.8663 , 1-val_avg_c_loss:0.8607 , 1-val_avg_e_loss:0.8350 , 1-val_avg_a_loss:0.8806 , 1-val_avg_n_loss:0.8263
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 22:07:57,903]::1387131020::DEBUG::Epoch: 78 , 1-MAE: 0.8521 , 1-val_avg_o_loss:0.8628 , 1-val_avg_c_loss:0.8576 , 1-val_avg_e_loss:0.8328 , 1-val_avg_a_loss:0.8797 , 1-val_avg_n_loss:0.8276
# 100%|██████████| 758/758 [02:55<00:00,  4.31it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 22:11:11,355]::1387131020::DEBUG::Epoch: 79 , 1-MAE: 0.8512 , 1-val_avg_o_loss:0.8638 , 1-val_avg_c_loss:0.8583 , 1-val_avg_e_loss:0.8323 , 1-val_avg_a_loss:0.8780 , 1-val_avg_n_loss:0.8234
# 100%|██████████| 758/758 [02:55<00:00,  4.31it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.13it/s]
# [2024-08-22 22:14:25,118]::1387131020::DEBUG::Epoch: 80 , 1-MAE: 0.8518 , 1-val_avg_o_loss:0.8648 , 1-val_avg_c_loss:0.8593 , 1-val_avg_e_loss:0.8313 , 1-val_avg_a_loss:0.8784 , 1-val_avg_n_loss:0.8252
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.19it/s]
# [2024-08-22 22:17:37,810]::1387131020::DEBUG::Epoch: 81 , 1-MAE: 0.8516 , 1-val_avg_o_loss:0.8634 , 1-val_avg_c_loss:0.8601 , 1-val_avg_e_loss:0.8319 , 1-val_avg_a_loss:0.8810 , 1-val_avg_n_loss:0.8217
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.12it/s]
# [2024-08-22 22:20:50,194]::1387131020::DEBUG::Epoch: 82 , 1-MAE: 0.8533 , 1-val_avg_o_loss:0.8660 , 1-val_avg_c_loss:0.8558 , 1-val_avg_e_loss:0.8358 , 1-val_avg_a_loss:0.8807 , 1-val_avg_n_loss:0.8285
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.16it/s]
# [2024-08-22 22:24:02,928]::1387131020::DEBUG::Epoch: 83 , 1-MAE: 0.8538 , 1-val_avg_o_loss:0.8663 , 1-val_avg_c_loss:0.8612 , 1-val_avg_e_loss:0.8357 , 1-val_avg_a_loss:0.8797 , 1-val_avg_n_loss:0.8258
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 22:27:15,273]::1387131020::DEBUG::Epoch: 84 , 1-MAE: 0.8558 , 1-val_avg_o_loss:0.8708 , 1-val_avg_c_loss:0.8539 , 1-val_avg_e_loss:0.8405 , 1-val_avg_a_loss:0.8840 , 1-val_avg_n_loss:0.8299
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.16it/s]
# [2024-08-22 22:30:28,039]::1387131020::DEBUG::Epoch: 85 , 1-MAE: 0.8522 , 1-val_avg_o_loss:0.8646 , 1-val_avg_c_loss:0.8569 , 1-val_avg_e_loss:0.8321 , 1-val_avg_a_loss:0.8812 , 1-val_avg_n_loss:0.8262
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.23it/s]
# [2024-08-22 22:33:41,062]::1387131020::DEBUG::Epoch: 86 , 1-MAE: 0.8537 , 1-val_avg_o_loss:0.8650 , 1-val_avg_c_loss:0.8616 , 1-val_avg_e_loss:0.8334 , 1-val_avg_a_loss:0.8815 , 1-val_avg_n_loss:0.8273
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 22:36:53,801]::1387131020::DEBUG::Epoch: 87 , 1-MAE: 0.8518 , 1-val_avg_o_loss:0.8650 , 1-val_avg_c_loss:0.8564 , 1-val_avg_e_loss:0.8348 , 1-val_avg_a_loss:0.8777 , 1-val_avg_n_loss:0.8251
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 22:40:06,275]::1387131020::DEBUG::Epoch: 88 , 1-MAE: 0.8530 , 1-val_avg_o_loss:0.8658 , 1-val_avg_c_loss:0.8598 , 1-val_avg_e_loss:0.8327 , 1-val_avg_a_loss:0.8820 , 1-val_avg_n_loss:0.8248
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.22it/s]
# [2024-08-22 22:43:19,266]::1387131020::DEBUG::Epoch: 89 , 1-MAE: 0.8524 , 1-val_avg_o_loss:0.8637 , 1-val_avg_c_loss:0.8582 , 1-val_avg_e_loss:0.8331 , 1-val_avg_a_loss:0.8799 , 1-val_avg_n_loss:0.8271
# 100%|██████████| 758/758 [02:55<00:00,  4.31it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 22:46:32,897]::1387131020::DEBUG::Epoch: 90 , 1-MAE: 0.8518 , 1-val_avg_o_loss:0.8637 , 1-val_avg_c_loss:0.8535 , 1-val_avg_e_loss:0.8369 , 1-val_avg_a_loss:0.8765 , 1-val_avg_n_loss:0.8283
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 22:49:45,717]::1387131020::DEBUG::Epoch: 91 , 1-MAE: 0.8515 , 1-val_avg_o_loss:0.8640 , 1-val_avg_c_loss:0.8590 , 1-val_avg_e_loss:0.8297 , 1-val_avg_a_loss:0.8780 , 1-val_avg_n_loss:0.8266
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.08it/s]
# [2024-08-22 22:52:59,004]::1387131020::DEBUG::Epoch: 92 , 1-MAE: 0.8517 , 1-val_avg_o_loss:0.8628 , 1-val_avg_c_loss:0.8598 , 1-val_avg_e_loss:0.8320 , 1-val_avg_a_loss:0.8806 , 1-val_avg_n_loss:0.8231
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.20it/s]
# [2024-08-22 22:56:11,846]::1387131020::DEBUG::Epoch: 93 , 1-MAE: 0.8552 , 1-val_avg_o_loss:0.8690 , 1-val_avg_c_loss:0.8598 , 1-val_avg_e_loss:0.8373 , 1-val_avg_a_loss:0.8806 , 1-val_avg_n_loss:0.8291
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 22:59:24,741]::1387131020::DEBUG::Epoch: 94 , 1-MAE: 0.8523 , 1-val_avg_o_loss:0.8645 , 1-val_avg_c_loss:0.8617 , 1-val_avg_e_loss:0.8320 , 1-val_avg_a_loss:0.8773 , 1-val_avg_n_loss:0.8260
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.16it/s]
# [2024-08-22 23:02:37,842]::1387131020::DEBUG::Epoch: 95 , 1-MAE: 0.8504 , 1-val_avg_o_loss:0.8619 , 1-val_avg_c_loss:0.8572 , 1-val_avg_e_loss:0.8311 , 1-val_avg_a_loss:0.8794 , 1-val_avg_n_loss:0.8225
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-22 23:05:50,484]::1387131020::DEBUG::Epoch: 96 , 1-MAE: 0.8509 , 1-val_avg_o_loss:0.8626 , 1-val_avg_c_loss:0.8556 , 1-val_avg_e_loss:0.8331 , 1-val_avg_a_loss:0.8785 , 1-val_avg_n_loss:0.8248
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-22 23:09:03,355]::1387131020::DEBUG::Epoch: 97 , 1-MAE: 0.8539 , 1-val_avg_o_loss:0.8669 , 1-val_avg_c_loss:0.8574 , 1-val_avg_e_loss:0.8386 , 1-val_avg_a_loss:0.8790 , 1-val_avg_n_loss:0.8276
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 23:12:16,458]::1387131020::DEBUG::Epoch: 98 , 1-MAE: 0.8532 , 1-val_avg_o_loss:0.8675 , 1-val_avg_c_loss:0.8575 , 1-val_avg_e_loss:0.8360 , 1-val_avg_a_loss:0.8799 , 1-val_avg_n_loss:0.8249
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.12it/s]
# [2024-08-22 23:15:29,789]::1387131020::DEBUG::Epoch: 99 , 1-MAE: 0.8506 , 1-val_avg_o_loss:0.8628 , 1-val_avg_c_loss:0.8544 , 1-val_avg_e_loss:0.8337 , 1-val_avg_a_loss:0.8765 , 1-val_avg_n_loss:0.8259
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.20it/s]
# [2024-08-22 23:18:42,702]::1387131020::DEBUG::Epoch: 100 , 1-MAE: 0.8545 , 1-val_avg_o_loss:0.8670 , 1-val_avg_c_loss:0.8550 , 1-val_avg_e_loss:0.8379 , 1-val_avg_a_loss:0.8838 , 1-val_avg_n_loss:0.8288
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.26it/s]
# [2024-08-22 23:21:55,062]::1387131020::DEBUG::Epoch: 101 , 1-MAE: 0.8537 , 1-val_avg_o_loss:0.8633 , 1-val_avg_c_loss:0.8558 , 1-val_avg_e_loss:0.8371 , 1-val_avg_a_loss:0.8825 , 1-val_avg_n_loss:0.8298
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 23:25:07,832]::1387131020::DEBUG::Epoch: 102 , 1-MAE: 0.8541 , 1-val_avg_o_loss:0.8657 , 1-val_avg_c_loss:0.8567 , 1-val_avg_e_loss:0.8365 , 1-val_avg_a_loss:0.8829 , 1-val_avg_n_loss:0.8288
# 100%|██████████| 758/758 [02:54<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.12it/s]
# [2024-08-22 23:28:20,540]::1387131020::DEBUG::Epoch: 103 , 1-MAE: 0.8528 , 1-val_avg_o_loss:0.8642 , 1-val_avg_c_loss:0.8569 , 1-val_avg_e_loss:0.8338 , 1-val_avg_a_loss:0.8799 , 1-val_avg_n_loss:0.8294
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.17it/s]
# [2024-08-22 23:31:33,308]::1387131020::DEBUG::Epoch: 104 , 1-MAE: 0.8526 , 1-val_avg_o_loss:0.8656 , 1-val_avg_c_loss:0.8567 , 1-val_avg_e_loss:0.8345 , 1-val_avg_a_loss:0.8782 , 1-val_avg_n_loss:0.8282
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.07it/s]
# [2024-08-22 23:34:46,499]::1387131020::DEBUG::Epoch: 105 , 1-MAE: 0.8526 , 1-val_avg_o_loss:0.8651 , 1-val_avg_c_loss:0.8565 , 1-val_avg_e_loss:0.8350 , 1-val_avg_a_loss:0.8763 , 1-val_avg_n_loss:0.8302
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 23:37:59,617]::1387131020::DEBUG::Epoch: 106 , 1-MAE: 0.8530 , 1-val_avg_o_loss:0.8645 , 1-val_avg_c_loss:0.8583 , 1-val_avg_e_loss:0.8339 , 1-val_avg_a_loss:0.8805 , 1-val_avg_n_loss:0.8276
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-22 23:41:11,786]::1387131020::DEBUG::Epoch: 107 , 1-MAE: 0.8538 , 1-val_avg_o_loss:0.8654 , 1-val_avg_c_loss:0.8593 , 1-val_avg_e_loss:0.8350 , 1-val_avg_a_loss:0.8822 , 1-val_avg_n_loss:0.8272
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 23:44:24,274]::1387131020::DEBUG::Epoch: 108 , 1-MAE: 0.8554 , 1-val_avg_o_loss:0.8678 , 1-val_avg_c_loss:0.8583 , 1-val_avg_e_loss:0.8372 , 1-val_avg_a_loss:0.8849 , 1-val_avg_n_loss:0.8289
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 23:47:36,704]::1387131020::DEBUG::Epoch: 109 , 1-MAE: 0.8517 , 1-val_avg_o_loss:0.8634 , 1-val_avg_c_loss:0.8578 , 1-val_avg_e_loss:0.8333 , 1-val_avg_a_loss:0.8784 , 1-val_avg_n_loss:0.8257
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.18it/s]
# [2024-08-22 23:50:48,985]::1387131020::DEBUG::Epoch: 110 , 1-MAE: 0.8510 , 1-val_avg_o_loss:0.8620 , 1-val_avg_c_loss:0.8577 , 1-val_avg_e_loss:0.8306 , 1-val_avg_a_loss:0.8799 , 1-val_avg_n_loss:0.8248
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-22 23:54:02,404]::1387131020::DEBUG::Epoch: 111 , 1-MAE: 0.8531 , 1-val_avg_o_loss:0.8647 , 1-val_avg_c_loss:0.8595 , 1-val_avg_e_loss:0.8332 , 1-val_avg_a_loss:0.8821 , 1-val_avg_n_loss:0.8263
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.19it/s]
# [2024-08-22 23:57:15,116]::1387131020::DEBUG::Epoch: 112 , 1-MAE: 0.8524 , 1-val_avg_o_loss:0.8670 , 1-val_avg_c_loss:0.8571 , 1-val_avg_e_loss:0.8338 , 1-val_avg_a_loss:0.8795 , 1-val_avg_n_loss:0.8247
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.21it/s]
# [2024-08-23 00:00:28,303]::1387131020::DEBUG::Epoch: 113 , 1-MAE: 0.8527 , 1-val_avg_o_loss:0.8663 , 1-val_avg_c_loss:0.8589 , 1-val_avg_e_loss:0.8341 , 1-val_avg_a_loss:0.8769 , 1-val_avg_n_loss:0.8275
# 100%|██████████| 758/758 [02:55<00:00,  4.33it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.12it/s]
# [2024-08-23 00:03:41,182]::1387131020::DEBUG::Epoch: 114 , 1-MAE: 0.8527 , 1-val_avg_o_loss:0.8643 , 1-val_avg_c_loss:0.8546 , 1-val_avg_e_loss:0.8365 , 1-val_avg_a_loss:0.8803 , 1-val_avg_n_loss:0.8278
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.20it/s]
# [2024-08-23 00:06:54,250]::1387131020::DEBUG::Epoch: 115 , 1-MAE: 0.8519 , 1-val_avg_o_loss:0.8657 , 1-val_avg_c_loss:0.8580 , 1-val_avg_e_loss:0.8327 , 1-val_avg_a_loss:0.8785 , 1-val_avg_n_loss:0.8248
# 100%|██████████| 758/758 [02:54<00:00,  4.34it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.15it/s]
# [2024-08-23 00:10:06,677]::1387131020::DEBUG::Epoch: 116 , 1-MAE: 0.8529 , 1-val_avg_o_loss:0.8668 , 1-val_avg_c_loss:0.8571 , 1-val_avg_e_loss:0.8343 , 1-val_avg_a_loss:0.8770 , 1-val_avg_n_loss:0.8295
# 100%|██████████| 758/758 [02:55<00:00,  4.31it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.13it/s]
# [2024-08-23 00:13:20,176]::1387131020::DEBUG::Epoch: 117 , 1-MAE: 0.8518 , 1-val_avg_o_loss:0.8634 , 1-val_avg_c_loss:0.8561 , 1-val_avg_e_loss:0.8339 , 1-val_avg_a_loss:0.8805 , 1-val_avg_n_loss:0.8253
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.14it/s]
# [2024-08-23 00:16:33,271]::1387131020::DEBUG::Epoch: 118 , 1-MAE: 0.8527 , 1-val_avg_o_loss:0.8644 , 1-val_avg_c_loss:0.8583 , 1-val_avg_e_loss:0.8343 , 1-val_avg_a_loss:0.8805 , 1-val_avg_n_loss:0.8258
# 100%|██████████| 758/758 [02:55<00:00,  4.32it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.11it/s]
# [2024-08-23 00:19:46,366]::1387131020::DEBUG::Epoch: 119 , 1-MAE: 0.8502 , 1-val_avg_o_loss:0.8634 , 1-val_avg_c_loss:0.8544 , 1-val_avg_e_loss:0.8320 , 1-val_avg_a_loss:0.8782 , 1-val_avg_n_loss:0.8229
# 100%|██████████| 758/758 [02:55<00:00,  4.31it/s]
# 100%|██████████| 193/193 [00:17<00:00, 11.23it/s]
# [2024-08-23 00:22:59,823]::1387131020::DEBUG::Epoch: 120 , 1-MAE: 0.8538 , 1-val_avg_o_loss:0.8689 , 1-val_avg_c_loss:0.8557 , 1-val_avg_e_loss:0.8360 , 1-val_avg_a_loss:0.8804 , 1-val_avg_n_loss:0.8280
